# %%
i

# Create a 100x100 pixel grayscale image with random pixel values
#define our width and height / hard code them just to show
width, height = 100, 100
#create numpy array - have rndome values fomr 0 to 255 - thats the diomension
#type of integers are np.unti78 we qe want an 8 bit image
gray_image = np.random.randint(0, 256, (height, width), dtype=np.uint8)

#print(gray_image)
mport numpy as np
import skimage.io as io
import matplotlib.pyplot as plt

# Display the image (optional)
io.imshow(gray_image)
# can also show imahes with set_matplotlib_close - think i.show is going to be deprecated....
plt.show()
# Out:
# C:\Users\eamon\AppData\Local\Temp\ipykernel_29508\778595831.py:16: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(gray_image)

# %%
# Create a 100x100 pixel RGB image with random pixel values
# a;most same as before with 3rd dimension 3, thsi is an rgb image
#
# red  / gren and blue channels...'
width, height = 100, 100
rgb_image = np.random.randint(0, 256, (height, width, 3), dtype=np.uint8)

# Display the image (optional)
io.imshow(rgb_image)
# Out:
# C:\Users\eamon\AppData\Local\Temp\ipykernel_29508\1886237462.py:6: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(rgb_image)

# %%
# import skimage.io as io
# image = io.imread('Red-Cat-8727.jpg')
# io.imshow(image)

# import skimage.io as io
# image = io.imread('Red-Cat-8727.jpg', as_gray=True)
# io.imshow(image)


import skimage.io as io
import matplotlib.pyplot as plt
image = io.imread('https://i.ibb.co/h041g0p/Red-Cat-8727.jpg')
plt.imshow(image)

# %%
from PIL import Image
from PIL.ExifTags import TAGS
# Open the image
image = Image.open("tokyo.jpg")
# Extracting the exif metadata
exifdata = image.getexif()


# Looping through all the tags present 
# in exifdata
image = Image.open("tokyo.jpg")
for tagid in exifdata:
    # getting the tag name instead of tag id
    tagname = TAGS.get(tagid, tagid)
    # passing the tagid to get its respective value
    value = exifdata.get(tagid)
    # printing the final result
    print(f"{tagname:17}: {value}")
image.close()
# Out:
# GPSInfo          : 26172
# ResolutionUnit   : 2
# ExifOffset       : 360
# Make             : Canon
# Model            : Canon EOS R50
# YResolution      : 350.0
# Orientation      : 1
# DateTime         : 2023:08:22 04:57:38
# YCbCrPositioning : 2
# Copyright        :
# XResolution      : 350.0
# Artist           :

# %%
# Task 3 - Pillow package modifyh exfi to add artistg and display

from PIL import Image
from PIL.ExifTags import TAGS
# Open the image
image = Image.open("tokyo.jpg")
# Extracting the exif metadata
exifdata = image.getexif()
image.shape
# this is the answer below!!!
exifdata[315] = "Sarah"


# Looping through all the tags present 
# in exifdata
for tagid in exifdata:
    # getting the tag name instead of tag id
    tagname = TAGS.get(tagid, tagid)
    # passing the tagid to get its respective value
    value = exifdata.get(tagid)
    # printing the final result
    print(f"{tagname:17}: {value}")
image.close()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 9
#       7 # Extracting the exif metadata
#       8 exifdata = image.getexif()
# ----> 9 image.shape
#      10 # this is the answer below!!!
#      11 exifdata[315] = "Sarah"
#
# File c:\Users\eamon\anaconda3\envs\assignment-a\Lib\site-packages\PIL\JpegImagePlugin.py:399, in JpegImageFile.__getattr__(self, name)
#     397     deprecate(name, 12)
#     398     return getattr(self, "_" + name)
# --> 399 raise AttributeError(name)
#
# AttributeError: shape
