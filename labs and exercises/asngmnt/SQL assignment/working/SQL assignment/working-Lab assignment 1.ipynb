# %% [markdown]
# **Module**: Data 9910 – Working with Data
#
# **Lecturer**: Lucas Rizzo
#
# **Class Group**: TU059/060/256
#
# **Worth**: 20%
#
# **Due Time**: Before next class on Week 6.
#
# **Programming Language**: The test can be done in both `R` or `Python`. You can change the kernel language going in *Kernel > Change Kernel*

# %% [markdown]
# ### Submission

# %% [markdown]
# Please submit this notebook and additional files (if any) in a zip file. ***Submissions without a report won't be accepted.***

# %% [markdown]
# # Problem description

# %% [markdown]
# A telecommunications company is starting a data project to improve their customer analytics capabilities. During informal interviews with the stakeholders, the following were suggested as possible features for the system:
#
# - identify trends by certain types of customers
# - identify trends by certain types of calls
# - identify relevant statistical information of overall calls performed by customers

# %% [markdown]
# # Dataset

# %% [markdown]
# The company has provided you with an sql dump in two files (`db.ddl` and `data.sql`) to replicate their PostgreSQL database. However, they are not very organised and did not provide a documentation alongside it. Hence, you will be required to recreate it and do some investigation to understand their data. Note that a ddl file also containts sql commands, but only those that describes the portion of SQL that creates, alters, and deletes database objects

# %% [markdown]
# ### Create a new local database
#
# Using pgAdmin create a new server to run the sql files.
#
# ![Screenshot of pgAdmin 4 to create a new connection](new_connection.jpg)
#
# You can use the parameters below to create the databse. If you use different ones you will need to remember them to connect to the database.
#
# `user = 'postgres'`
#
# `password = 'admin'`
#
# `host = 'localhost'`
#
# `port = 5432`
#
# `database = 'telecommunications'`

# %% [markdown]
# ### Import the data

# %% [markdown]
# Using the query tool open the `db.ddl` file and run the commands to create the necessary tables. After that, open the `data.sql` to run the insert commands and add all the data to the database (this can take around 20 seconds to run).
#
# ![Screenshot of pgAdmin 4 to open a SQL file in the query tool](query_tool.jpg)

# %% [markdown]
# ### QUESTION 1

# %% [markdown]
# Using your preferred language (R or Python) create a connection object to the companies database. (1 mark)

# %%
# import required packages
import sqlalchemy as db
from sqlalchemy import text
import pandas as pd
import psycopg2
from sqlalchemy import Table, Column, Integer, String, MetaData

# %%
# create a connection to the telecommunications database
user = 'postgres'
password = 'password0134!'
host = 'localhost'
port = 5432
database = 'telecommunications'

engine = db.create_engine('postgresql+psycopg2://{0}:{1}@{2}:{3}/{4}'.format(user,
                                                                    password,
                                                                    host,
                                                                    port,
                                                                    database))
conn = engine.connect()


metadata_obj = db.MetaData() # import and initialise a metadata obj
metadata_obj.reflect(bind=engine) # reflect

# %% [markdown]
# ### QUESTION 2

# %% [markdown]
# Extract the ERD from the database (this can be done via PgAdmin or via sqlalchemy_schemadisplay). Write a general description of the database structure (2 marks)

# %% [markdown]
# Below is an overview of the **telecommunications** database and  its Entity Relationship Diagram (ERD).
#
# ### Tables
# There are 4 tables present in the database
# - *call_rates*
#     - Primary Key = *callrate* - this is a unique identifier
#     - Foreign Key = None - no constraints on tables values
#     - Attributes and datatype =
#         - *callrate* = int
#         - *isinternatioal* = VARCHAR(5) - contains TRUE  / FALSE values - should be Boolean
#         - *isroaming* = VARCHAR(5) -  - contains TRUE  / FALSE values - should be Boolean
#         - *costperminute* = numeric(4,2) precision and scale values (00.00)
# - *calls*
#     - Primary Key = *connectionid* - this is a unique identifier
#     - Foreign Keys = *call_rates.callrate* + *customers.phonenumber*
#     - attributes =
#         - *phonenumber* = VARCHAR(13)
#         - *calltime* = VARCHAR(16)
#         - *duration* = numeric(13,9) precision and scale values (0000.000000000)
#         - *connectionid* = VARCHAR(36)
#         - *callrate* = int
# - *customers*
#     - Primary Key = *phonenumber* - this is a unique identifier
#     - Foreign Key = None - no constraints on tables values
#     - attributes =
#         - *phonenumber* = VARCHAR(13)
#         - *contractstartdate* = date
#         - *dob* = date
# - *customer_service*
#     - Primary Key = *connectionid* - this is a unique identifier
#     - Foreign Key = calls.connectionid -
#     - attributes =
#         - *connectionid* = VARCHAR(36)
#
# ### Relationships
# - The *calls* table is a bridging entity between the customers and call_rates tables.
#     - *callrate* could have many *calls* associated with it but a *call* can have only one *callrate*
#     - *customers* could have many *calls* but a *call* can only have one *customer*
# - The *customer_service* table has a one to one relationship with the *calls* table
#     - a *customer_service* entry can only have one *call* and *call* can only have one *customer_service* id
#
# ### shape and structure
# - Max number of rows  = 1000 rows in *customer_service*,  *customers* and *calls*.
# - max number of columns = 5 in calls.
#
#
# ![telecommunication database erd diagram](./tcomm-erd-2.png)
# ERD diagram

# %%
# place the db tables into a pandas dataframe and place that dataframe into a dictionary with the table names as the keys
# this will allow me to more easily loop through them and utilise some of the built in pandas functionaility supporting data analysis
# 
db_table_names = ["customers", "calls", "customer_service", "call_rates"]

# create a dictionary to place the tables into in python
tbls_dict ={}

# loop through the tables using the selct query to get all the table rows and columns into a dictionary, some references used from here
# https://stackoverflow.com/questions/24959589/get-table-columns-from-sqlalchemy-table-model
for table_name in db_table_names:
        table = db.Table(table_name, metadata_obj, autoload=True, autoload_with=engine) # create a sqlalchemy table object we cna manipulate
        stmt = db.select(table)       # select statement in SQLALchemy
        result = conn.execute(stmt).fetchall() # execute the query in the connection and store the return in results using fetchall to return all rows
        columns = table.columns.keys() # get columns names which will sue in dictionary
        # put results into dictionary created earlier, specifies the table name as the key so cna access by table name
        tbls_dict[table_name] = pd.DataFrame(result, columns=columns)
        
# get the shape of all four tables i.e. num rows and columns 
print('----table shape--------------------')

for table_name, df in tbls_dict.items():
        print(f"{table_name} : {df.shape}")

# print('---------NA values---------------')

# # get any NUll or NA values
# for table_name, df in tbls_dict.items():
#         print((f"--- table_name--- : {table_name})"))
#         print(df.isna().sum())
        
        
for table_name, df in tbls_dict.items():
        print((f"------------------------ table_name   = {table_name})  -------------------------------"))
        missing_cnt = (df=='?').sum()
        print('\"  <<<    ?   >>>   \" values present =  \n', missing_cnt)
        print('------')
        unknown_cnt = (df=='unknown').sum()
        print('\"   <<< unknown >>>   \" values present =  \n', unknown_cnt)
        print('------')
        na_cnt = df.isin(['N/A', 'N\\A', 'NA', 'n/a', 'n\\A', 'na', 'N_A']).sum()
        print('   <<<  NA  >>>    values present = \n', na_cnt)
        print('------')
        none_cnt = df.isin(['None', 'none']).sum()
        print('    none    values present = \n', none_cnt)
        print('------')
        dup_rows = (df.duplicated().sum())
        print('   <<< duplicate rows  >>>  =  \n', none_cnt)
# Out:
# ----table shape--------------------
# customers : (4999, 3)
# calls : (161584, 5)
# customer_service : (16189, 1)
# call_rates : (4, 4)
# ------------------------ table_name   = customers)  -------------------------------
# "  <<<    ?   >>>   " values present =
#  phonenumber          0
# contractstartdate    0
# dob                  0
# dtype: int64
# ------
# "   <<< unknown >>>   " values present =
#  phonenumber          0
# contractstartdate    0
# dob                  0
# dtype: int64
# ------
#    <<<  NA  >>>    values present =
#  phonenumber          0
# contractstartdate    0
# dob                  0
# dtype: int64
# ------
#     none    values present =
#  phonenumber          0
# contractstartdate    0
# dob                  0
# dtype: int64
# ------
#    <<< duplicate rows  >>>  =
#  phonenumber          0
# contractstartdate    0
# dob                  0
# dtype: int64
# ------------------------ table_name   = calls)  -------------------------------
# "  <<<    ?   >>>   " values present =
#  phonenumber     0
# calltime        0
# duration        0
# connectionid    0
# callrate        0
# dtype: int64
# ------
# "   <<< unknown >>>   " values present =
#  phonenumber     0
# calltime        0
# duration        0
# connectionid    0
# callrate        0
# dtype: int64
# ------
#    <<<  NA  >>>    values present =
#  phonenumber     0
# calltime        0
# duration        0
# connectionid    0
# callrate        0
# dtype: int64
# ------
#     none    values present =
#  phonenumber     0
# calltime        0
# duration        0
# connectionid    0
# callrate        0
# dtype: int64
# ------
#    <<< duplicate rows  >>>  =
#  phonenumber     0
# calltime        0
# duration        0
# connectionid    0
# callrate        0
# dtype: int64
# ------------------------ table_name   = customer_service)  -------------------------------
# "  <<<    ?   >>>   " values present =
#  connectionid    0
# dtype: int64
# ------
# "   <<< unknown >>>   " values present =
#  connectionid    0
# dtype: int64
# ------
#    <<<  NA  >>>    values present =
#  connectionid    0
# dtype: int64
# ------
#     none    values present =
#  connectionid    0
# dtype: int64
# ------
#    <<< duplicate rows  >>>  =
#  connectionid    0
# dtype: int64
# ------------------------ table_name   = call_rates)  -------------------------------
# "  <<<    ?   >>>   " values present =
#  callrate           0
# isinternational    0
# isroaming          0
# costperminute      0
# dtype: int64
# ------
# "   <<< unknown >>>   " values present =
#  callrate           0
# isinternational    0
# isroaming          0
# costperminute      0
# dtype: int64
# ------
#    <<<  NA  >>>    values present =
#  callrate           0
# isinternational    0
# isroaming          0
# costperminute      0
# dtype: int64
# ------
#     none    values present =
#  callrate           0
# isinternational    0
# isroaming          0
# costperminute      0
# dtype: int64
# ------
#    <<< duplicate rows  >>>  =
#  callrate           0
# isinternational    0
# isroaming          0
# costperminute      0
# dtype: int64

# %% [markdown]
# # Customer information

# %% [markdown]
# Query the database to extract the following information:

# %% [markdown]
# a) The overall number of customers (1 mark)

# %%
# establish connection
result = conn.execute(text("SELECT COUNT(*) FROM customers"))

# hav to sue fetchone, as fetch returns nothing, fetch all give two elements, and fetch many returns full tuple, the second one being empty
# fetchone is returning first column in the next row of the resutl values returned'
num_cust=result.fetchone()[0]
print(f' Total number of customers  = {num_cust}')
# Out:
#  Total number of customers  = 4999

# %%
# result = conn.execute(text("SELECT COUNT(*) FROM customers"))

# print(result)
# # # print all results
# for row in result:
#     print(row)
# # Fetch the single result row
# total_customers = result.scalar()

# print("Total number of customers:", total_customers)

# inspector = inspect(engine)
# tables = inspector.get_table_names()

# print("Number of tables:", len(tables))
# print("Table names:", tables)

# Run the query and load directly into a pandas DataFrame
# df_total = pd.read_sql(text("SELECT COUNT(*) AS total_customers FROM customers;"), conn)

# # Display the DataFrame nicely
# print(df_total)


#pd.read_sql(text("SELECT table_schema, table_name FROM information_schema.tables WHERE table_name = 'customers';"), conn)
df_check = pd.read_sql(text("""
SELECT 
    COUNT(*) AS total_rows,
    COUNT(DISTINCT phonenumber) AS unique_customers
FROM customers;
"""), conn)

print(df_check)
# Out:
#    total_rows  unique_customers
# 0        4999              4999

# %%
# a customer could have more than one phone
# but we will just determin the number of customers regardless of the number of unique phone numbers
# do they match?
Select count
cust_count_df <- dbGetQuery(con, "SELECT COUNT(student_number) FROM student WHERE dob > '01-Nov-1980'")
head(s_count_df)

# %% [markdown]
# b) The number of customers by year of DOB in descending order (2 marks)

# %%
# we'll put a sql query straight into the db and get the rsult
# stmt = db.select(
    
stmt = ("SELECT EXTRACT(YEAR FROM dob) AS birth_year, COUNT(*) AS num_customers FROM customers GROUP BY birth_year ORDER BY birth_year DESC")

result = conn.execute(text(stmt)).fetchall()

# put it into a dataframe to more easily format it for viewing
df=pd.DataFrame(result, columns=['year_born', 'num_custs'])
print(df)
# will cross valdiate the answer bty checkgin the total number in the data = the tital num  of customers we calcualted earier
# thsi is just an extra layer of cross validation that our answer is correct
print("total customers validation from results ", df['num_custs'].sum()) # to check if total number  = 4999
# Out:
#    year_born  num_custs
# 0       2000          1
# 1       1999         97
# 2       1998         89
# 3       1997        115
# 4       1996         87
# 5       1995        105
# 6       1994        108
# 7       1993         98
# 8       1992         94
# 9       1991         99
# 10      1990         92
# 11      1989         96
# 12      1988         96
# 13      1987        105
# 14      1986        107
# 15      1985        100
# 16      1984         80
# 17      1983         99
# 18      1982         97
# 19      1981         91
# 20      1980        104
# 21      1979         70
# 22      1978        108
# 23      1977        101
# 24      1976        112
# 25      1975        111
# 26      1974        102
# 27      1973        105
# 28      1972         95
# 29      1971         97
# 30      1970        105
# 31      1969        105
# 32      1968         76
# 33      1967         93
# 34      1966         96
# 35      1965         98
# 36      1964        108
# 37      1963         83
# 38      1962        105
# 39      1961        105
# 40      1960        105
# 41      1959        113
# 42      1958        111
# 43      1957         99
# 44      1956        108
# 45      1955        110
# 46      1954        103
# 47      1953        110
# 48      1952        105
# 49      1951         93
# 50      1950        107
# total customers validation from results  4999

# %%
from sqlalchemy import text
import pandas as pd

# SQL query to count customers by birth year
query = """
    SELECT EXTRACT(YEAR FROM dob) AS birth_year,
           COUNT(*) AS num_customers
    FROM customers
    GROUP BY birth_year
    ORDER BY birth_year DESC
"""

# Execute the query
result = conn.execute(text(query))

# Fetch all results and put into a DataFrame
df_birth_year_counts = pd.DataFrame(result.fetchall(), columns=['birth_year', 'num_customers'])

# View the result
print(df_birth_year_counts)
# Out:
#    birth_year  num_customers
# 0        2000              1
# 1        1999             97
# 2        1998             89
# 3        1997            115
# 4        1996             87
# 5        1995            105
# 6        1994            108
# 7        1993             98
# 8        1992             94
# 9        1991             99
# 10       1990             92
# 11       1989             96
# 12       1988             96
# 13       1987            105
# 14       1986            107
# 15       1985            100
# 16       1984             80
# 17       1983             99
# 18       1982             97
# 19       1981             91
# 20       1980            104
# 21       1979             70
# 22       1978            108
# 23       1977            101
# 24       1976            112
# 25       1975            111
# 26       1974            102
# 27       1973            105
# 28       1972             95
# 29       1971             97
# 30       1970            105
# 31       1969            105
# 32       1968             76
# 33       1967             93
# 34       1966             96
# 35       1965             98
# 36       1964            108
# 37       1963             83
# 38       1962            105
# 39       1961            105
# 40       1960            105
# 41       1959            113
# 42       1958            111
# 43       1957             99
# 44       1956            108
# 45       1955            110
# 46       1954            103
# 47       1953            110
# 48       1952            105
# 49       1951             93
# 50       1950            107

# %% [markdown]
# c) Analyse the query below and describe what is the result given by it. (1 mark)

# %%
# Python (uncomment if you are using Python)

stmt = db.select(
    
    
)

result = conn.execute(text("SELECT c.phonenumber, SUM(cr.costperminute * c.duration) AS total_amount_spent " + 
                      "FROM public.calls c INNER JOIN public.call_rates cr ON c.callrate = cr.callrate "
                      "WHERE c.connectionid NOT IN ( SELECT DISTINCT connectionid FROM public.customer_service) " +
                      "GROUP BY c.phonenumber ORDER BY c.phonenumber;"))
for row in result:
    print(row)

# R (uncomment if you are using R)
# query <- "SELECT c.phonenumber, SUM(cr.costperminute * c.duration) AS total_amount_spent"
# query <- paste(query, "FROM public.calls c INNER JOIN public.call_rates cr ON c.callrate = cr.callrate")
# query <- paste(query, "WHERE c.connectionid NOT IN ( SELECT DISTINCT connectionid FROM public.customer_service)")
# query <- paste(query, "GROUP BY c.phonenumber ORDER BY c.phonenumber;")

# result <- dbGetQuery(con, query)

# result
# Out:
# ('01 000 9436', Decimal('3201.22279225500'))
# ('01 001 6896', Decimal('11069.16794494900'))
# ('01 001 9955', Decimal('3143.07759377700'))
# ('01 002 1488', Decimal('7667.06401183800'))
# ('01 002 1807', Decimal('1037.42097668100'))
# ('01 002 3138', Decimal('10969.08258640800'))
# ('01 002 7003', Decimal('25476.58783680990'))
# ('01 003 5862', Decimal('2178.43534643600'))
# ('01 004 1518', Decimal('1583.04664798870'))
# ('01 004 3369', Decimal('1893.67951344500'))
# ('01 004 6123', Decimal('3919.39081954100'))
# ('01 005 3059', Decimal('6618.55011914400'))
# ('01 005 7353', Decimal('2169.99057156000'))
# ('01 005 8909', Decimal('16340.42254020600'))
# ('01 005 9012', Decimal('13579.88341802100'))
# ('01 006 5619', Decimal('9908.71578357400'))
# ('01 006 8032', Decimal('6544.87565328800'))
# ('01 007 0548', Decimal('10625.15229737000'))
# ('01 007 3126', Decimal('16346.97708737820'))
# ('01 008 0438', Decimal('11732.57507735700'))
# ('01 008 1378', Decimal('16202.03157874900'))
# ('01 008 2702', Decimal('2093.73442266500'))
# ('01 008 5273', Decimal('5212.03782482500'))
# ('01 008 6188', Decimal('604.90602753600'))
# ('01 009 8882', Decimal('6438.23909134200'))
# ('01 010 3210', Decimal('994.47204624600'))
# ('01 010 4583', Decimal('3652.19646965700'))
# ('01 010 9798', Decimal('13200.33665920640'))
# ('01 011 1266', Decimal('2692.98790003200'))
# ('01 011 1953', Decimal('8352.79487290800'))
# ('01 011 8477', Decimal('10128.51896065000'))
# ('01 012 7288', Decimal('12143.71717179510'))
# ('01 013 7832', Decimal('15756.26908299400'))
# ('01 014 0689', Decimal('6555.21606614010'))
# ('01 014 1996', Decimal('7723.68498584300'))
# ('01 016 0950', Decimal('7681.59676234180'))
# ('01 018 5577', Decimal('9739.18611223100'))
# ('01 019 5062', Decimal('7147.24923474700'))
# ('01 019 5772', Decimal('2619.93214362900'))
# ('01 020 0786', Decimal('11021.01452169650'))
# ('01 020 1096', Decimal('5360.10134083900'))
# ('01 020 6183', Decimal('13118.99206286340'))
# ('01 020 7989', Decimal('5537.04718490300'))
# ('01 020 9379', Decimal('7767.24311661700'))
# ('01 021 2043', Decimal('17975.66459880400'))
# ('01 021 4367', Decimal('20908.16364052500'))
# ('01 021 5019', Decimal('19953.98072896300'))
# ('01 021 5942', Decimal('4116.69812355900'))
# ('01 022 1093', Decimal('6147.65384866400'))
# ('01 022 2769', Decimal('10529.14719029000'))
# ('01 023 1536', Decimal('9420.34906963300'))
# ('01 023 6034', Decimal('16997.70858894000'))
# ('01 023 8054', Decimal('6734.29134534100'))
# ('01 025 2912', Decimal('2907.11030114200'))
# ('01 025 5897', Decimal('6114.86535435100'))
# ('01 025 6508', Decimal('3764.85638656080'))
# ('01 025 6891', Decimal('4659.62932753200'))
# ('01 025 7679', Decimal('246.17357167400'))
# ('01 026 1446', Decimal('12863.79671161800'))
# ('01 026 5303', Decimal('7813.30799693300'))
# ('01 026 8589', Decimal('8255.82321558000'))
# ('01 027 3127', Decimal('9706.32416658630'))
# ('01 027 6544', Decimal('5669.38738566100'))
# ('01 027 7838', Decimal('2512.60812188600'))
# ('01 028 5379', Decimal('14295.03610590006'))
# ('01 028 7785', Decimal('8112.61185456050'))
# ('01 029 5689', Decimal('46.28027419200'))
# ('01 029 6454', Decimal('20157.14044059000'))
# ('01 029 8602', Decimal('2064.31737230300'))
# ('01 029 9299', Decimal('882.57581278230'))
# ('01 030 0622', Decimal('9876.37171440000'))
# ('01 030 5462', Decimal('3269.23403390700'))
# ('01 031 1696', Decimal('15100.71716459950'))
# ('01 031 7619', Decimal('2931.60202557200'))
# ('01 031 8008', Decimal('4696.51274518320'))
# ('01 033 6968', Decimal('382.21382376000'))
# ('01 034 3280', Decimal('13659.12785038190'))
# ('01 036 2386', Decimal('11648.93973293600'))
# ('01 036 2438', Decimal('6584.71534933500'))
# ('01 036 5399', Decimal('7948.28105181800'))
# ('01 038 0026', Decimal('4321.69144346200'))
# ('01 038 1351', Decimal('14760.48023010620'))
# ('01 038 5176', Decimal('13811.25926186200'))
# ('01 038 6331', Decimal('883.49627330700'))
# ('01 039 0574', Decimal('14048.98470148420'))
# ('01 040 2094', Decimal('6128.88240582400'))
# ('01 040 5603', Decimal('15092.06980840400'))
# ('01 040 6754', Decimal('2424.13742541100'))
# ('01 040 7065', Decimal('12036.27816245000'))
# ('01 040 8055', Decimal('5954.70838381000'))
# ('01 041 0679', Decimal('18703.37295092800'))
# ('01 041 2527', Decimal('1761.69996975400'))
# ('01 041 8034', Decimal('1373.66610397500'))
# ('01 042 1549', Decimal('12663.60721432240'))
# ('01 042 4350', Decimal('1694.21688716500'))
# ('01 042 5622', Decimal('10411.54205268500'))
# ('01 042 9157', Decimal('5217.35417424700'))
# ('01 043 6513', Decimal('5427.38599715800'))
# ('01 044 2909', Decimal('7284.49309226760'))
# ('01 045 3778', Decimal('15728.41082925540'))
# ('01 045 9305', Decimal('5755.60875124140'))
# ('01 046 1809', Decimal('13019.59167620400'))
# ('01 046 2525', Decimal('248.17912137300'))
# ('01 046 7656', Decimal('9131.41102090000'))
# ('01 047 1637', Decimal('16409.74073523400'))
# ('01 047 6919', Decimal('13644.34804833940'))
# ('01 048 3321', Decimal('1272.52167738600'))
# ('01 049 3297', Decimal('7361.43945050300'))
# ('01 049 6783', Decimal('3430.65693076000'))
# ('01 049 9980', Decimal('13331.95812003400'))
# ('01 050 1589', Decimal('4288.39379798100'))
# ('01 050 9912', Decimal('4526.69783148900'))
# ('01 051 5064', Decimal('8196.02003847640'))
# ('01 051 6305', Decimal('12847.50145327440'))
# ('01 051 7089', Decimal('7238.29633254700'))
# ('01 052 8765', Decimal('4394.98976226300'))
# ('01 053 1264', Decimal('11530.46501750000'))
# ('01 054 1555', Decimal('12355.00667714900'))
# ('01 054 1611', Decimal('8684.91243480540'))
# ('01 055 3380', Decimal('3054.12438555320'))
# ('01 055 4064', Decimal('8988.78881234400'))
# ('01 056 4534', Decimal('3291.43378501800'))
# ('01 056 8501', Decimal('7569.38134865100'))
# ('01 057 1498', Decimal('8226.60151989300'))
# ('01 057 6955', Decimal('2193.31048044400'))
# ('01 058 1435', Decimal('2194.42478763500'))
# ('01 058 6889', Decimal('9949.90948132150'))
# ('01 059 1117', Decimal('4317.37891880970'))
# ('01 059 3596', Decimal('12523.06330715020'))
# ('01 059 8202', Decimal('2083.59154150800'))
# ('01 059 9597', Decimal('263.76389104100'))
# ('01 060 5603', Decimal('5400.10880419500'))
# ('01 060 6515', Decimal('3410.39968713900'))
# ('01 060 7849', Decimal('13450.37222500000'))
# ('01 061 2698', Decimal('4139.59440901000'))
# ('01 061 7312', Decimal('13398.84446851760'))
# ('01 062 1387', Decimal('8314.09807827000'))
# ('01 062 4505', Decimal('17414.75997369300'))
# ('01 062 6478', Decimal('2023.02070749700'))
# ('01 062 6717', Decimal('4548.09393736000'))
# ('01 062 7978', Decimal('12080.38044283800'))
# ('01 063 9249', Decimal('753.70819529000'))
# ('01 064 9939', Decimal('8365.44627669560'))
# ('01 065 9063', Decimal('7567.51077629200'))
# ('01 066 4390', Decimal('6285.81093156700'))
# ('01 067 7684', Decimal('16722.56244238082'))
# ('01 067 9625', Decimal('14010.59813011200'))
# ('01 068 3946', Decimal('9319.33705876900'))
# ('01 068 6894', Decimal('7172.94556146432'))
# ('01 071 1196', Decimal('2433.90034950300'))
# ('01 071 5324', Decimal('1271.28076855000'))
# ('01 071 7402', Decimal('10547.79044383600'))
# ('01 072 3292', Decimal('3627.87145683600'))
# ('01 072 5523', Decimal('779.69340103100'))
# ('01 073 3754', Decimal('5411.35438159630'))
# ('01 073 6007', Decimal('18776.31729115200'))
# ('01 074 4230', Decimal('1052.68686507500'))
# ('01 074 4857', Decimal('5063.09007361700'))
# ('01 075 2041', Decimal('7097.08947893400'))
# ('01 076 8087', Decimal('5876.21764421000'))
# ('01 077 5662', Decimal('2737.16507325100'))
# ('01 077 9376', Decimal('4264.85834883800'))
# ('01 078 3073', Decimal('10581.47644134108'))
# ('01 078 5248', Decimal('16615.58709364590'))
# ('01 078 7201', Decimal('4252.98169787500'))
# ('01 078 9022', Decimal('4299.12631458200'))
# ('01 079 7078', Decimal('3372.91993701300'))
# ('01 079 9635', Decimal('13064.87585073690'))
# ('01 080 0105', Decimal('4524.30825530200'))
# ('01 080 1036', Decimal('904.61787326400'))
# ('01 080 1220', Decimal('10075.71265387000'))
# ('01 080 3589', Decimal('3473.80780026300'))
# ('01 080 4058', Decimal('16284.95423553700'))
# ('01 080 5748', Decimal('10620.43362515000'))
# ('01 080 6020', Decimal('23402.35124478900'))
# ('01 080 6043', Decimal('933.10280334000'))
# ('01 080 8799', Decimal('15260.42292408200'))
# ('01 080 9502', Decimal('8028.19032903200'))
# ('01 080 9716', Decimal('5731.54484673200'))
# ('01 081 4561', Decimal('2133.31471865400'))
# ('01 081 4566', Decimal('4905.21546268200'))
# ('01 081 8458', Decimal('6268.56964988000'))
# ('01 081 9637', Decimal('4097.19802983800'))
# ('01 082 1105', Decimal('4731.34618863900'))
# ('01 082 4718', Decimal('1856.33891313900'))
# ('01 082 9004', Decimal('2735.79946747700'))
# ('01 083 0997', Decimal('135.77596037200'))
# ('01 085 0209', Decimal('7428.56978247900'))
# ('01 085 3475', Decimal('128.05384875400'))
# ('01 085 4787', Decimal('13591.52405721000'))
# ('01 085 9247', Decimal('11629.01105481600'))
# ('01 086 0400', Decimal('8305.93147239720'))
# ('01 086 7028', Decimal('2666.56440420400'))
# ('01 086 7661', Decimal('11331.38428688100'))
# ('01 087 6846', Decimal('16078.28080433260'))
# ('01 087 7025', Decimal('262.17679653200'))
# ('01 088 0475', Decimal('627.87540015200'))
# ('01 088 6093', Decimal('3560.24007151800'))
# ('01 088 6733', Decimal('4849.52779345000'))
# ('01 089 0549', Decimal('3742.83117768900'))
# ('01 089 6127', Decimal('5881.74989410300'))
# ('01 090 2350', Decimal('8797.11975955800'))
# ('01 090 3690', Decimal('1014.97258980200'))
# ('01 091 3191', Decimal('5014.77921604210'))
# ('01 091 4461', Decimal('1914.95350779200'))
# ('01 091 5387', Decimal('14199.71646529900'))
# ('01 091 9901', Decimal('10538.78724042220'))
# ('01 093 0318', Decimal('16543.88622587600'))
# ('01 093 3659', Decimal('5056.54613702100'))
# ('01 093 5026', Decimal('3382.37277751500'))
# ('01 094 2631', Decimal('12375.21111391300'))
# ('01 094 7572', Decimal('20484.26009440000'))
# ('01 095 5179', Decimal('14872.15159918400'))
# ('01 095 6183', Decimal('14212.79669895600'))
# ('01 095 7173', Decimal('5938.21932902400'))
# ('01 096 1539', Decimal('15517.87909175800'))
# ('01 097 9221', Decimal('15116.19869633010'))
# ('01 098 4438', Decimal('4510.95102824200'))
# ('01 098 8776', Decimal('5991.94105309840'))
# ('01 099 0689', Decimal('9024.61893757960'))
# ('01 099 1853', Decimal('2135.24596486500'))
# ('01 099 5443', Decimal('4889.39922665000'))
# ('01 099 6113', Decimal('5762.31653284100'))
# ('01 099 8585', Decimal('1768.71884617100'))
# ('01 100 3828', Decimal('4970.55474327700'))
# ('01 100 4959', Decimal('9353.57429563490'))
# ('01 100 5312', Decimal('5122.02527077300'))
# ('01 100 6767', Decimal('8211.69738983000'))
# ('01 101 0122', Decimal('6172.09748497700'))
# ('01 101 4205', Decimal('5062.94383729900'))
# ('01 101 5266', Decimal('2318.61685664800'))
# ('01 101 5451', Decimal('9152.82544328000'))
# ('01 101 7036', Decimal('4659.58031607700'))
# ('01 102 3250', Decimal('15856.33432363900'))
# ('01 102 5743', Decimal('14489.23792398400'))
# ('01 103 5669', Decimal('2119.72197958800'))
# ('01 103 8315', Decimal('4054.46457544800'))
# ('01 104 0513', Decimal('2183.86169523900'))
# ('01 104 0620', Decimal('7090.68111611500'))
# ('01 104 2635', Decimal('20470.50042750400'))
# ('01 104 4540', Decimal('5653.26046670700'))
# ('01 104 7507', Decimal('13542.42186942300'))
# ('01 104 8816', Decimal('1662.33832681800'))
# ('01 105 1378', Decimal('4808.18130490700'))
# ('01 105 2419', Decimal('13219.17758053600'))
# ('01 106 0144', Decimal('4425.00230818100'))
# ('01 106 0847', Decimal('14268.04836585800'))
# ('01 106 2284', Decimal('14105.66623028300'))
# ('01 106 9634', Decimal('7711.93693303300'))
# ('01 107 0324', Decimal('16390.54266486400'))
# ('01 108 0021', Decimal('12022.24390121100'))
# ('01 108 0816', Decimal('14982.85735059700'))
# ('01 108 2515', Decimal('2253.24415778800'))
# ('01 109 0966', Decimal('508.37808291900'))
# ('01 109 2515', Decimal('3303.82924860000'))
# ('01 109 6735', Decimal('7066.69252681600'))
# ('01 109 6982', Decimal('5481.90251790300'))
# ('01 109 8748', Decimal('10613.45758423800'))
# ('01 110 0724', Decimal('6312.30701005400'))
# ('01 110 4632', Decimal('13086.67456904060'))
# ('01 110 6536', Decimal('2487.41261664600'))
# ('01 110 8390', Decimal('546.93279654000'))
# ('01 110 8839', Decimal('17146.38621246200'))
# ('01 110 9700', Decimal('1288.96114168900'))
# ('01 111 0448', Decimal('10599.57369015180'))
# ('01 112 1838', Decimal('15576.14809854000'))
# ('01 112 6336', Decimal('3665.37885900500'))
# ('01 113 3918', Decimal('18663.99591631850'))
# ('01 113 4041', Decimal('2212.32169765900'))
# ('01 113 9048', Decimal('8392.37271269700'))
# ('01 114 2425', Decimal('16258.53356374100'))
# ('01 114 8854', Decimal('6748.42158817500'))
# ('01 115 0744', Decimal('13759.70957524740'))
# ('01 115 5361', Decimal('10850.76462405500'))
# ('01 115 6043', Decimal('2664.31287483880'))
# ('01 115 8888', Decimal('4276.36152112000'))
# ('01 116 2405', Decimal('3133.50924887100'))
# ('01 116 2490', Decimal('4443.49943885700'))
# ('01 116 7820', Decimal('8242.48011122560'))
# ('01 116 7986', Decimal('14195.13185823870'))
# ('01 117 1364', Decimal('1801.41178854300'))
# ('01 117 4702', Decimal('4826.12420271000'))
# ('01 117 5538', Decimal('8835.97104430700'))
# ('01 117 6176', Decimal('8915.58787099900'))
# ('01 117 7199', Decimal('4069.36458940100'))
# ('01 118 3666', Decimal('14144.43780098650'))
# ('01 118 3689', Decimal('51.75325017000'))
# ('01 118 4164', Decimal('10348.38027249646'))
# ('01 118 7246', Decimal('6001.64588897300'))
# ('01 118 9489', Decimal('16238.29790612900'))
# ('01 118 9715', Decimal('7746.24248793700'))
# ('01 119 4349', Decimal('1753.19146066200'))
# ('01 119 5352', Decimal('14495.80632441330'))
# ('01 119 9126', Decimal('1080.81215569400'))
# ('01 120 0757', Decimal('9874.24065853760'))
# ('01 120 0772', Decimal('2054.97400425900'))
# ('01 120 7794', Decimal('5319.25521282800'))
# ('01 120 9576', Decimal('5475.16381794042'))
# ('01 121 3013', Decimal('2186.44563457700'))
# ('01 121 4075', Decimal('22447.82215915060'))
# ('01 121 8920', Decimal('5488.77526479200'))
# ('01 121 9246', Decimal('69.44223979800'))
# ('01 122 5643', Decimal('7649.21596786670'))
# ('01 122 8155', Decimal('7800.61957954220'))
# ('01 122 8982', Decimal('12352.56465841970'))
# ('01 123 3207', Decimal('11890.27690527100'))
# ('01 123 4401', Decimal('3234.94595267300'))
# ('01 123 6751', Decimal('17999.81435457710'))
# ('01 123 9294', Decimal('12127.35127716200'))
# ('01 124 1137', Decimal('5953.32782355800'))
# ('01 124 8133', Decimal('303.65128596400'))
# ('01 125 4223', Decimal('5173.56671118020'))
# ('01 125 4831', Decimal('6448.58531652800'))
# ('01 125 6352', Decimal('3989.55076591200'))
# ('01 125 7323', Decimal('12393.11028678900'))
# ('01 126 5554', Decimal('5241.70570963100'))
# ('01 127 6482', Decimal('8261.93087600700'))
# ('01 127 9548', Decimal('19475.66763774100'))
# ('01 129 5428', Decimal('10772.41307437200'))
# ('01 129 5848', Decimal('15209.80846454510'))
# ('01 129 7514', Decimal('7366.62200927100'))
# ('01 130 6190', Decimal('15416.38535698650'))
# ('01 130 6495', Decimal('12334.61964290400'))
# ('01 131 1010', Decimal('7076.32938721500'))
# ('01 131 2670', Decimal('14996.61775308460'))
# ('01 131 3929', Decimal('14178.55178780800'))
# ('01 131 7338', Decimal('1459.20664229600'))
# ('01 132 1436', Decimal('5648.57604282500'))
# ('01 132 1904', Decimal('1969.08348656400'))
# ('01 132 5695', Decimal('2900.01258439700'))
# ('01 132 8893', Decimal('2812.33110845600'))
# ('01 133 1507', Decimal('9136.91696172940'))
# ('01 134 7272', Decimal('2406.94774477200'))
# ('01 135 1366', Decimal('2378.50033450700'))
# ('01 135 1423', Decimal('3011.50421845600'))
# ('01 136 7321', Decimal('4095.74468538700'))
# ('01 137 1576', Decimal('7504.81848763600'))
# ('01 137 5238', Decimal('4722.56974344200'))
# ('01 137 5885', Decimal('3130.71197706700'))
# ('01 137 7256', Decimal('20940.92215577200'))
# ('01 138 0205', Decimal('3629.00241233800'))
# ('01 139 2949', Decimal('7405.08436831300'))
# ('01 140 5404', Decimal('9720.88991802400'))
# ('01 140 8199', Decimal('2853.58961833510'))
# ('01 141 0080', Decimal('4514.85089900100'))
# ('01 141 0504', Decimal('7827.95648716300'))
# ('01 142 3394', Decimal('12825.79820275200'))
# ('01 142 3409', Decimal('6502.97323015900'))
# ('01 143 1824', Decimal('7482.34693732000'))
# ('01 143 6965', Decimal('1746.46723794200'))
# ('01 143 8073', Decimal('15553.29040379760'))
# ('01 144 3410', Decimal('15836.88081510700'))
# ('01 144 6368', Decimal('1182.03602834100'))
# ('01 144 8110', Decimal('1006.54063972130'))
# ('01 146 4477', Decimal('17606.36909719000'))
# ('01 147 1997', Decimal('10979.99828421100'))
# ('01 147 4551', Decimal('5318.05940906000'))
# ('01 147 9607', Decimal('15045.71789933700'))
# ('01 148 3325', Decimal('15232.88249391820'))
# ('01 148 3612', Decimal('3137.27701183400'))
# ('01 148 5574', Decimal('3018.09421589990'))
# ('01 148 6430', Decimal('1784.80776442300'))
# ('01 149 9236', Decimal('4783.85624813830'))
# ('01 149 9413', Decimal('3896.44322931100'))
# ('01 150 1632', Decimal('3704.34197999400'))
# ('01 150 1673', Decimal('1573.09524284000'))
# ('01 150 3230', Decimal('15577.75391598000'))
# ('01 150 4389', Decimal('699.45631277700'))
# ('01 150 5142', Decimal('7365.61763656200'))
# ('01 151 0818', Decimal('6656.59134951100'))
# ('01 151 0845', Decimal('16267.92639109404'))
# ('01 151 2521', Decimal('4622.55736859000'))
# ('01 151 2782', Decimal('7263.76603577700'))
# ('01 151 6551', Decimal('7349.14035598000'))
# ('01 151 6643', Decimal('13296.26034053774'))
# ('01 152 3397', Decimal('6882.30697100600'))
# ('01 153 7935', Decimal('12666.97880940100'))
# ('01 153 8674', Decimal('4860.86315823200'))
# ('01 154 7337', Decimal('17249.15724329690'))
# ('01 156 4753', Decimal('16.12833778500'))
# ('01 156 5486', Decimal('8190.88405033597'))
# ('01 156 7305', Decimal('16298.41449998960'))
# ('01 156 8421', Decimal('15754.84508440800'))
# ('01 156 9548', Decimal('3768.72669826300'))
# ('01 157 0608', Decimal('6173.08059974800'))
# ('01 157 9991', Decimal('9576.00727539100'))
# ('01 158 6402', Decimal('2060.44698136500'))
# ('01 158 7062', Decimal('7547.06664723400'))
# ('01 158 7833', Decimal('1871.28520312100'))
# ('01 158 8895', Decimal('3492.39166180700'))
# ('01 158 9429', Decimal('12228.39282872400'))
# ('01 159 0347', Decimal('14306.83837278080'))
# ('01 159 0855', Decimal('8808.98092499800'))
# ('01 159 8591', Decimal('2239.93438883900'))
# ('01 160 2803', Decimal('106.51815267600'))
# ('01 160 4028', Decimal('12109.18190962680'))
# ('01 160 8117', Decimal('4911.26217423900'))
# ('01 161 8741', Decimal('10603.93362027000'))
# ('01 162 0261', Decimal('11621.34558522700'))
# ('01 162 5934', Decimal('6546.80155107880'))
# ('01 163 3058', Decimal('6338.66870198900'))
# ('01 165 0885', Decimal('4923.10361554800'))
# ('01 166 0928', Decimal('7357.05443668000'))
# ('01 166 6119', Decimal('9915.58621717200'))
# ('01 166 6140', Decimal('2340.41045786600'))
# ('01 166 6768', Decimal('531.09311196900'))
# ('01 167 1683', Decimal('5131.70783089500'))
# ('01 167 7379', Decimal('8745.33376732600'))
# ('01 168 0445', Decimal('3333.12010225900'))
# ('01 168 3717', Decimal('18047.80345377900'))
# ('01 168 9604', Decimal('10635.25842815500'))
# ('01 169 2437', Decimal('12723.48937702100'))
# ('01 170 1428', Decimal('2799.19594260600'))
# ('01 170 8358', Decimal('2485.07998272000'))
# ('01 171 0815', Decimal('5053.86267451600'))
# ('01 171 1252', Decimal('3511.00805830140'))
# ('01 171 1438', Decimal('2630.24984336400'))
# ('01 171 5319', Decimal('7000.53533905240'))
# ('01 172 0308', Decimal('10401.08562234600'))
# ('01 172 6812', Decimal('6329.35949222500'))
# ('01 172 7725', Decimal('8092.95804153100'))
# ('01 173 0215', Decimal('10434.96314152600'))
# ('01 173 1780', Decimal('13763.40025060900'))
# ('01 173 2196', Decimal('9843.36326053220'))
# ('01 173 3215', Decimal('966.05379814100'))
# ('01 173 5928', Decimal('10475.71762941300'))
# ('01 173 7904', Decimal('8480.59266539400'))
# ('01 174 2362', Decimal('2406.88804312900'))
# ('01 174 4997', Decimal('2874.70820227400'))
# ('01 174 6137', Decimal('2443.99111392200'))
# ('01 175 2891', Decimal('7854.65681568200'))
# ('01 175 5988', Decimal('10632.76853808300'))
# ('01 175 6813', Decimal('16836.91675955700'))
# ('01 175 7126', Decimal('3336.44805255200'))
# ('01 176 7457', Decimal('6296.68398906200'))
# ('01 177 0952', Decimal('1032.40069720000'))
# ('01 177 4165', Decimal('1368.54456081100'))
# ('01 177 4863', Decimal('5649.95431334000'))
# ('01 178 6757', Decimal('2613.37056781300'))
# ('01 180 3115', Decimal('10841.47044625560'))
# ('01 180 4661', Decimal('1543.52936259100'))
# ('01 180 9556', Decimal('5707.32398184500'))
# ('01 181 1680', Decimal('3562.03356622500'))
# ('01 181 6124', Decimal('8934.20424538190'))
# ('01 182 3297', Decimal('8395.56545398400'))
# ('01 182 4112', Decimal('14992.46895244900'))
# ('01 183 2755', Decimal('10878.40943653800'))
# ('01 183 3850', Decimal('5612.81375718900'))
# ('01 183 9718', Decimal('2038.39662504200'))
# ('01 184 0672', Decimal('6331.95577877400'))
# ('01 185 2943', Decimal('12428.77511179000'))
# ('01 185 4094', Decimal('4770.00443399100'))
# ('01 185 8476', Decimal('4741.44561840300'))
# ('01 186 4068', Decimal('18008.49909412800'))
# ('01 187 1140', Decimal('14534.00917735500'))
# ('01 187 3845', Decimal('18234.13545177780'))
# ('01 187 4164', Decimal('9299.61765851000'))
# ('01 187 7119', Decimal('1759.46007783500'))
# ('01 188 1642', Decimal('1377.74091869500'))
# ('01 188 1943', Decimal('2175.79896424500'))
# ('01 188 8208', Decimal('11282.83946109530'))
# ('01 189 7404', Decimal('5107.08003161300'))
# ('01 189 8206', Decimal('15027.13047063300'))
# ('01 190 2516', Decimal('1021.99512642400'))
# ('01 190 4183', Decimal('2009.90846610300'))
# ('01 190 8424', Decimal('9906.20536001100'))
# ('01 190 9802', Decimal('9772.54601217400'))
# ('01 191 2566', Decimal('6172.58500129100'))
# ('01 191 4804', Decimal('11023.51534141900'))
# ('01 191 9303', Decimal('8261.29079555800'))
# ('01 192 3852', Decimal('7846.28443357440'))
# ('01 192 6771', Decimal('2556.01343175300'))
# ('01 192 7529', Decimal('6856.88284208600'))
# ('01 192 7626', Decimal('881.38550818900'))
# ('01 194 3068', Decimal('1845.85801624200'))
# ('01 194 5162', Decimal('11699.55734797040'))
# ('01 194 5183', Decimal('21238.82147511940'))
# ('01 194 6183', Decimal('13439.11312900340'))
# ('01 194 8039', Decimal('4617.59305540980'))
# ('01 195 0468', Decimal('12594.01791412000'))
# ('01 195 3899', Decimal('1805.52756281300'))
# ('01 195 4785', Decimal('20164.84148448680'))
# ('01 195 5842', Decimal('17158.80135357900'))
# ('01 195 7265', Decimal('1981.64545383000'))
# ('01 196 5075', Decimal('2589.19067335800'))
# ('01 196 7964', Decimal('2716.65966715300'))
# ('01 197 0761', Decimal('1267.35000181000'))
# ('01 197 1057', Decimal('1122.34159198000'))
# ('01 197 7672', Decimal('442.66284779200'))
# ('01 197 8891', Decimal('1688.31260491800'))
# ('01 198 0288', Decimal('14861.23160564300'))
# ('01 198 0950', Decimal('10171.25468225500'))
# ('01 198 3417', Decimal('3114.67126050900'))
# ('01 198 5897', Decimal('546.65453775600'))
# ('01 199 1016', Decimal('15348.40914828780'))
# ('01 199 6268', Decimal('726.76990958000'))
# ('01 200 0011', Decimal('1705.86526019500'))
# ('01 200 1319', Decimal('5139.80751516400'))
# ('01 201 2567', Decimal('5916.09564295300'))
# ('01 201 2682', Decimal('6636.95332248400'))
# ('01 201 5556', Decimal('18644.57288052850'))
# ('01 201 6093', Decimal('7669.04641519200'))
# ('01 201 6140', Decimal('3292.38569361600'))
# ('01 202 0237', Decimal('1477.49260403000'))
# ('01 202 0353', Decimal('3032.29444544600'))
# ('01 202 0384', Decimal('8791.45690889500'))
# ('01 202 2201', Decimal('14900.14790108212'))
# ('01 202 6439', Decimal('1048.05464229200'))
# ('01 203 2213', Decimal('5391.49315035000'))
# ('01 203 2991', Decimal('1973.11792655800'))
# ('01 203 4015', Decimal('4585.82972585400'))
# ('01 203 9468', Decimal('7194.25821486700'))
# ('01 204 5594', Decimal('9230.75361871940'))
# ('01 205 2242', Decimal('7903.11046557200'))
# ('01 205 7529', Decimal('5122.04913587900'))
# ('01 205 8305', Decimal('17325.35957989400'))
# ('01 205 9689', Decimal('311.84848666800'))
# ('01 205 9705', Decimal('2093.11877372100'))
# ('01 206 4995', Decimal('17123.15867548100'))
# ('01 206 7443', Decimal('7729.77832710000'))
# ('01 207 7024', Decimal('14755.65767137700'))
# ('01 208 1902', Decimal('7782.13875036700'))
# ('01 208 3579', Decimal('5877.78899677900'))
# ('01 208 4478', Decimal('10340.97937872800'))
# ('01 208 6879', Decimal('4845.24742416000'))
# ('01 209 0819', Decimal('10253.41985914760'))
# ('01 209 1612', Decimal('11936.87861255920'))
# ('01 209 5912', Decimal('2689.27001046300'))
# ('01 211 3425', Decimal('19125.72560525800'))
# ('01 211 5140', Decimal('13644.32931511500'))
# ('01 211 6541', Decimal('17072.37758945520'))
# ('01 211 7104', Decimal('9574.64696366500'))
# ('01 212 0290', Decimal('1153.17313821500'))
# ('01 212 4291', Decimal('15983.89016391980'))
# ('01 212 9923', Decimal('8626.03542645700'))
# ('01 213 2476', Decimal('5401.62433633000'))
# ('01 213 3660', Decimal('4882.30962935200'))
# ('01 213 8819', Decimal('14592.53064333400'))
# ('01 214 0664', Decimal('10369.45475298860'))
# ('01 214 1610', Decimal('16557.46253925100'))
# ('01 214 8720', Decimal('11359.87434486160'))
# ('01 215 4902', Decimal('7113.82603138320'))
# ('01 215 5448', Decimal('15944.99744001000'))
# ('01 215 7116', Decimal('3277.27171342800'))
# ('01 216 0513', Decimal('16670.12407849100'))
# ('01 216 6453', Decimal('17668.74457888500'))
# ('01 217 5335', Decimal('13427.17861227400'))
# ('01 217 5877', Decimal('354.15681730000'))
# ('01 217 7550', Decimal('10560.85556652000'))
# ('01 217 8310', Decimal('14267.29909482780'))
# ('01 218 0890', Decimal('3532.31801006900'))
# ('01 218 6927', Decimal('2131.99372815200'))
# ('01 219 0775', Decimal('974.06051265800'))
# ('01 219 2711', Decimal('978.98672105600'))
# ('01 219 5055', Decimal('7208.78554388400'))
# ('01 219 6067', Decimal('9325.24819356860'))
# ('01 219 6215', Decimal('9716.51233466600'))
# ('01 220 2580', Decimal('14584.69988305400'))
# ('01 220 2663', Decimal('19072.82254144900'))
# ('01 220 9415', Decimal('9342.26405099100'))
# ('01 221 5212', Decimal('2090.17316957500'))
# ('01 221 5448', Decimal('2551.21572137258'))
# ('01 221 8813', Decimal('5073.16404434200'))
# ('01 222 3669', Decimal('2176.70655777200'))
# ('01 222 6311', Decimal('5054.49671832300'))
# ('01 222 7701', Decimal('6247.32801511300'))
# ('01 223 0244', Decimal('17377.09998472770'))
# ('01 224 0455', Decimal('5753.08259851500'))
# ('01 224 3963', Decimal('5977.85709754400'))
# ('01 225 6098', Decimal('16137.09943763300'))
# ('01 225 8073', Decimal('2984.64720165000'))
# ('01 226 2628', Decimal('12909.32754019850'))
# ('01 227 5263', Decimal('9175.83061323400'))
# ('01 227 9959', Decimal('13694.55131878500'))
# ('01 228 4949', Decimal('1078.08959541800'))
# ('01 228 9332', Decimal('9229.06198095200'))
# ('01 229 0394', Decimal('14619.25600287300'))
# ('01 229 1458', Decimal('13994.37256988000'))
# ('01 229 4703', Decimal('12262.70777033900'))
# ('01 229 8743', Decimal('11660.05838324800'))
# ('01 230 1940', Decimal('3417.29505620500'))
# ('01 230 2501', Decimal('4612.70096119200'))
# ('01 230 6971', Decimal('11740.08926463100'))
# ('01 230 9103', Decimal('8699.93461493480'))
# ('01 233 3287', Decimal('6211.52850314500'))
# ('01 233 8555', Decimal('14171.25129922560'))
# ('01 234 3803', Decimal('8180.96215825700'))
# ('01 234 4184', Decimal('15516.31679441660'))
# ('01 234 6120', Decimal('8842.76198908680'))
# ('01 235 0067', Decimal('14286.46896402000'))
# ('01 235 1869', Decimal('2507.56201443000'))
# ('01 235 3224', Decimal('10190.27626551800'))
# ('01 235 4880', Decimal('2694.64165704800'))
# ('01 235 7430', Decimal('932.72803818200'))
# ('01 236 0519', Decimal('6225.45563022600'))
# ('01 236 6210', Decimal('3907.27903226400'))
# ('01 237 1047', Decimal('4230.18256747900'))
# ('01 237 9710', Decimal('9116.68819186200'))
# ('01 238 4133', Decimal('8966.37852730000'))
# ('01 238 8586', Decimal('11877.59641714500'))
# ('01 240 1383', Decimal('1713.29962369600'))
# ('01 240 4133', Decimal('11435.23431235200'))
# ('01 240 4690', Decimal('8299.13701145200'))
# ('01 240 5578', Decimal('2254.68865591500'))
# ('01 241 0489', Decimal('9613.60219801700'))
# ('01 241 9382', Decimal('2573.51469552300'))
# ('01 243 4778', Decimal('16833.91108762000'))
# ('01 243 5948', Decimal('5563.29844731300'))
# ('01 243 6450', Decimal('3430.04543048800'))
# ('01 244 2454', Decimal('14135.91269697200'))
# ('01 244 2646', Decimal('1637.52435138300'))
# ('01 244 2658', Decimal('11882.07113661740'))
# ('01 244 7105', Decimal('1307.79606811400'))
# ('01 244 7361', Decimal('7019.59427539800'))
# ('01 244 8806', Decimal('9495.60339802600'))
# ('01 245 5697', Decimal('18204.98378928030'))
# ('01 245 9534', Decimal('10320.29074899300'))
# ('01 246 5159', Decimal('2814.62404960600'))
# ('01 247 6613', Decimal('22370.05652639100'))
# ('01 247 8370', Decimal('10029.55778633900'))
# ('01 249 1090', Decimal('26.42490685800'))
# ('01 249 1448', Decimal('3009.12975437080'))
# ('01 249 7746', Decimal('13231.89515292000'))
# ('01 250 3124', Decimal('16269.34749278240'))
# ('01 250 7386', Decimal('2944.54901869200'))
# ('01 250 9855', Decimal('12961.51159347300'))
# ('01 251 6227', Decimal('13886.23982694000'))
# ('01 251 9007', Decimal('6718.21207982300'))
# ('01 252 0685', Decimal('1088.39580861300'))
# ('01 252 2830', Decimal('2983.36018218700'))
# ('01 252 3527', Decimal('7272.17799185700'))
# ('01 253 6046', Decimal('10359.72865563200'))
# ('01 253 6161', Decimal('4114.99577989000'))
# ('01 253 7761', Decimal('3684.36161790000'))
# ('01 253 9964', Decimal('732.56213774100'))
# ('01 254 8971', Decimal('15740.97512574760'))
# ('01 255 0256', Decimal('4352.09060201800'))
# ('01 255 8668', Decimal('3813.33091632800'))
# ('01 256 4296', Decimal('21425.34397622200'))
# ('01 256 4498', Decimal('6738.70468341400'))
# ('01 256 5219', Decimal('1192.33204201000'))
# ('01 257 0056', Decimal('665.85304657200'))
# ('01 257 2235', Decimal('9648.09266848100'))
# ('01 257 8466', Decimal('3032.64571022100'))
# ('01 258 0694', Decimal('9893.33152221300'))
# ('01 258 4533', Decimal('15798.15561171600'))
# ('01 258 8772', Decimal('7525.32865470600'))
# ('01 259 1137', Decimal('11111.54445041670'))
# ('01 259 8086', Decimal('6254.57371674200'))
# ('01 259 8095', Decimal('2546.94345564100'))
# ('01 259 9107', Decimal('509.70337803500'))
# ('01 260 0073', Decimal('17903.83765179280'))
# ('01 260 1450', Decimal('12449.17149893240'))
# ('01 260 4797', Decimal('3753.93961749000'))
# ('01 262 0194', Decimal('2947.97903606000'))
# ('01 262 2672', Decimal('7937.60199717900'))
# ('01 263 9539', Decimal('9357.88274903200'))
# ('01 264 0352', Decimal('1186.91238809700'))
# ('01 264 0835', Decimal('8553.92194572400'))
# ('01 264 6566', Decimal('12427.55153109500'))
# ('01 265 3934', Decimal('11255.93895038470'))
# ('01 266 2396', Decimal('3296.94861199800'))
# ('01 266 4464', Decimal('12157.08389273200'))
# ('01 266 4579', Decimal('1553.98326228000'))
# ('01 267 1304', Decimal('896.95906401000'))
# ('01 267 3722', Decimal('4769.79886627800'))
# ('01 267 4419', Decimal('4424.65018502100'))
# ('01 268 7140', Decimal('12197.13956649900'))
# ('01 269 4612', Decimal('1340.15991817800'))
# ('01 271 8206', Decimal('4098.44283642800'))
# ('01 272 2488', Decimal('5586.64683138500'))
# ('01 272 5419', Decimal('13510.02631226200'))
# ('01 273 0693', Decimal('3495.86121598700'))
# ('01 274 2699', Decimal('10356.30351428400'))
# ('01 274 3705', Decimal('13734.21226980900'))
# ('01 274 6134', Decimal('3291.09174350900'))
# ('01 275 3512', Decimal('15564.39311894800'))
# ('01 276 4663', Decimal('11105.33191386460'))
# ('01 276 6266', Decimal('8740.49782127750'))
# ('01 277 0570', Decimal('4702.64965721800'))
# ('01 277 1936', Decimal('14566.79111044100'))
# ('01 277 2115', Decimal('4838.82109697720'))
# ('01 277 7508', Decimal('1526.07935266700'))
# ('01 277 7885', Decimal('4169.50405615600'))
# ('01 278 2534', Decimal('11545.31087900800'))
# ('01 278 3857', Decimal('4990.04715424000'))
# ('01 278 3982', Decimal('3579.03063125200'))
# ('01 280 2299', Decimal('6849.25085630100'))
# ('01 281 2777', Decimal('11477.81269760200'))
# ('01 281 6998', Decimal('16298.18618693800'))
# ('01 281 7096', Decimal('80.74703074900'))
# ('01 283 0288', Decimal('8006.19000644100'))
# ('01 283 0942', Decimal('8779.38889504600'))
# ('01 283 2624', Decimal('20736.78531485360'))
# ('01 283 4158', Decimal('16211.16285624600'))
# ('01 284 7237', Decimal('7697.00484503200'))
# ('01 285 2072', Decimal('12621.20416370400'))
# ('01 285 9869', Decimal('2636.88976219200'))
# ('01 286 0082', Decimal('10316.19570865060'))
# ('01 287 2765', Decimal('14532.79749782230'))
# ('01 287 3546', Decimal('581.68900936200'))
# ('01 287 4571', Decimal('11968.51342322400'))
# ('01 287 5228', Decimal('4784.09609970900'))
# ('01 287 9205', Decimal('5450.94463254500'))
# ('01 288 1641', Decimal('2384.11748626900'))
# ('01 288 6732', Decimal('8170.14682841800'))
# ('01 288 8606', Decimal('284.58922336000'))
# ('01 288 9973', Decimal('6783.30400471700'))
# ('01 289 3129', Decimal('9138.48752008200'))
# ('01 289 3470', Decimal('3748.03916319300'))
# ('01 289 3801', Decimal('1862.71846725100'))
# ('01 289 4619', Decimal('16572.34786425140'))
# ('01 289 6490', Decimal('7536.45460707180'))
# ('01 289 6679', Decimal('2306.39800237400'))
# ('01 291 6924', Decimal('3091.04337467700'))
# ('01 293 3849', Decimal('14404.01294685210'))
# ('01 293 5985', Decimal('12346.05695452300'))
# ('01 293 8480', Decimal('8322.78721417500'))
# ('01 294 0960', Decimal('5387.84739842200'))
# ('01 295 1672', Decimal('1838.23482288300'))
# ('01 296 1866', Decimal('679.77277369300'))
# ('01 296 4602', Decimal('7895.35545305600'))
# ('01 297 2895', Decimal('4542.94161392900'))
# ('01 297 5159', Decimal('12247.30430332000'))
# ('01 298 4326', Decimal('1544.77795145800'))
# ('01 298 7495', Decimal('12637.54066323400'))
# ('01 298 8674', Decimal('7868.88479746400'))
# ('01 299 1968', Decimal('8784.10402572900'))
# ('01 299 4078', Decimal('1998.41414356100'))
# ('01 299 6910', Decimal('14596.80213412940'))
# ('01 300 0457', Decimal('8939.90312027800'))
# ('01 300 3300', Decimal('6844.56030408400'))
# ('01 300 4808', Decimal('16856.13339890700'))
# ('01 301 5814', Decimal('2384.00177310600'))
# ('01 301 8491', Decimal('15409.99181981660'))
# ('01 302 5938', Decimal('6431.86184240410'))
# ('01 303 2429', Decimal('4210.57616064300'))
# ('01 303 4393', Decimal('2536.60452863100'))
# ('01 303 6077', Decimal('6481.74925550100'))
# ('01 303 6093', Decimal('1392.12811287700'))
# ('01 303 6152', Decimal('2481.95438716300'))
# ('01 304 0309', Decimal('8967.12987207050'))
# ('01 304 0401', Decimal('1095.94391652100'))
# ('01 304 1114', Decimal('7058.92780604100'))
# ('01 304 8897', Decimal('3207.84194318170'))
# ('01 305 0448', Decimal('1520.57458700800'))
# ('01 305 1589', Decimal('19076.93409617000'))
# ('01 305 9725', Decimal('10339.20015813100'))
# ('01 306 4064', Decimal('5710.62892167800'))
# ('01 306 9805', Decimal('3360.78242918400'))
# ('01 307 2572', Decimal('3628.04089460900'))
# ('01 308 6438', Decimal('3644.81998139600'))
# ('01 308 6854', Decimal('6964.65275785900'))
# ('01 308 7002', Decimal('1298.97773195700'))
# ('01 308 8054', Decimal('6753.10214372460'))
# ('01 308 8092', Decimal('9871.98073524820'))
# ('01 309 6489', Decimal('2097.54050581100'))
# ('01 309 8936', Decimal('6650.84124072300'))
# ('01 310 7654', Decimal('12023.01516079440'))
# ('01 310 9309', Decimal('1438.86245418100'))
# ('01 311 2568', Decimal('886.68890961000'))
# ('01 311 3058', Decimal('2036.52227717000'))
# ('01 311 3525', Decimal('1708.82384359200'))
# ('01 311 4869', Decimal('1998.17572298370'))
# ('01 312 2399', Decimal('9752.98600416780'))
# ('01 314 4643', Decimal('7641.69514169280'))
# ('01 314 6617', Decimal('5058.57917001200'))
# ('01 314 8156', Decimal('1657.72211578900'))
# ('01 315 3292', Decimal('3976.38817219000'))
# ('01 315 7585', Decimal('12966.27723720500'))
# ('01 316 0833', Decimal('4622.76180642400'))
# ('01 316 6215', Decimal('3510.22455354400'))
# ('01 317 8196', Decimal('8925.58382309900'))
# ('01 318 7069', Decimal('11146.40327630640'))
# ('01 319 0829', Decimal('19282.25314400300'))
# ('01 319 1303', Decimal('6255.32135614300'))
# ('01 319 4823', Decimal('549.21975296820'))
# ('01 319 6933', Decimal('5878.80920653000'))
# ('01 320 1786', Decimal('14760.92990638100'))
# ('01 321 3899', Decimal('2990.08477422600'))
# ('01 321 4390', Decimal('1966.75918537160'))
# ('01 321 6436', Decimal('2594.72192464180'))
# ('01 321 7383', Decimal('11161.97281704400'))
# ('01 323 8791', Decimal('7371.45705907940'))
# ('01 324 0817', Decimal('5745.68990191090'))
# ('01 324 5584', Decimal('13518.25466248000'))
# ('01 324 5696', Decimal('1852.09273514400'))
# ('01 325 0109', Decimal('6171.36022893540'))
# ('01 325 1775', Decimal('3418.14435422700'))
# ('01 325 8421', Decimal('12047.10189534900'))
# ('01 326 5286', Decimal('9769.05676133900'))
# ('01 326 6357', Decimal('5706.52794818100'))
# ('01 326 7310', Decimal('14962.40180852000'))
# ('01 327 5955', Decimal('13109.46072733784'))
# ('01 327 6328', Decimal('2971.87063968200'))
# ('01 329 0155', Decimal('7493.19094465500'))
# ('01 329 4094', Decimal('3407.32151673800'))
# ('01 330 0461', Decimal('1933.99560898900'))
# ('01 330 1116', Decimal('850.27446333600'))
# ('01 331 6608', Decimal('5883.65392013440'))
# ('01 331 9525', Decimal('2578.21983879700'))
# ('01 332 1323', Decimal('9991.81723303600'))
# ('01 332 1932', Decimal('3355.14763544400'))
# ('01 333 4589', Decimal('8427.41420766680'))
# ('01 333 8811', Decimal('12088.29683360200'))
# ('01 334 3142', Decimal('908.43408316600'))
# ('01 334 6424', Decimal('10340.68497844100'))
# ('01 335 0016', Decimal('5009.83681065500'))
# ('01 335 3834', Decimal('21177.31724480960'))
# ('01 335 7604', Decimal('3795.86872811200'))
# ('01 336 1609', Decimal('4327.02916559400'))
# ('01 336 5304', Decimal('13154.34161998200'))
# ('01 337 5581', Decimal('9236.07609927080'))
# ('01 337 6789', Decimal('1528.68776269900'))
# ('01 337 7213', Decimal('6845.90409692600'))
# ('01 338 5977', Decimal('1421.92081740000'))
# ('01 339 0509', Decimal('2757.69129406400'))
# ('01 339 1321', Decimal('13310.21978562100'))
# ('01 339 8768', Decimal('8509.75136331160'))
# ('01 339 8827', Decimal('13024.82215224500'))
# ('01 340 1043', Decimal('842.42712452400'))
# ('01 341 0777', Decimal('3889.00834603900'))
# ('01 342 4426', Decimal('12127.79165557300'))
# ('01 342 4684', Decimal('12588.09514060010'))
# ('01 342 9711', Decimal('16233.71822064900'))
# ('01 343 0866', Decimal('12868.50625475800'))
# ('01 343 0941', Decimal('13476.54559391970'))
# ('01 343 2849', Decimal('232.28086889800'))
# ('01 343 6935', Decimal('1747.66742420200'))
# ('01 343 8505', Decimal('5308.56481998500'))
# ('01 343 8704', Decimal('196.96233391400'))
# ('01 343 9184', Decimal('3888.04137596040'))
# ('01 344 0968', Decimal('1575.03986244800'))
# ('01 344 2775', Decimal('6341.17863976600'))
# ('01 344 5300', Decimal('17172.39699860530'))
# ('01 344 8318', Decimal('3009.94408212700'))
# ('01 344 9240', Decimal('10678.62500815600'))
# ('01 345 1376', Decimal('2507.57406311700'))
# ('01 345 2110', Decimal('4177.01628481800'))
# ('01 345 5354', Decimal('1410.94552889700'))
# ('01 345 8166', Decimal('404.77370312400'))
# ('01 346 0587', Decimal('8319.41654873070'))
# ('01 346 3655', Decimal('561.80170802500'))
# ('01 347 8712', Decimal('3077.99651125700'))
# ('01 348 2089', Decimal('13279.55802389140'))
# ('01 348 3953', Decimal('3339.41866300000'))
# ('01 349 0107', Decimal('3366.21501416900'))
# ('01 349 1885', Decimal('13602.14952017900'))
# ('01 349 3041', Decimal('6237.66768324250'))
# ('01 349 5304', Decimal('17646.36156061490'))
# ('01 350 4583', Decimal('11056.83344277700'))
# ('01 351 4243', Decimal('2314.02679100100'))
# ('01 351 9489', Decimal('3405.27251162200'))
# ('01 352 4852', Decimal('14228.30270350500'))
# ('01 352 6228', Decimal('9094.93334071300'))
# ('01 352 7245', Decimal('3078.56614879800'))
# ('01 353 6815', Decimal('10654.75461436410'))
# ('01 355 0845', Decimal('1641.05107012800'))
# ('01 355 6210', Decimal('16026.96684645900'))
# ('01 355 8388', Decimal('1095.62152083000'))
# ('01 356 0028', Decimal('256.67171120400'))
# ('01 356 7208', Decimal('6004.48785793200'))
# ('01 356 7823', Decimal('11062.53880364400'))
# ('01 356 8467', Decimal('2024.49353172300'))
# ('01 356 9059', Decimal('5627.04980675700'))
# ('01 357 0985', Decimal('4890.61093488846'))
# ('01 357 2698', Decimal('11937.94757582300'))
# ('01 357 5518', Decimal('17171.38357896070'))
# ('01 357 8011', Decimal('8351.81912494300'))
# ('01 357 9666', Decimal('11835.92609743600'))
# ('01 358 0761', Decimal('5154.48038025200'))
# ('01 358 1522', Decimal('7053.27176462500'))
# ('01 358 4453', Decimal('1876.83732372900'))
# ('01 358 5897', Decimal('13811.43656890079'))
# ('01 358 7022', Decimal('1693.37582389900'))
# ('01 358 9178', Decimal('5837.30292952650'))
# ('01 359 1945', Decimal('2293.23769998800'))
# ('01 359 4106', Decimal('25.95151030500'))
# ('01 359 5314', Decimal('4114.50332390300'))
# ('01 359 6978', Decimal('15615.73485529900'))
# ('01 360 1528', Decimal('5146.11010064800'))
# ('01 360 3714', Decimal('19570.55717242200'))
# ('01 360 5127', Decimal('2947.05669906700'))
# ('01 360 6707', Decimal('9960.15300061700'))
# ('01 361 0243', Decimal('997.24665112700'))
# ('01 361 8576', Decimal('10526.27560887000'))
# ('01 362 4874', Decimal('10617.46409655800'))
# ('01 362 9745', Decimal('4735.36489132400'))
# ('01 365 0935', Decimal('10607.07573997000'))
# ('01 365 3745', Decimal('19854.92516828920'))
# ('01 365 3993', Decimal('2884.84326615900'))
# ('01 365 7191', Decimal('3047.54663398200'))
# ('01 365 8238', Decimal('4706.21665486400'))
# ('01 365 9085', Decimal('12251.46471758000'))
# ('01 365 9269', Decimal('3801.12763137680'))
# ('01 366 3375', Decimal('11356.59521141300'))
# ('01 366 3890', Decimal('6565.08159193500'))
# ('01 366 4812', Decimal('20637.84277433080'))
# ('01 366 4885', Decimal('5551.35303362600'))
# ('01 366 7657', Decimal('1965.51355647100'))
# ('01 367 9248', Decimal('13098.38708293300'))
# ('01 368 5516', Decimal('4611.11437134700'))
# ('01 368 9347', Decimal('893.82129164700'))
# ('01 369 1568', Decimal('10804.98211404500'))
# ('01 369 3417', Decimal('10533.45578819200'))
# ('01 369 9109', Decimal('971.89947880200'))
# ('01 370 1025', Decimal('1245.89642684100'))
# ('01 370 2302', Decimal('4284.23854603400'))
# ('01 370 2537', Decimal('552.40825358300'))
# ('01 370 6146', Decimal('12776.00647612200'))
# ('01 372 4115', Decimal('6059.96247598500'))
# ('01 372 7020', Decimal('4553.53165130700'))
# ('01 373 7352', Decimal('9110.07129555580'))
# ('01 373 9086', Decimal('17216.42592974100'))
# ('01 374 2058', Decimal('15198.72474771820'))
# ('01 374 7050', Decimal('2891.22667009500'))
# ('01 374 8257', Decimal('7791.90760182200'))
# ('01 375 3328', Decimal('10350.21187992300'))
# ('01 375 6297', Decimal('11273.56845931000'))
# ('01 375 7765', Decimal('12921.96346850700'))
# ('01 376 8191', Decimal('8637.93422975700'))
# ('01 376 9118', Decimal('8852.11162232800'))
# ('01 376 9647', Decimal('686.15058641300'))
# ('01 376 9732', Decimal('984.46232854100'))
# ('01 376 9978', Decimal('4471.97672209700'))
# ('01 377 7250', Decimal('5108.09972078400'))
# ('01 378 0380', Decimal('585.49267876000'))
# ('01 378 2019', Decimal('683.95814477000'))
# ('01 378 3829', Decimal('5401.75612289100'))
# ('01 378 5908', Decimal('4617.91643473000'))
# ('01 378 8151', Decimal('12235.34683301800'))
# ('01 378 9048', Decimal('1414.52883733600'))
# ('01 379 2034', Decimal('6489.67907329480'))
# ('01 379 3437', Decimal('830.03060495900'))
# ('01 379 4917', Decimal('9900.83509767200'))
# ('01 380 0699', Decimal('4552.81765124300'))
# ('01 380 2201', Decimal('8931.28910140070'))
# ('01 380 9537', Decimal('2307.66309104600'))
# ('01 381 2388', Decimal('12561.21723350900'))
# ('01 381 3799', Decimal('9174.89628710500'))
# ('01 381 7795', Decimal('11043.81892157600'))
# ('01 382 1514', Decimal('6699.80385776000'))
# ('01 383 1786', Decimal('13562.28026345200'))
# ('01 384 4760', Decimal('2396.00019447100'))
# ('01 384 5030', Decimal('5573.91015750100'))
# ('01 384 8102', Decimal('6040.69531359400'))
# ('01 384 9017', Decimal('5711.31979003200'))
# ('01 384 9777', Decimal('14325.13726491800'))
# ('01 385 0297', Decimal('9964.65488680170'))
# ('01 385 1296', Decimal('14952.96848941600'))
# ('01 385 4549', Decimal('771.03867022500'))
# ('01 385 9961', Decimal('4838.97891707500'))
# ('01 386 0879', Decimal('6465.33416741300'))
# ('01 386 6800', Decimal('3109.65723167000'))
# ('01 387 1040', Decimal('4345.93260622700'))
# ('01 387 4460', Decimal('6621.89848104700'))
# ('01 387 4474', Decimal('721.89076476400'))
# ('01 390 5277', Decimal('980.43799605960'))
# ('01 390 7597', Decimal('6074.91351038300'))
# ('01 390 8440', Decimal('3327.24667192670'))
# ('01 391 1965', Decimal('15624.58879984800'))
# ('01 391 4655', Decimal('2453.26148520500'))
# ('01 391 6604', Decimal('3125.44538970800'))
# ('01 391 8004', Decimal('5487.81453151000'))
# ('01 391 9913', Decimal('15428.41722348300'))
# ('01 392 7209', Decimal('5350.52214993400'))
# ('01 392 9179', Decimal('2711.11976431980'))
# ('01 393 3469', Decimal('18939.14393403060'))
# ('01 393 5320', Decimal('2044.66226816400'))
# ('01 394 5310', Decimal('2242.60732921200'))
# ('01 394 6355', Decimal('17486.64161198300'))
# ('01 395 4374', Decimal('11395.74530572860'))
# ('01 396 4021', Decimal('11389.04583170600'))
# ('01 397 0048', Decimal('13728.74861090500'))
# ('01 397 3945', Decimal('15875.45811034700'))
# ('01 398 1321', Decimal('132.48358749600'))
# ('01 398 2988', Decimal('9012.05798257700'))
# ('01 398 4556', Decimal('15414.69909922800'))
# ('01 398 8167', Decimal('6690.74646970900'))
# ('01 398 8225', Decimal('2390.96052624800'))
# ('01 398 8679', Decimal('8061.74904492800'))
# ('01 399 1578', Decimal('14516.83895722210'))
# ('01 399 8230', Decimal('6623.57156321620'))
# ('01 400 5603', Decimal('7728.94373745100'))
# ('01 400 8461', Decimal('4807.92972757200'))
# ('01 401 0045', Decimal('8527.92836033900'))
# ('01 401 3325', Decimal('9668.42443870860'))
# ('01 401 7445', Decimal('196.12642985000'))
# ('01 401 7526', Decimal('11420.46462661660'))
# ('01 401 8501', Decimal('2152.87864598900'))
# ('01 402 0562', Decimal('5751.06644281000'))
# ('01 402 1009', Decimal('11292.11837428000'))
# ('01 402 3865', Decimal('10548.99643350480'))
# ('01 402 4809', Decimal('5105.35489642300'))
# ('01 402 7274', Decimal('5138.67130997220'))
# ('01 403 1833', Decimal('16963.41710020670'))
# ('01 403 4565', Decimal('5853.24766655700'))
# ('01 403 4696', Decimal('642.75329782400'))
# ('01 403 7846', Decimal('479.57778983100'))
# ('01 404 1507', Decimal('13906.93009653800'))
# ('01 404 4910', Decimal('15551.72063585700'))
# ('01 405 0225', Decimal('3661.35375348900'))
# ('01 405 1667', Decimal('6357.37029020200'))
# ('01 405 9451', Decimal('7497.22473796300'))
# ('01 405 9858', Decimal('7878.11130302000'))
# ('01 406 0830', Decimal('142.66740690000'))
# ('01 406 2524', Decimal('1017.03069481800'))
# ('01 406 6501', Decimal('2656.15429313600'))
# ('01 406 7147', Decimal('8768.67514334130'))
# ('01 406 7475', Decimal('2177.92849918200'))
# ('01 407 2829', Decimal('20425.34261030850'))
# ('01 408 0711', Decimal('4172.05603147000'))
# ('01 408 4728', Decimal('4126.88286031200'))
# ('01 408 6462', Decimal('1961.47304793400'))
# ('01 409 9391', Decimal('9300.23129282880'))
# ('01 409 9654', Decimal('6857.32100404800'))
# ('01 411 1461', Decimal('17673.82842014620'))
# ('01 411 7204', Decimal('11124.02111276400'))
# ('01 412 2505', Decimal('2313.03006170000'))
# ('01 412 4772', Decimal('17967.81884746460'))
# ('01 412 5013', Decimal('1376.27963395800'))
# ('01 412 7742', Decimal('6763.37744738000'))
# ('01 413 1352', Decimal('11561.50398411800'))
# ('01 414 1966', Decimal('11757.74712673200'))
# ('01 414 3005', Decimal('13555.69654967300'))
# ('01 414 5564', Decimal('8636.25011990900'))
# ('01 414 6525', Decimal('9112.42696896700'))
# ('01 415 3250', Decimal('29.79262579800'))
# ('01 415 3412', Decimal('221.77985520600'))
# ('01 416 0456', Decimal('2503.91180444300'))
# ('01 416 1750', Decimal('7788.83316351100'))
# ('01 416 1861', Decimal('19588.71385367950'))
# ('01 416 7217', Decimal('9316.40451039019'))
# ('01 416 9189', Decimal('9240.71918422100'))
# ('01 416 9315', Decimal('4123.91521868200'))
# ('01 417 3924', Decimal('5229.06345814520'))
# ('01 417 4788', Decimal('2325.53519900900'))
# ('01 417 8694', Decimal('7123.96155127580'))
# ('01 418 2994', Decimal('15331.34309673600'))
# ('01 418 3392', Decimal('943.34986730300'))
# ('01 418 4106', Decimal('6917.26997122300'))
# ('01 418 5967', Decimal('11015.10502400800'))
# ('01 419 1281', Decimal('14028.67574732510'))
# ('01 419 3645', Decimal('10300.04745369090'))
# ('01 420 2813', Decimal('4342.61103454500'))
# ('01 420 6513', Decimal('2809.71938803200'))
# ('01 421 0869', Decimal('16776.08900889800'))
# ('01 421 2552', Decimal('16418.44439579800'))
# ('01 421 5513', Decimal('5557.93785231600'))
# ('01 421 5546', Decimal('1069.81035792100'))
# ('01 421 9709', Decimal('3782.06359253920'))
# ('01 422 0928', Decimal('14489.22967435700'))
# ('01 423 9771', Decimal('1634.47148286300'))
# ('01 424 6464', Decimal('13452.17837643000'))
# ('01 425 3401', Decimal('16674.35699663300'))
# ('01 425 6741', Decimal('7194.25507899300'))
# ('01 426 4394', Decimal('1685.49355528000'))
# ('01 426 8053', Decimal('1298.97011433700'))
# ('01 427 8839', Decimal('3762.83127405100'))
# ('01 428 0462', Decimal('12861.00587173830'))
# ('01 428 4612', Decimal('1845.88814929500'))
# ...
# ('093 410 3918', Decimal('13517.40908566800'))
# ('093 420 2415', Decimal('705.48812971000'))
# ('093 478 5261', Decimal('16821.50352196700'))
# ('093 492 9000', Decimal('6527.37140468700'))
# ('093 524 2883', Decimal('1558.27591186500'))
# ('093 533 4989', Decimal('492.07969279200'))
# ('093 538 0948', Decimal('2868.15628689400'))
# ('093 547 6476', Decimal('1004.27482596600'))
# ('093 575 4743', Decimal('2022.71389400600'))
# ('093 589 1414', Decimal('268.18109564300'))
# ('093 601 0044', Decimal('895.80568924000'))
# ('093 627 9331', Decimal('13478.35871590600'))
# ('093 637 7339', Decimal('8390.80804620700'))
# ('093 640 8352', Decimal('7012.75634175700'))
# ('093 695 2827', Decimal('7097.05802437180'))
# ('093 701 5695', Decimal('4629.22045788200'))
# ('093 707 9424', Decimal('9940.97897240836'))
# ('093 750 9371', Decimal('3597.56649138604'))
# ('093 775 9316', Decimal('5981.91575982500'))
# ('093 785 0140', Decimal('21239.40675080350'))
# ('093 785 2635', Decimal('4236.33289831200'))
# ('093 808 7724', Decimal('10426.35003799930'))
# ('093 828 7603', Decimal('1603.77296682900'))
# ('093 881 8364', Decimal('4297.64404602500'))
# ('093 887 6720', Decimal('7692.86331114200'))
# ('093 894 3237', Decimal('12378.66638727200'))
# ('093 894 5323', Decimal('16146.42642221760'))
# ('093 919 4149', Decimal('12948.67051584600'))
# ('093 935 1738', Decimal('12452.43640302200'))
# ('093 936 0880', Decimal('1721.89416231000'))
# ('093 951 2803', Decimal('5077.17862363800'))
# ('093 984 5046', Decimal('4581.85745299100'))
# ('094 015 4045', Decimal('9185.46447668100'))
# ('094 028 7607', Decimal('9762.40187932500'))
# ('094 043 7234', Decimal('1769.35233447600'))
# ('094 045 1850', Decimal('12593.13984265180'))
# ('094 074 0846', Decimal('5551.36721812900'))
# ('094 098 0120', Decimal('10814.64051029400'))
# ('094 104 2173', Decimal('8964.56382863000'))
# ('094 114 5820', Decimal('7315.06612907540'))
# ('094 124 7294', Decimal('14481.50546910700'))
# ('094 126 0518', Decimal('13655.26414646500'))
# ('094 157 8940', Decimal('5594.11685801780'))
# ('094 158 6154', Decimal('14586.09647015300'))
# ('094 218 1087', Decimal('479.81858982900'))
# ('094 222 5131', Decimal('6515.74486506300'))
# ('094 267 5141', Decimal('8899.03079501670'))
# ('094 287 0474', Decimal('7423.39013322900'))
# ('094 289 8213', Decimal('12632.41004303360'))
# ('094 294 0177', Decimal('10662.51054709800'))
# ('094 335 8698', Decimal('3480.39014544500'))
# ('094 342 8577', Decimal('11719.69836430700'))
# ('094 351 8312', Decimal('7488.30348832200'))
# ('094 367 3891', Decimal('3645.42522917900'))
# ('094 382 8505', Decimal('4021.64945944400'))
# ('094 411 3454', Decimal('16745.73832080400'))
# ('094 412 5291', Decimal('4476.82530039500'))
# ('094 436 3632', Decimal('4981.61251032500'))
# ('094 477 7926', Decimal('6305.58728061740'))
# ('094 479 4391', Decimal('8362.04880183600'))
# ('094 534 4223', Decimal('2373.66664511400'))
# ('094 573 5833', Decimal('680.39091435600'))
# ('094 583 3797', Decimal('6730.11767093200'))
# ('094 608 0105', Decimal('13427.05797710700'))
# ('094 628 3117', Decimal('1863.27352545300'))
# ('094 654 9560', Decimal('14199.59312362540'))
# ('094 689 4474', Decimal('2026.31828337100'))
# ('094 743 2120', Decimal('5014.48137043600'))
# ('094 779 8856', Decimal('1653.19398792100'))
# ('094 802 0926', Decimal('9500.81392254500'))
# ('094 807 6464', Decimal('16584.88002086000'))
# ('094 825 6429', Decimal('15059.27015509300'))
# ('094 828 8715', Decimal('202.00425234600'))
# ('094 829 6874', Decimal('19291.65916724980'))
# ('094 856 7706', Decimal('4655.52391967400'))
# ('094 891 4459', Decimal('5164.34795304000'))
# ('094 894 9060', Decimal('6327.23466461100'))
# ('094 901 1858', Decimal('17183.58795305600'))
# ('094 918 8978', Decimal('6545.37884684600'))
# ('094 926 5983', Decimal('7607.33027032800'))
# ('094 932 7239', Decimal('7114.05809656400'))
# ('094 988 4515', Decimal('1076.71410156500'))
# ('095 002 2486', Decimal('5733.27154521600'))
# ('095 019 3128', Decimal('139.63468714000'))
# ('095 045 0703', Decimal('11897.70384472990'))
# ('095 062 6260', Decimal('15550.11167334430'))
# ('095 089 6861', Decimal('8998.15063585897'))
# ('095 093 2766', Decimal('2476.47434197800'))
# ('095 093 6529', Decimal('2175.91724126100'))
# ('095 104 4167', Decimal('18304.84616013900'))
# ('095 119 3949', Decimal('7616.29733052700'))
# ('095 125 1767', Decimal('13474.62347710800'))
# ('095 135 9134', Decimal('5882.32591698200'))
# ('095 137 6784', Decimal('16082.58175344300'))
# ('095 189 9559', Decimal('4085.62851263360'))
# ('095 233 6225', Decimal('699.52709607800'))
# ('095 237 0920', Decimal('10706.60292038700'))
# ('095 265 2444', Decimal('14723.96362169150'))
# ('095 276 1170', Decimal('11740.02347166000'))
# ('095 281 1792', Decimal('7629.74419233900'))
# ('095 319 7775', Decimal('4281.95447068140'))
# ('095 365 7288', Decimal('1325.61414937600'))
# ('095 369 0498', Decimal('12007.95646545400'))
# ('095 386 3222', Decimal('3574.86385072600'))
# ('095 398 6440', Decimal('4145.30018916500'))
# ('095 413 3035', Decimal('1464.26495026600'))
# ('095 414 6769', Decimal('5446.79250206980'))
# ('095 427 3639', Decimal('3488.78594390700'))
# ('095 432 0525', Decimal('11113.68050963270'))
# ('095 483 6391', Decimal('20224.30612680600'))
# ('095 503 6129', Decimal('3016.55344871450'))
# ('095 553 1980', Decimal('10959.74847961900'))
# ('095 562 2752', Decimal('16370.12671345400'))
# ('095 590 6556', Decimal('7793.33075842900'))
# ('095 592 3053', Decimal('2279.39115664200'))
# ('095 592 9168', Decimal('9840.82490836200'))
# ('095 592 9413', Decimal('6393.62124019700'))
# ('095 595 1684', Decimal('1628.95126557800'))
# ('095 599 1909', Decimal('1324.57059582700'))
# ('095 639 0996', Decimal('4206.67672641400'))
# ('095 661 9423', Decimal('892.37668946600'))
# ('095 682 4274', Decimal('1056.87985873200'))
# ('095 696 3668', Decimal('8192.67113670900'))
# ('095 697 4329', Decimal('1006.76210003600'))
# ('095 708 1099', Decimal('18077.09548409400'))
# ('095 737 1152', Decimal('5696.36254560400'))
# ('095 770 1007', Decimal('12055.97353496300'))
# ('095 773 9254', Decimal('6398.81472363500'))
# ('095 778 5357', Decimal('6346.77020071900'))
# ('095 785 7003', Decimal('471.56106674400'))
# ('095 809 4048', Decimal('3953.32861556500'))
# ('095 860 7556', Decimal('12791.32354996400'))
# ('095 868 8733', Decimal('2589.59855355600'))
# ('095 873 9443', Decimal('19448.79025804500'))
# ('095 893 5103', Decimal('4932.43007692500'))
# ('095 910 5244', Decimal('12890.15212372120'))
# ('095 911 0660', Decimal('3583.47415629700'))
# ('095 930 6123', Decimal('1400.37484257000'))
# ('095 937 2294', Decimal('613.47573842600'))
# ('095 943 2513', Decimal('3729.07869443900'))
# ('095 974 1555', Decimal('10842.27550393900'))
# ('095 988 3431', Decimal('4912.62781659700'))
# ('096 031 2027', Decimal('924.34004196800'))
# ('096 049 6722', Decimal('4483.68954220800'))
# ('096 059 7711', Decimal('3242.14956572600'))
# ('096 163 8616', Decimal('1579.54885459000'))
# ('096 166 1215', Decimal('10946.35756721942'))
# ('096 171 7739', Decimal('1261.40072190200'))
# ('096 178 1757', Decimal('5244.35547506300'))
# ('096 186 4517', Decimal('14189.88162551600'))
# ('096 216 7538', Decimal('2627.54834561900'))
# ('096 217 0066', Decimal('1323.27089388000'))
# ('096 235 9352', Decimal('2702.20540095800'))
# ('096 240 7557', Decimal('3656.13099727900'))
# ('096 241 5530', Decimal('8144.16706110100'))
# ('096 245 2124', Decimal('7746.06508380500'))
# ('096 274 9944', Decimal('4127.70315956500'))
# ('096 303 9307', Decimal('14193.70633953500'))
# ('096 324 9242', Decimal('17347.79184217400'))
# ('096 356 6517', Decimal('2340.37998285450'))
# ('096 411 5000', Decimal('3016.51039061700'))
# ('096 425 4011', Decimal('2980.68987912300'))
# ('096 451 4366', Decimal('14861.75517933900'))
# ('096 481 4167', Decimal('5490.83793105400'))
# ('096 491 3734', Decimal('5173.99111911700'))
# ('096 553 0228', Decimal('9308.63082634360'))
# ('096 575 9818', Decimal('1270.56812615300'))
# ('096 583 0838', Decimal('1807.83492206100'))
# ('096 596 8412', Decimal('7016.95991233000'))
# ('096 624 6086', Decimal('8539.85749467800'))
# ('096 625 8463', Decimal('3235.04899236600'))
# ('096 628 0190', Decimal('16320.35645561900'))
# ('096 660 8648', Decimal('2007.40706571500'))
# ('096 675 2696', Decimal('1493.41913218400'))
# ('096 721 2926', Decimal('1621.85995080500'))
# ('096 724 1328', Decimal('6621.05433841200'))
# ('096 760 4136', Decimal('19946.78775156100'))
# ('096 762 4518', Decimal('8630.57841393200'))
# ('096 762 5554', Decimal('9571.10068250200'))
# ('096 776 3415', Decimal('3696.34772895800'))
# ('096 778 6309', Decimal('17207.14804437300'))
# ('096 843 3437', Decimal('11429.62908663000'))
# ('096 856 8319', Decimal('941.32735279700'))
# ('096 875 0322', Decimal('1817.73396221700'))
# ('096 894 9646', Decimal('3668.81823391500'))
# ('096 911 2396', Decimal('720.38800000800'))
# ('096 917 0305', Decimal('7294.89054433800'))
# ('096 942 1313', Decimal('8759.08268557900'))
# ('096 954 7374', Decimal('1547.72083661500'))
# ('096 963 9439', Decimal('13466.83124553740'))
# ('096 965 5787', Decimal('4624.81915631600'))
# ('096 984 5416', Decimal('6857.57700823100'))
# ('097 049 1224', Decimal('5572.55239220700'))
# ('097 068 0123', Decimal('589.59466039800'))
# ('097 128 0556', Decimal('3113.72724558300'))
# ('097 156 3860', Decimal('1928.19571469500'))
# ('097 159 3589', Decimal('12860.32189669720'))
# ('097 168 9493', Decimal('5627.05463655600'))
# ('097 211 1630', Decimal('13869.80788488600'))
# ('097 241 8396', Decimal('4071.01157165800'))
# ('097 244 2994', Decimal('1372.70552989600'))
# ('097 276 0543', Decimal('13094.43951826340'))
# ('097 286 3014', Decimal('7520.57289037600'))
# ('097 309 1688', Decimal('13984.96455409100'))
# ('097 337 9385', Decimal('5155.68704279800'))
# ('097 343 4457', Decimal('14970.12885208120'))
# ('097 355 2360', Decimal('2466.28804157000'))
# ('097 380 6492', Decimal('2818.84406551500'))
# ('097 383 9791', Decimal('4490.92045401600'))
# ('097 418 2240', Decimal('64.96184455300'))
# ('097 421 3048', Decimal('927.92103395800'))
# ('097 458 2208', Decimal('428.60740086500'))
# ('097 470 1830', Decimal('7005.70808177700'))
# ('097 480 6837', Decimal('4302.98352440400'))
# ('097 492 8940', Decimal('4960.21717713700'))
# ('097 518 8668', Decimal('11899.31131632200'))
# ('097 539 0904', Decimal('22554.26055307200'))
# ('097 546 3920', Decimal('10766.99016771720'))
# ('097 566 2311', Decimal('8713.63188287000'))
# ('097 584 7397', Decimal('12429.58131877400'))
# ('097 601 5401', Decimal('8742.66330192700'))
# ('097 603 9467', Decimal('16603.33912152430'))
# ('097 632 0123', Decimal('1981.76085750600'))
# ('097 660 7672', Decimal('11097.72648864700'))
# ('097 669 5398', Decimal('4208.23124684500'))
# ('097 670 6904', Decimal('9414.46263211860'))
# ('097 677 9605', Decimal('6195.34141123500'))
# ('097 705 0231', Decimal('11010.34078293100'))
# ('097 738 2344', Decimal('1509.37488597020'))
# ('097 739 7332', Decimal('1982.79766635100'))
# ('097 742 5312', Decimal('7394.96077541600'))
# ('097 749 5893', Decimal('3879.01090461900'))
# ('097 781 5993', Decimal('5994.36555632200'))
# ('097 782 9315', Decimal('14980.27059727820'))
# ('097 800 1897', Decimal('1781.19427423700'))
# ('097 821 7601', Decimal('1614.09285560840'))
# ('097 825 7348', Decimal('3954.29668554900'))
# ('097 830 7504', Decimal('1579.45497281300'))
# ('097 835 8282', Decimal('12772.56940021200'))
# ('097 853 6536', Decimal('13209.91696892700'))
# ('097 857 3575', Decimal('9288.77765916700'))
# ('097 860 7752', Decimal('16135.17204022500'))
# ('097 886 8635', Decimal('2747.71673108000'))
# ('097 918 8834', Decimal('11114.07325088620'))
# ('097 922 5004', Decimal('3146.58876407700'))
# ('097 970 8184', Decimal('14660.55274195960'))
# ('097 974 5548', Decimal('216.35636921000'))
# ('097 978 6830', Decimal('18274.39010086030'))
# ('097 984 1283', Decimal('3750.57871429700'))
# ('098 023 1709', Decimal('2654.01431144100'))
# ('098 024 6082', Decimal('2812.86251880300'))
# ('098 033 2530', Decimal('10613.10841354900'))
# ('098 058 2030', Decimal('10544.96744933600'))
# ('098 064 9518', Decimal('588.95861358300'))
# ('098 067 7222', Decimal('9723.10210807900'))
# ('098 148 2924', Decimal('3496.25778622100'))
# ('098 175 2992', Decimal('6314.57719917000'))
# ('098 203 9497', Decimal('2288.12143911900'))
# ('098 223 3747', Decimal('14261.12360568360'))
# ('098 270 2822', Decimal('4417.32278717100'))
# ('098 302 3134', Decimal('15708.98416642540'))
# ('098 317 0154', Decimal('190.78823781100'))
# ('098 325 9421', Decimal('14688.87361977080'))
# ('098 395 7912', Decimal('4466.29100481000'))
# ('098 436 3682', Decimal('14310.04370553310'))
# ('098 436 8234', Decimal('1611.26185076200'))
# ('098 456 6760', Decimal('16418.10713811300'))
# ('098 471 2379', Decimal('19203.93612650800'))
# ('098 471 5749', Decimal('11349.21017339260'))
# ('098 479 8154', Decimal('14355.47765956820'))
# ('098 506 4624', Decimal('1520.06323081900'))
# ('098 507 3591', Decimal('1165.63646379440'))
# ('098 532 2951', Decimal('9756.70765787400'))
# ('098 568 8430', Decimal('2733.39221219860'))
# ('098 645 4041', Decimal('1011.64768158800'))
# ('098 662 8068', Decimal('9254.90392927920'))
# ('098 703 0848', Decimal('4456.53709852800'))
# ('098 733 2818', Decimal('11025.13177535200'))
# ('098 742 7462', Decimal('18430.52064225500'))
# ('098 745 4469', Decimal('5357.93798315100'))
# ('098 746 1914', Decimal('17630.36312684500'))
# ('098 761 8559', Decimal('5904.73283332800'))
# ('098 787 5555', Decimal('7066.11498900800'))
# ('098 792 0545', Decimal('6359.01328337800'))
# ('098 793 5932', Decimal('6487.48875432200'))
# ('098 802 1130', Decimal('6516.48890989900'))
# ('098 804 6637', Decimal('7361.89797357660'))
# ('098 830 0863', Decimal('4346.44308127800'))
# ('098 861 2349', Decimal('15911.64858736500'))
# ('098 873 2168', Decimal('175.49002001700'))
# ('098 876 1159', Decimal('8171.38635817700'))
# ('098 976 3902', Decimal('13523.64456757100'))
# ('098 984 0097', Decimal('21257.25059690500'))
# ('098 986 3148', Decimal('5280.54607865300'))
# ('098 991 7385', Decimal('5479.75956812160'))
# ('099 007 2663', Decimal('13443.29042302100'))
# ('099 074 8265', Decimal('3499.07295906720'))
# ('099 082 9689', Decimal('691.34334584300'))
# ('099 118 3706', Decimal('15573.43673614700'))
# ('099 123 4828', Decimal('3562.82539585800'))
# ('099 129 9014', Decimal('442.15903880500'))
# ('099 131 8627', Decimal('18984.06051582600'))
# ('099 155 4735', Decimal('10907.84602400020'))
# ('099 182 3641', Decimal('15200.90704093600'))
# ('099 183 1097', Decimal('15680.95155490060'))
# ('099 201 0842', Decimal('11298.96460610400'))
# ('099 205 6701', Decimal('1346.60871112000'))
# ('099 236 8205', Decimal('795.31473645400'))
# ('099 254 0042', Decimal('10120.85296717600'))
# ('099 264 7569', Decimal('22158.16218228200'))
# ('099 302 4237', Decimal('7257.30229907800'))
# ('099 329 2806', Decimal('4445.62385470800'))
# ('099 385 3375', Decimal('2783.24222185500'))
# ('099 392 3191', Decimal('2197.89408978000'))
# ('099 403 7775', Decimal('2849.70993161700'))
# ('099 421 7006', Decimal('9812.70154117700'))
# ('099 421 7773', Decimal('2421.68614720100'))
# ('099 422 7581', Decimal('3542.71994012200'))
# ('099 459 2667', Decimal('10560.28672734400'))
# ('099 467 0203', Decimal('8568.64898264240'))
# ('099 468 7790', Decimal('750.61048295700'))
# ('099 496 5160', Decimal('4021.65995700000'))
# ('099 534 3954', Decimal('13852.77460786340'))
# ('099 567 1853', Decimal('3239.05550250600'))
# ('099 573 8495', Decimal('3710.43476618700'))
# ('099 648 3187', Decimal('541.69679364900'))
# ('099 649 5307', Decimal('7245.90267704300'))
# ('099 653 9766', Decimal('14346.50511847800'))
# ('099 665 4287', Decimal('8099.76418116800'))
# ('099 687 9704', Decimal('1647.13924254800'))
# ('099 760 8745', Decimal('10498.66139139100'))
# ('099 768 5189', Decimal('911.95129180340'))
# ('099 776 2074', Decimal('14525.19367632500'))
# ('099 786 5545', Decimal('5449.59467086710'))
# ('099 804 3736', Decimal('5409.45040364500'))
# ('099 818 3679', Decimal('3714.55559817400'))
# ('099 827 2933', Decimal('179.48789991400'))
# ('099 852 4932', Decimal('76.35258134400'))
# ('099 863 6734', Decimal('6226.86151542200'))
# ('099 891 4468', Decimal('14565.74982760170'))
# ('099 932 6937', Decimal('4801.13495435000'))
# ('099 934 4854', Decimal('2256.71366887000'))
# ('099 950 5844', Decimal('3069.26121537700'))
# ('099 959 2978', Decimal('10048.52560930600'))
# ('099 965 9604', Decimal('7522.97774996400'))
# ('099 971 0686', Decimal('7109.96425991880'))

# %% [markdown]
# d) There is a logical error on the result of the above query. As a telecommunications specialist, you have observed that the `total_amount_spent` returned is too high for the usual expected values in this industry. Please fix the query so that values falls in a reasonable range. (1 mark)

# %% [markdown]
# e) Given the correct query for the `total_amount_spent` spent, identify the min, max and average revenue gererate by overall phone numbers (1 mark)

# %%
result = conn.execute(text(
    "SELECT MIN(total_amount_spent), MAX(total_amount_spent), AVG(total_amount_spent) "
    "FROM ("
    "SELECT c.phonenumber, SUM(cr.costperminute * c.duration / 60) AS total_amount_spent "
    "FROM public.calls c "
    "INNER JOIN public.call_rates cr ON c.callrate = cr.callrate "
    "WHERE c.connectionid NOT IN (SELECT DISTINCT connectionid FROM public.customer_service) "
    "GROUP BY c.phonenumber"
    ") AS totals"
))

for row in result:
    print(row)
# Out:
# (Decimal('0.13573812340000000000'), Decimal('483.59002186295666676666'), Decimal('125.135435194589396511280553'))

# %% [markdown]
# # Calls information

# %% [markdown]
# ### Question 4

# %% [markdown]
# Query the database to extract the following information:

# %% [markdown]
# a) The average call duration in minutes per phone number, excluding those made to the customer service (2 marks)

# %%
conn.rollback()
result = conn.execute(text("SELECT c.phonenumber, AVG(c.duration/60) AS avg_call_duration_mins " 
                        "FROM public.calls c INNER JOIN public.call_rates cr ON c.callrate = cr.callrate "
                        "WHERE c.connectionid NOT IN ( SELECT DISTINCT connectionid FROM public.customer_service) "
                        "GROUP BY c.phonenumber "
                        "ORDER BY c.phonenumber;"
                        #")"
)
)

# get the value from the tuple result returned byt the sql query
avg_call_dur_result = result.fetchall()

# loop through the values, assigning a value to the first and second values in the tuple result
# this just allow us call them in print satement with mroe descriptive details
for row in avg_call_dur_result:
    phonenumber = row[0]
    avg_duration = row[1]
    print(f" phone number = {phonenumber}  --  average call duration in mins : {round(avg_duration, 2)}")
# Out:
#  phone number = 01 000 9436  --  average call duration in mins : 12.26
#  phone number = 01 001 6896  --  average call duration in mins : 17.20
#  phone number = 01 001 9955  --  average call duration in mins : 13.17
#  phone number = 01 002 1488  --  average call duration in mins : 15.98
#  phone number = 01 002 1807  --  average call duration in mins : 9.34
#  phone number = 01 002 3138  --  average call duration in mins : 16.66
#  phone number = 01 002 7003  --  average call duration in mins : 19.11
#  phone number = 01 003 5862  --  average call duration in mins : 16.18
#  phone number = 01 004 1518  --  average call duration in mins : 11.59
#  phone number = 01 004 3369  --  average call duration in mins : 17.85
#  phone number = 01 004 6123  --  average call duration in mins : 16.44
#  phone number = 01 005 3059  --  average call duration in mins : 12.40
#  phone number = 01 005 7353  --  average call duration in mins : 11.89
#  phone number = 01 005 8909  --  average call duration in mins : 15.85
#  phone number = 01 005 9012  --  average call duration in mins : 15.68
#  phone number = 01 006 5619  --  average call duration in mins : 17.22
#  phone number = 01 006 8032  --  average call duration in mins : 18.58
#  phone number = 01 007 0548  --  average call duration in mins : 16.65
#  phone number = 01 007 3126  --  average call duration in mins : 14.61
#  phone number = 01 008 0438  --  average call duration in mins : 14.47
#  phone number = 01 008 1378  --  average call duration in mins : 15.95
#  phone number = 01 008 2702  --  average call duration in mins : 17.44
#  phone number = 01 008 5273  --  average call duration in mins : 17.36
#  phone number = 01 008 6188  --  average call duration in mins : 8.84
#  phone number = 01 009 8882  --  average call duration in mins : 13.29
#  phone number = 01 010 3210  --  average call duration in mins : 8.40
#  phone number = 01 010 4583  --  average call duration in mins : 12.38
#  phone number = 01 010 9798  --  average call duration in mins : 14.69
#  phone number = 01 011 1266  --  average call duration in mins : 12.77
#  phone number = 01 011 1953  --  average call duration in mins : 21.12
#  phone number = 01 011 8477  --  average call duration in mins : 13.49
#  phone number = 01 012 7288  --  average call duration in mins : 14.14
#  phone number = 01 013 7832  --  average call duration in mins : 14.80
#  phone number = 01 014 0689  --  average call duration in mins : 14.79
#  phone number = 01 014 1996  --  average call duration in mins : 15.76
#  phone number = 01 016 0950  --  average call duration in mins : 15.52
#  phone number = 01 018 5577  --  average call duration in mins : 16.98
#  phone number = 01 019 5062  --  average call duration in mins : 14.84
#  phone number = 01 019 5772  --  average call duration in mins : 15.31
#  phone number = 01 020 0786  --  average call duration in mins : 14.93
#  phone number = 01 020 1096  --  average call duration in mins : 15.37
#  phone number = 01 020 6183  --  average call duration in mins : 17.26
#  phone number = 01 020 7989  --  average call duration in mins : 17.33
#  phone number = 01 020 9379  --  average call duration in mins : 16.28
#  phone number = 01 021 2043  --  average call duration in mins : 17.04
#  phone number = 01 021 4367  --  average call duration in mins : 19.28
#  phone number = 01 021 5019  --  average call duration in mins : 16.24
#  phone number = 01 021 5942  --  average call duration in mins : 13.07
#  phone number = 01 022 1093  --  average call duration in mins : 12.56
#  phone number = 01 022 2769  --  average call duration in mins : 16.96
#  phone number = 01 023 1536  --  average call duration in mins : 16.30
#  phone number = 01 023 6034  --  average call duration in mins : 14.52
#  phone number = 01 023 8054  --  average call duration in mins : 12.75
#  phone number = 01 025 2912  --  average call duration in mins : 13.72
#  phone number = 01 025 5897  --  average call duration in mins : 19.64
#  phone number = 01 025 6508  --  average call duration in mins : 15.99
#  phone number = 01 025 6891  --  average call duration in mins : 10.85
#  phone number = 01 025 7679  --  average call duration in mins : 13.42
#  phone number = 01 026 1446  --  average call duration in mins : 17.01
#  phone number = 01 026 5303  --  average call duration in mins : 18.46
#  phone number = 01 026 8589  --  average call duration in mins : 13.89
#  phone number = 01 027 3127  --  average call duration in mins : 15.05
#  phone number = 01 027 6544  --  average call duration in mins : 13.38
#  phone number = 01 027 7838  --  average call duration in mins : 17.69
#  phone number = 01 028 5379  --  average call duration in mins : 14.78
#  phone number = 01 028 7785  --  average call duration in mins : 16.23
#  phone number = 01 029 5689  --  average call duration in mins : 12.86
#  phone number = 01 029 6454  --  average call duration in mins : 17.89
#  phone number = 01 029 8602  --  average call duration in mins : 16.53
#  phone number = 01 029 9299  --  average call duration in mins : 14.14
#  phone number = 01 030 0622  --  average call duration in mins : 16.77
#  phone number = 01 030 5462  --  average call duration in mins : 10.26
#  phone number = 01 031 1696  --  average call duration in mins : 18.52
#  phone number = 01 031 7619  --  average call duration in mins : 13.12
#  phone number = 01 031 8008  --  average call duration in mins : 16.44
#  phone number = 01 033 6968  --  average call duration in mins : 11.18
#  phone number = 01 034 3280  --  average call duration in mins : 13.58
#  phone number = 01 036 2386  --  average call duration in mins : 16.72
#  phone number = 01 036 2438  --  average call duration in mins : 16.87
#  phone number = 01 036 5399  --  average call duration in mins : 13.73
#  phone number = 01 038 0026  --  average call duration in mins : 20.06
#  phone number = 01 038 1351  --  average call duration in mins : 12.59
#  phone number = 01 038 5176  --  average call duration in mins : 15.42
#  phone number = 01 038 6331  --  average call duration in mins : 7.38
#  phone number = 01 039 0574  --  average call duration in mins : 16.46
#  phone number = 01 040 2094  --  average call duration in mins : 12.05
#  phone number = 01 040 5603  --  average call duration in mins : 16.85
#  phone number = 01 040 6754  --  average call duration in mins : 20.25
#  phone number = 01 040 7065  --  average call duration in mins : 16.49
#  phone number = 01 040 8055  --  average call duration in mins : 12.85
#  phone number = 01 041 0679  --  average call duration in mins : 16.56
#  phone number = 01 041 2527  --  average call duration in mins : 13.34
#  phone number = 01 041 8034  --  average call duration in mins : 26.06
#  phone number = 01 042 1549  --  average call duration in mins : 16.69
#  phone number = 01 042 4350  --  average call duration in mins : 28.42
#  phone number = 01 042 5622  --  average call duration in mins : 18.80
#  phone number = 01 042 9157  --  average call duration in mins : 17.75
#  phone number = 01 043 6513  --  average call duration in mins : 12.01
#  phone number = 01 044 2909  --  average call duration in mins : 11.20
#  phone number = 01 045 3778  --  average call duration in mins : 13.60
#  phone number = 01 045 9305  --  average call duration in mins : 12.68
#  phone number = 01 046 1809  --  average call duration in mins : 16.14
#  phone number = 01 046 2525  --  average call duration in mins : 7.20
#  phone number = 01 046 7656  --  average call duration in mins : 15.10
#  phone number = 01 047 1637  --  average call duration in mins : 15.05
#  phone number = 01 047 6919  --  average call duration in mins : 16.33
#  phone number = 01 048 3321  --  average call duration in mins : 13.29
#  phone number = 01 049 3297  --  average call duration in mins : 11.36
#  phone number = 01 049 6783  --  average call duration in mins : 14.62
#  phone number = 01 049 9980  --  average call duration in mins : 14.95
#  phone number = 01 050 1589  --  average call duration in mins : 13.55
#  phone number = 01 050 9912  --  average call duration in mins : 16.22
#  phone number = 01 051 5064  --  average call duration in mins : 16.55
#  phone number = 01 051 6305  --  average call duration in mins : 13.56
#  phone number = 01 051 7089  --  average call duration in mins : 14.94
#  phone number = 01 052 8765  --  average call duration in mins : 16.65
#  phone number = 01 053 1264  --  average call duration in mins : 17.63
#  phone number = 01 054 1555  --  average call duration in mins : 12.44
#  phone number = 01 054 1611  --  average call duration in mins : 13.83
#  phone number = 01 055 3380  --  average call duration in mins : 12.53
#  phone number = 01 055 4064  --  average call duration in mins : 15.51
#  phone number = 01 056 4534  --  average call duration in mins : 22.94
#  phone number = 01 056 8501  --  average call duration in mins : 18.34
#  phone number = 01 057 1498  --  average call duration in mins : 14.06
#  phone number = 01 057 6955  --  average call duration in mins : 14.83
#  phone number = 01 058 1435  --  average call duration in mins : 18.39
#  phone number = 01 058 6889  --  average call duration in mins : 14.22
#  phone number = 01 059 1117  --  average call duration in mins : 12.96
#  phone number = 01 059 3596  --  average call duration in mins : 15.30
#  phone number = 01 059 8202  --  average call duration in mins : 16.20
#  phone number = 01 059 9597  --  average call duration in mins : 16.36
#  phone number = 01 060 5603  --  average call duration in mins : 13.42
#  phone number = 01 060 6515  --  average call duration in mins : 18.57
#  phone number = 01 060 7849  --  average call duration in mins : 15.85
#  phone number = 01 061 2698  --  average call duration in mins : 13.66
#  phone number = 01 061 7312  --  average call duration in mins : 13.29
#  phone number = 01 062 1387  --  average call duration in mins : 14.28
#  phone number = 01 062 4505  --  average call duration in mins : 13.92
#  phone number = 01 062 6478  --  average call duration in mins : 17.78
#  phone number = 01 062 6717  --  average call duration in mins : 16.67
#  phone number = 01 062 7978  --  average call duration in mins : 14.00
#  phone number = 01 063 9249  --  average call duration in mins : 17.16
#  phone number = 01 064 9939  --  average call duration in mins : 11.53
#  phone number = 01 065 9063  --  average call duration in mins : 14.19
#  phone number = 01 066 4390  --  average call duration in mins : 14.61
#  phone number = 01 067 7684  --  average call duration in mins : 15.48
#  phone number = 01 067 9625  --  average call duration in mins : 14.01
#  phone number = 01 068 3946  --  average call duration in mins : 16.80
#  phone number = 01 068 6894  --  average call duration in mins : 13.04
#  phone number = 01 071 1196  --  average call duration in mins : 19.62
#  phone number = 01 071 5324  --  average call duration in mins : 16.30
#  phone number = 01 071 7402  --  average call duration in mins : 15.60
#  phone number = 01 072 3292  --  average call duration in mins : 15.38
#  phone number = 01 072 5523  --  average call duration in mins : 10.73
#  phone number = 01 073 3754  --  average call duration in mins : 11.31
#  phone number = 01 073 6007  --  average call duration in mins : 16.83
#  phone number = 01 074 4230  --  average call duration in mins : 9.09
#  phone number = 01 074 4857  --  average call duration in mins : 15.83
#  phone number = 01 075 2041  --  average call duration in mins : 14.34
#  phone number = 01 076 8087  --  average call duration in mins : 13.48
#  phone number = 01 077 5662  --  average call duration in mins : 12.42
#  phone number = 01 077 9376  --  average call duration in mins : 15.28
#  phone number = 01 078 3073  --  average call duration in mins : 13.40
#  phone number = 01 078 5248  --  average call duration in mins : 13.79
#  phone number = 01 078 7201  --  average call duration in mins : 14.47
#  phone number = 01 078 9022  --  average call duration in mins : 16.78
#  phone number = 01 079 7078  --  average call duration in mins : 21.04
#  phone number = 01 079 9635  --  average call duration in mins : 14.19
#  phone number = 01 080 0105  --  average call duration in mins : 16.22
#  phone number = 01 080 1036  --  average call duration in mins : 16.31
#  phone number = 01 080 1220  --  average call duration in mins : 18.41
#  phone number = 01 080 3589  --  average call duration in mins : 13.01
#  phone number = 01 080 4058  --  average call duration in mins : 15.50
#  phone number = 01 080 5748  --  average call duration in mins : 16.60
#  phone number = 01 080 6020  --  average call duration in mins : 18.85
#  phone number = 01 080 6043  --  average call duration in mins : 27.28
#  phone number = 01 080 8799  --  average call duration in mins : 15.32
#  phone number = 01 080 9502  --  average call duration in mins : 15.73
#  phone number = 01 080 9716  --  average call duration in mins : 12.18
#  phone number = 01 081 4561  --  average call duration in mins : 17.02
#  phone number = 01 081 4566  --  average call duration in mins : 15.34
#  phone number = 01 081 8458  --  average call duration in mins : 13.87
#  phone number = 01 081 9637  --  average call duration in mins : 10.29
#  phone number = 01 082 1105  --  average call duration in mins : 17.45
#  phone number = 01 082 4718  --  average call duration in mins : 8.71
#  phone number = 01 082 9004  --  average call duration in mins : 14.12
#  phone number = 01 083 0997  --  average call duration in mins : 4.35
#  phone number = 01 085 0209  --  average call duration in mins : 15.31
#  phone number = 01 085 3475  --  average call duration in mins : 8.21
#  phone number = 01 085 4787  --  average call duration in mins : 17.23
#  phone number = 01 085 9247  --  average call duration in mins : 15.69
#  phone number = 01 086 0400  --  average call duration in mins : 16.10
#  phone number = 01 086 7028  --  average call duration in mins : 13.36
#  phone number = 01 086 7661  --  average call duration in mins : 18.29
#  phone number = 01 087 6846  --  average call duration in mins : 13.67
#  phone number = 01 087 7025  --  average call duration in mins : 10.58
#  phone number = 01 088 0475  --  average call duration in mins : 10.58
#  phone number = 01 088 6093  --  average call duration in mins : 15.73
#  phone number = 01 088 6733  --  average call duration in mins : 17.11
#  phone number = 01 089 0549  --  average call duration in mins : 14.73
#  phone number = 01 089 6127  --  average call duration in mins : 10.84
#  phone number = 01 090 2350  --  average call duration in mins : 15.66
#  phone number = 01 090 3690  --  average call duration in mins : 12.44
#  phone number = 01 091 3191  --  average call duration in mins : 16.58
#  phone number = 01 091 4461  --  average call duration in mins : 14.60
#  phone number = 01 091 5387  --  average call duration in mins : 14.79
#  phone number = 01 091 9901  --  average call duration in mins : 13.73
#  phone number = 01 093 0318  --  average call duration in mins : 13.71
#  phone number = 01 093 3659  --  average call duration in mins : 14.15
#  phone number = 01 093 5026  --  average call duration in mins : 13.31
#  phone number = 01 094 2631  --  average call duration in mins : 14.81
#  phone number = 01 094 7572  --  average call duration in mins : 16.11
#  phone number = 01 095 5179  --  average call duration in mins : 16.77
#  phone number = 01 095 6183  --  average call duration in mins : 13.88
#  phone number = 01 095 7173  --  average call duration in mins : 14.67
#  phone number = 01 096 1539  --  average call duration in mins : 15.38
#  phone number = 01 097 9221  --  average call duration in mins : 16.91
#  phone number = 01 098 4438  --  average call duration in mins : 21.61
#  phone number = 01 098 8776  --  average call duration in mins : 15.02
#  phone number = 01 099 0689  --  average call duration in mins : 12.77
#  phone number = 01 099 1853  --  average call duration in mins : 12.73
#  phone number = 01 099 5443  --  average call duration in mins : 13.87
#  phone number = 01 099 6113  --  average call duration in mins : 14.88
#  phone number = 01 099 8585  --  average call duration in mins : 14.79
#  phone number = 01 100 3828  --  average call duration in mins : 16.53
#  phone number = 01 100 4959  --  average call duration in mins : 13.08
#  phone number = 01 100 5312  --  average call duration in mins : 17.42
#  phone number = 01 100 6767  --  average call duration in mins : 14.01
#  phone number = 01 101 0122  --  average call duration in mins : 17.18
#  phone number = 01 101 4205  --  average call duration in mins : 16.19
#  phone number = 01 101 5266  --  average call duration in mins : 16.29
#  phone number = 01 101 5451  --  average call duration in mins : 13.49
#  phone number = 01 101 7036  --  average call duration in mins : 14.51
#  phone number = 01 102 3250  --  average call duration in mins : 16.88
#  phone number = 01 102 5743  --  average call duration in mins : 15.12
#  phone number = 01 103 5669  --  average call duration in mins : 17.79
#  phone number = 01 103 8315  --  average call duration in mins : 16.24
#  phone number = 01 104 0513  --  average call duration in mins : 19.37
#  phone number = 01 104 0620  --  average call duration in mins : 15.06
#  phone number = 01 104 2635  --  average call duration in mins : 16.80
#  phone number = 01 104 4540  --  average call duration in mins : 14.86
#  phone number = 01 104 7507  --  average call duration in mins : 13.95
#  phone number = 01 104 8816  --  average call duration in mins : 17.76
#  phone number = 01 105 1378  --  average call duration in mins : 12.92
#  phone number = 01 105 2419  --  average call duration in mins : 16.44
#  phone number = 01 106 0144  --  average call duration in mins : 11.70
#  phone number = 01 106 0847  --  average call duration in mins : 15.25
#  phone number = 01 106 2284  --  average call duration in mins : 13.30
#  phone number = 01 106 9634  --  average call duration in mins : 13.29
#  phone number = 01 107 0324  --  average call duration in mins : 14.52
#  phone number = 01 108 0021  --  average call duration in mins : 14.53
#  phone number = 01 108 0816  --  average call duration in mins : 17.24
#  phone number = 01 108 2515  --  average call duration in mins : 12.79
#  phone number = 01 109 0966  --  average call duration in mins : 11.61
#  phone number = 01 109 2515  --  average call duration in mins : 13.54
#  phone number = 01 109 6735  --  average call duration in mins : 15.88
#  phone number = 01 109 6982  --  average call duration in mins : 19.66
#  phone number = 01 109 8748  --  average call duration in mins : 15.61
#  phone number = 01 110 0724  --  average call duration in mins : 16.22
#  phone number = 01 110 4632  --  average call duration in mins : 15.77
#  phone number = 01 110 6536  --  average call duration in mins : 18.31
#  phone number = 01 110 8390  --  average call duration in mins : 35.06
#  phone number = 01 110 8839  --  average call duration in mins : 15.44
#  phone number = 01 110 9700  --  average call duration in mins : 11.20
#  phone number = 01 111 0448  --  average call duration in mins : 15.56
#  phone number = 01 112 1838  --  average call duration in mins : 15.66
#  phone number = 01 112 6336  --  average call duration in mins : 13.49
#  phone number = 01 113 3918  --  average call duration in mins : 16.95
#  phone number = 01 113 4041  --  average call duration in mins : 10.74
#  phone number = 01 113 9048  --  average call duration in mins : 17.89
#  phone number = 01 114 2425  --  average call duration in mins : 16.14
#  phone number = 01 114 8854  --  average call duration in mins : 17.75
#  phone number = 01 115 0744  --  average call duration in mins : 16.64
#  phone number = 01 115 5361  --  average call duration in mins : 12.72
#  phone number = 01 115 6043  --  average call duration in mins : 10.85
#  phone number = 01 115 8888  --  average call duration in mins : 19.53
#  phone number = 01 116 2405  --  average call duration in mins : 19.12
#  phone number = 01 116 2490  --  average call duration in mins : 15.92
#  phone number = 01 116 7820  --  average call duration in mins : 15.97
#  phone number = 01 116 7986  --  average call duration in mins : 14.19
#  phone number = 01 117 1364  --  average call duration in mins : 17.92
#  phone number = 01 117 4702  --  average call duration in mins : 12.82
#  phone number = 01 117 5538  --  average call duration in mins : 13.41
#  phone number = 01 117 6176  --  average call duration in mins : 12.82
#  phone number = 01 117 7199  --  average call duration in mins : 12.32
#  phone number = 01 118 3666  --  average call duration in mins : 14.74
#  phone number = 01 118 3689  --  average call duration in mins : 28.75
#  phone number = 01 118 4164  --  average call duration in mins : 12.03
#  phone number = 01 118 7246  --  average call duration in mins : 12.99
#  phone number = 01 118 9489  --  average call duration in mins : 18.32
#  phone number = 01 118 9715  --  average call duration in mins : 16.30
#  phone number = 01 119 4349  --  average call duration in mins : 9.16
#  phone number = 01 119 5352  --  average call duration in mins : 14.59
#  phone number = 01 119 9126  --  average call duration in mins : 12.49
#  phone number = 01 120 0757  --  average call duration in mins : 13.16
#  phone number = 01 120 0772  --  average call duration in mins : 13.04
#  phone number = 01 120 7794  --  average call duration in mins : 13.34
#  phone number = 01 120 9576  --  average call duration in mins : 13.09
#  phone number = 01 121 3013  --  average call duration in mins : 16.74
#  phone number = 01 121 4075  --  average call duration in mins : 15.82
#  phone number = 01 121 8920  --  average call duration in mins : 23.43
#  phone number = 01 121 9246  --  average call duration in mins : 12.86
#  phone number = 01 122 5643  --  average call duration in mins : 14.46
#  phone number = 01 122 8155  --  average call duration in mins : 18.88
#  phone number = 01 122 8982  --  average call duration in mins : 13.36
#  phone number = 01 123 3207  --  average call duration in mins : 15.90
#  phone number = 01 123 4401  --  average call duration in mins : 10.68
#  phone number = 01 123 6751  --  average call duration in mins : 14.28
#  phone number = 01 123 9294  --  average call duration in mins : 13.99
#  phone number = 01 124 1137  --  average call duration in mins : 14.57
#  phone number = 01 124 8133  --  average call duration in mins : 9.73
#  phone number = 01 125 4223  --  average call duration in mins : 12.56
#  phone number = 01 125 4831  --  average call duration in mins : 15.99
#  phone number = 01 125 6352  --  average call duration in mins : 13.83
#  phone number = 01 125 7323  --  average call duration in mins : 15.31
#  phone number = 01 126 5554  --  average call duration in mins : 15.98
#  phone number = 01 127 6482  --  average call duration in mins : 14.65
#  phone number = 01 127 9548  --  average call duration in mins : 16.10
#  phone number = 01 129 5428  --  average call duration in mins : 14.39
#  phone number = 01 129 5848  --  average call duration in mins : 15.79
#  phone number = 01 129 7514  --  average call duration in mins : 17.12
#  phone number = 01 130 6190  --  average call duration in mins : 15.99
#  phone number = 01 130 6495  --  average call duration in mins : 18.14
#  phone number = 01 131 1010  --  average call duration in mins : 17.04
#  phone number = 01 131 2670  --  average call duration in mins : 13.93
#  phone number = 01 131 3929  --  average call duration in mins : 18.01
#  phone number = 01 131 7338  --  average call duration in mins : 18.71
#  phone number = 01 132 1436  --  average call duration in mins : 13.01
#  phone number = 01 132 1904  --  average call duration in mins : 18.13
#  phone number = 01 132 5695  --  average call duration in mins : 13.77
#  phone number = 01 132 8893  --  average call duration in mins : 17.00
#  phone number = 01 133 1507  --  average call duration in mins : 14.06
#  phone number = 01 134 7272  --  average call duration in mins : 18.09
#  phone number = 01 135 1366  --  average call duration in mins : 10.51
#  phone number = 01 135 1423  --  average call duration in mins : 13.55
#  phone number = 01 136 7321  --  average call duration in mins : 12.07
#  phone number = 01 137 1576  --  average call duration in mins : 15.96
#  phone number = 01 137 5238  --  average call duration in mins : 14.70
#  phone number = 01 137 5885  --  average call duration in mins : 14.59
#  phone number = 01 137 7256  --  average call duration in mins : 15.89
#  phone number = 01 138 0205  --  average call duration in mins : 18.80
#  phone number = 01 139 2949  --  average call duration in mins : 12.85
#  phone number = 01 140 5404  --  average call duration in mins : 15.14
#  phone number = 01 140 8199  --  average call duration in mins : 15.34
#  phone number = 01 141 0080  --  average call duration in mins : 14.64
#  phone number = 01 141 0504  --  average call duration in mins : 17.83
#  phone number = 01 142 3394  --  average call duration in mins : 19.14
#  phone number = 01 142 3409  --  average call duration in mins : 15.93
#  phone number = 01 143 1824  --  average call duration in mins : 14.51
#  phone number = 01 143 6965  --  average call duration in mins : 15.73
#  phone number = 01 143 8073  --  average call duration in mins : 18.76
#  phone number = 01 144 3410  --  average call duration in mins : 18.13
#  phone number = 01 144 6368  --  average call duration in mins : 10.13
#  phone number = 01 144 8110  --  average call duration in mins : 15.45
#  phone number = 01 146 4477  --  average call duration in mins : 15.95
#  phone number = 01 147 1997  --  average call duration in mins : 13.65
#  phone number = 01 147 4551  --  average call duration in mins : 15.81
#  phone number = 01 147 9607  --  average call duration in mins : 15.30
#  phone number = 01 148 3325  --  average call duration in mins : 16.21
#  phone number = 01 148 3612  --  average call duration in mins : 18.63
#  phone number = 01 148 5574  --  average call duration in mins : 12.64
#  phone number = 01 148 6430  --  average call duration in mins : 10.63
#  phone number = 01 149 9236  --  average call duration in mins : 13.39
#  phone number = 01 149 9413  --  average call duration in mins : 17.99
#  phone number = 01 150 1632  --  average call duration in mins : 19.17
#  phone number = 01 150 1673  --  average call duration in mins : 21.60
#  phone number = 01 150 3230  --  average call duration in mins : 16.74
#  phone number = 01 150 4389  --  average call duration in mins : 13.35
#  phone number = 01 150 5142  --  average call duration in mins : 14.72
#  phone number = 01 151 0818  --  average call duration in mins : 13.23
#  phone number = 01 151 0845  --  average call duration in mins : 15.48
#  phone number = 01 151 2521  --  average call duration in mins : 15.19
#  phone number = 01 151 2782  --  average call duration in mins : 15.29
#  phone number = 01 151 6551  --  average call duration in mins : 18.34
#  phone number = 01 151 6643  --  average call duration in mins : 17.91
#  phone number = 01 152 3397  --  average call duration in mins : 14.01
#  phone number = 01 153 7935  --  average call duration in mins : 16.94
#  phone number = 01 153 8674  --  average call duration in mins : 13.23
#  phone number = 01 154 7337  --  average call duration in mins : 16.29
#  phone number = 01 156 4753  --  average call duration in mins : 8.96
#  phone number = 01 156 5486  --  average call duration in mins : 14.01
#  phone number = 01 156 7305  --  average call duration in mins : 16.57
#  phone number = 01 156 8421  --  average call duration in mins : 15.52
#  phone number = 01 156 9548  --  average call duration in mins : 17.54
#  phone number = 01 157 0608  --  average call duration in mins : 12.81
#  phone number = 01 157 9991  --  average call duration in mins : 15.66
#  phone number = 01 158 6402  --  average call duration in mins : 18.37
#  phone number = 01 158 7062  --  average call duration in mins : 18.41
#  phone number = 01 158 7833  --  average call duration in mins : 16.52
#  phone number = 01 158 8895  --  average call duration in mins : 14.95
#  phone number = 01 158 9429  --  average call duration in mins : 14.07
#  phone number = 01 159 0347  --  average call duration in mins : 13.51
#  phone number = 01 159 0855  --  average call duration in mins : 13.81
#  phone number = 01 159 8591  --  average call duration in mins : 12.94
#  phone number = 01 160 2803  --  average call duration in mins : 6.83
#  phone number = 01 160 4028  --  average call duration in mins : 11.06
#  phone number = 01 160 8117  --  average call duration in mins : 13.48
#  phone number = 01 161 8741  --  average call duration in mins : 14.55
#  phone number = 01 162 0261  --  average call duration in mins : 13.19
#  phone number = 01 162 5934  --  average call duration in mins : 17.02
#  phone number = 01 163 3058  --  average call duration in mins : 15.44
#  phone number = 01 165 0885  --  average call duration in mins : 14.87
#  phone number = 01 166 0928  --  average call duration in mins : 18.74
#  phone number = 01 166 6119  --  average call duration in mins : 13.91
#  phone number = 01 166 6140  --  average call duration in mins : 13.65
#  phone number = 01 166 6768  --  average call duration in mins : 15.53
#  phone number = 01 167 1683  --  average call duration in mins : 17.67
#  phone number = 01 167 7379  --  average call duration in mins : 13.21
#  phone number = 01 168 0445  --  average call duration in mins : 13.52
#  phone number = 01 168 3717  --  average call duration in mins : 15.64
#  phone number = 01 168 9604  --  average call duration in mins : 15.96
#  phone number = 01 169 2437  --  average call duration in mins : 14.60
#  phone number = 01 170 1428  --  average call duration in mins : 11.02
#  phone number = 01 170 8358  --  average call duration in mins : 17.49
#  phone number = 01 171 0815  --  average call duration in mins : 11.32
#  phone number = 01 171 1252  --  average call duration in mins : 15.17
#  phone number = 01 171 1438  --  average call duration in mins : 12.37
#  phone number = 01 171 5319  --  average call duration in mins : 17.75
#  phone number = 01 172 0308  --  average call duration in mins : 14.56
#  phone number = 01 172 6812  --  average call duration in mins : 19.56
#  phone number = 01 172 7725  --  average call duration in mins : 10.93
#  phone number = 01 173 0215  --  average call duration in mins : 13.36
#  phone number = 01 173 1780  --  average call duration in mins : 16.42
#  phone number = 01 173 2196  --  average call duration in mins : 16.27
#  phone number = 01 173 3215  --  average call duration in mins : 12.24
#  phone number = 01 173 5928  --  average call duration in mins : 13.71
#  phone number = 01 173 7904  --  average call duration in mins : 19.13
#  phone number = 01 174 2362  --  average call duration in mins : 12.07
#  phone number = 01 174 4997  --  average call duration in mins : 13.99
#  phone number = 01 174 6137  --  average call duration in mins : 10.52
#  phone number = 01 175 2891  --  average call duration in mins : 15.52
#  phone number = 01 175 5988  --  average call duration in mins : 13.71
#  phone number = 01 175 6813  --  average call duration in mins : 14.96
#  phone number = 01 175 7126  --  average call duration in mins : 17.77
#  phone number = 01 176 7457  --  average call duration in mins : 18.00
#  phone number = 01 177 0952  --  average call duration in mins : 8.10
#  phone number = 01 177 4165  --  average call duration in mins : 13.90
#  phone number = 01 177 4863  --  average call duration in mins : 12.04
#  phone number = 01 178 6757  --  average call duration in mins : 19.06
#  phone number = 01 180 3115  --  average call duration in mins : 17.15
#  phone number = 01 180 4661  --  average call duration in mins : 16.15
#  phone number = 01 180 9556  --  average call duration in mins : 16.03
#  phone number = 01 181 1680  --  average call duration in mins : 14.22
#  phone number = 01 181 6124  --  average call duration in mins : 15.36
#  phone number = 01 182 3297  --  average call duration in mins : 12.89
#  phone number = 01 182 4112  --  average call duration in mins : 15.70
#  phone number = 01 183 2755  --  average call duration in mins : 17.88
#  phone number = 01 183 3850  --  average call duration in mins : 14.96
#  phone number = 01 183 9718  --  average call duration in mins : 14.12
#  phone number = 01 184 0672  --  average call duration in mins : 19.03
#  phone number = 01 185 2943  --  average call duration in mins : 15.32
#  phone number = 01 185 4094  --  average call duration in mins : 14.51
#  phone number = 01 185 8476  --  average call duration in mins : 14.11
#  phone number = 01 186 4068  --  average call duration in mins : 14.13
#  phone number = 01 187 1140  --  average call duration in mins : 14.27
#  phone number = 01 187 3845  --  average call duration in mins : 15.78
#  phone number = 01 187 4164  --  average call duration in mins : 13.83
#  phone number = 01 187 7119  --  average call duration in mins : 20.00
#  phone number = 01 188 1642  --  average call duration in mins : 15.51
#  phone number = 01 188 1943  --  average call duration in mins : 20.33
#  phone number = 01 188 8208  --  average call duration in mins : 16.38
#  phone number = 01 189 7404  --  average call duration in mins : 17.97
#  phone number = 01 189 8206  --  average call duration in mins : 16.95
#  phone number = 01 190 2516  --  average call duration in mins : 12.87
#  phone number = 01 190 4183  --  average call duration in mins : 9.30
#  phone number = 01 190 8424  --  average call duration in mins : 15.94
#  phone number = 01 190 9802  --  average call duration in mins : 17.26
#  phone number = 01 191 2566  --  average call duration in mins : 17.57
#  phone number = 01 191 4804  --  average call duration in mins : 17.34
#  phone number = 01 191 9303  --  average call duration in mins : 13.12
#  phone number = 01 192 3852  --  average call duration in mins : 14.70
#  phone number = 01 192 6771  --  average call duration in mins : 20.73
#  phone number = 01 192 7529  --  average call duration in mins : 13.55
#  phone number = 01 192 7626  --  average call duration in mins : 7.27
#  phone number = 01 194 3068  --  average call duration in mins : 11.33
#  phone number = 01 194 5162  --  average call duration in mins : 15.25
#  phone number = 01 194 5183  --  average call duration in mins : 17.34
#  phone number = 01 194 6183  --  average call duration in mins : 14.09
#  phone number = 01 194 8039  --  average call duration in mins : 12.58
#  phone number = 01 195 0468  --  average call duration in mins : 16.66
#  phone number = 01 195 3899  --  average call duration in mins : 16.96
#  phone number = 01 195 4785  --  average call duration in mins : 16.63
#  phone number = 01 195 5842  --  average call duration in mins : 13.92
#  phone number = 01 195 7265  --  average call duration in mins : 13.73
#  phone number = 01 196 5075  --  average call duration in mins : 10.25
#  phone number = 01 196 7964  --  average call duration in mins : 20.00
#  phone number = 01 197 0761  --  average call duration in mins : 19.34
#  phone number = 01 197 1057  --  average call duration in mins : 21.94
#  phone number = 01 197 7672  --  average call duration in mins : 15.55
#  phone number = 01 197 8891  --  average call duration in mins : 28.09
#  phone number = 01 198 0288  --  average call duration in mins : 17.58
#  phone number = 01 198 0950  --  average call duration in mins : 14.32
#  phone number = 01 198 3417  --  average call duration in mins : 17.05
#  phone number = 01 198 5897  --  average call duration in mins : 16.82
#  phone number = 01 199 1016  --  average call duration in mins : 13.28
#  phone number = 01 199 6268  --  average call duration in mins : 15.53
#  phone number = 01 200 0011  --  average call duration in mins : 23.72
#  phone number = 01 200 1319  --  average call duration in mins : 16.76
#  phone number = 01 201 2567  --  average call duration in mins : 18.88
#  phone number = 01 201 2682  --  average call duration in mins : 14.75
#  phone number = 01 201 5556  --  average call duration in mins : 14.45
#  phone number = 01 201 6093  --  average call duration in mins : 14.20
#  phone number = 01 201 6140  --  average call duration in mins : 15.05
#  phone number = 01 202 0237  --  average call duration in mins : 35.48
#  phone number = 01 202 0353  --  average call duration in mins : 13.06
#  phone number = 01 202 0384  --  average call duration in mins : 13.39
#  phone number = 01 202 2201  --  average call duration in mins : 15.78
#  phone number = 01 202 6439  --  average call duration in mins : 11.33
#  phone number = 01 203 2213  --  average call duration in mins : 12.89
#  phone number = 01 203 2991  --  average call duration in mins : 12.57
#  phone number = 01 203 4015  --  average call duration in mins : 18.35
#  phone number = 01 203 9468  --  average call duration in mins : 13.42
#  phone number = 01 204 5594  --  average call duration in mins : 16.23
#  phone number = 01 205 2242  --  average call duration in mins : 17.20
#  phone number = 01 205 7529  --  average call duration in mins : 11.81
#  phone number = 01 205 8305  --  average call duration in mins : 14.42
#  phone number = 01 205 9689  --  average call duration in mins : 10.22
#  phone number = 01 205 9705  --  average call duration in mins : 14.60
#  phone number = 01 206 4995  --  average call duration in mins : 18.07
#  phone number = 01 206 7443  --  average call duration in mins : 21.27
#  phone number = 01 207 7024  --  average call duration in mins : 17.93
#  phone number = 01 208 1902  --  average call duration in mins : 16.74
#  phone number = 01 208 3579  --  average call duration in mins : 21.22
#  phone number = 01 208 4478  --  average call duration in mins : 16.12
#  phone number = 01 208 6879  --  average call duration in mins : 15.32
#  phone number = 01 209 0819  --  average call duration in mins : 12.99
#  phone number = 01 209 1612  --  average call duration in mins : 14.38
#  phone number = 01 209 5912  --  average call duration in mins : 18.43
#  phone number = 01 211 3425  --  average call duration in mins : 15.85
#  phone number = 01 211 5140  --  average call duration in mins : 16.94
#  phone number = 01 211 6541  --  average call duration in mins : 15.08
#  phone number = 01 211 7104  --  average call duration in mins : 14.66
#  phone number = 01 212 0290  --  average call duration in mins : 9.60
#  phone number = 01 212 4291  --  average call duration in mins : 16.86
#  phone number = 01 212 9923  --  average call duration in mins : 14.90
#  phone number = 01 213 2476  --  average call duration in mins : 20.24
#  phone number = 01 213 3660  --  average call duration in mins : 13.76
#  phone number = 01 213 8819  --  average call duration in mins : 13.18
#  phone number = 01 214 0664  --  average call duration in mins : 14.38
#  phone number = 01 214 1610  --  average call duration in mins : 15.05
#  phone number = 01 214 8720  --  average call duration in mins : 12.77
#  phone number = 01 215 4902  --  average call duration in mins : 13.96
#  phone number = 01 215 5448  --  average call duration in mins : 15.73
#  phone number = 01 215 7116  --  average call duration in mins : 14.99
#  phone number = 01 216 0513  --  average call duration in mins : 12.28
#  phone number = 01 216 6453  --  average call duration in mins : 14.63
#  phone number = 01 217 5335  --  average call duration in mins : 16.88
#  phone number = 01 217 5877  --  average call duration in mins : 22.70
#  phone number = 01 217 7550  --  average call duration in mins : 15.28
#  phone number = 01 217 8310  --  average call duration in mins : 15.21
#  phone number = 01 218 0890  --  average call duration in mins : 15.65
#  phone number = 01 218 6927  --  average call duration in mins : 9.43
#  phone number = 01 219 0775  --  average call duration in mins : 11.71
#  phone number = 01 219 2711  --  average call duration in mins : 15.37
#  phone number = 01 219 5055  --  average call duration in mins : 13.86
#  phone number = 01 219 6067  --  average call duration in mins : 13.71
#  phone number = 01 219 6215  --  average call duration in mins : 14.51
#  phone number = 01 220 2580  --  average call duration in mins : 14.72
#  phone number = 01 220 2663  --  average call duration in mins : 15.62
#  phone number = 01 220 9415  --  average call duration in mins : 11.08
#  phone number = 01 221 5212  --  average call duration in mins : 15.47
#  phone number = 01 221 5448  --  average call duration in mins : 16.86
#  phone number = 01 221 8813  --  average call duration in mins : 15.58
#  phone number = 01 222 3669  --  average call duration in mins : 19.08
#  phone number = 01 222 6311  --  average call duration in mins : 12.90
#  phone number = 01 222 7701  --  average call duration in mins : 15.21
#  phone number = 01 223 0244  --  average call duration in mins : 20.37
#  phone number = 01 224 0455  --  average call duration in mins : 15.07
#  phone number = 01 224 3963  --  average call duration in mins : 13.89
#  phone number = 01 225 6098  --  average call duration in mins : 13.97
#  phone number = 01 225 8073  --  average call duration in mins : 16.37
#  phone number = 01 226 2628  --  average call duration in mins : 14.81
#  phone number = 01 227 5263  --  average call duration in mins : 14.26
#  phone number = 01 227 9959  --  average call duration in mins : 15.15
#  phone number = 01 228 4949  --  average call duration in mins : 15.71
#  phone number = 01 228 9332  --  average call duration in mins : 13.96
#  phone number = 01 229 0394  --  average call duration in mins : 14.60
#  phone number = 01 229 1458  --  average call duration in mins : 13.07
#  phone number = 01 229 4703  --  average call duration in mins : 13.55
#  phone number = 01 229 8743  --  average call duration in mins : 18.06
#  phone number = 01 230 1940  --  average call duration in mins : 13.29
#  phone number = 01 230 2501  --  average call duration in mins : 14.33
#  phone number = 01 230 6971  --  average call duration in mins : 15.79
#  phone number = 01 230 9103  --  average call duration in mins : 17.51
#  phone number = 01 233 3287  --  average call duration in mins : 16.11
#  phone number = 01 233 8555  --  average call duration in mins : 15.13
#  phone number = 01 234 3803  --  average call duration in mins : 12.73
#  phone number = 01 234 4184  --  average call duration in mins : 15.72
#  phone number = 01 234 6120  --  average call duration in mins : 13.34
#  phone number = 01 235 0067  --  average call duration in mins : 13.80
#  phone number = 01 235 1869  --  average call duration in mins : 14.59
#  phone number = 01 235 3224  --  average call duration in mins : 13.45
#  phone number = 01 235 4880  --  average call duration in mins : 15.97
#  phone number = 01 235 7430  --  average call duration in mins : 11.86
#  phone number = 01 236 0519  --  average call duration in mins : 14.59
#  phone number = 01 236 6210  --  average call duration in mins : 16.37
#  phone number = 01 237 1047  --  average call duration in mins : 19.20
#  phone number = 01 237 9710  --  average call duration in mins : 14.74
#  phone number = 01 238 4133  --  average call duration in mins : 16.54
#  phone number = 01 238 8586  --  average call duration in mins : 14.15
#  phone number = 01 240 1383  --  average call duration in mins : 13.99
#  phone number = 01 240 4133  --  average call duration in mins : 14.12
#  phone number = 01 240 4690  --  average call duration in mins : 20.58
#  phone number = 01 240 5578  --  average call duration in mins : 11.69
#  phone number = 01 241 0489  --  average call duration in mins : 12.04
#  phone number = 01 241 9382  --  average call duration in mins : 14.42
#  phone number = 01 243 4778  --  average call duration in mins : 14.63
#  phone number = 01 243 5948  --  average call duration in mins : 16.71
#  phone number = 01 243 6450  --  average call duration in mins : 14.51
#  phone number = 01 244 2454  --  average call duration in mins : 15.46
#  phone number = 01 244 2646  --  average call duration in mins : 18.94
#  phone number = 01 244 2658  --  average call duration in mins : 12.43
#  phone number = 01 244 7105  --  average call duration in mins : 12.10
#  phone number = 01 244 7361  --  average call duration in mins : 13.61
#  phone number = 01 244 8806  --  average call duration in mins : 15.15
#  phone number = 01 245 5697  --  average call duration in mins : 17.98
#  phone number = 01 245 9534  --  average call duration in mins : 14.17
#  phone number = 01 246 5159  --  average call duration in mins : 11.38
#  phone number = 01 247 6613  --  average call duration in mins : 17.70
#  phone number = 01 247 8370  --  average call duration in mins : 15.16
#  phone number = 01 249 1090  --  average call duration in mins : 14.68
#  phone number = 01 249 1448  --  average call duration in mins : 13.02
#  phone number = 01 249 7746  --  average call duration in mins : 18.55
#  phone number = 01 250 3124  --  average call duration in mins : 15.42
#  phone number = 01 250 7386  --  average call duration in mins : 12.42
#  phone number = 01 250 9855  --  average call duration in mins : 17.95
#  phone number = 01 251 6227  --  average call duration in mins : 14.76
#  phone number = 01 251 9007  --  average call duration in mins : 19.13
#  phone number = 01 252 0685  --  average call duration in mins : 15.91
#  phone number = 01 252 2830  --  average call duration in mins : 19.33
#  phone number = 01 252 3527  --  average call duration in mins : 17.18
#  phone number = 01 253 6046  --  average call duration in mins : 12.82
#  phone number = 01 253 6161  --  average call duration in mins : 15.13
#  phone number = 01 253 7761  --  average call duration in mins : 13.64
#  phone number = 01 253 9964  --  average call duration in mins : 10.39
#  phone number = 01 254 8971  --  average call duration in mins : 13.24
#  phone number = 01 255 0256  --  average call duration in mins : 13.52
#  phone number = 01 255 8668  --  average call duration in mins : 15.46
#  phone number = 01 256 4296  --  average call duration in mins : 18.84
#  phone number = 01 256 4498  --  average call duration in mins : 17.77
#  phone number = 01 256 5219  --  average call duration in mins : 36.61
#  phone number = 01 257 0056  --  average call duration in mins : 6.49
#  phone number = 01 257 2235  --  average call duration in mins : 16.43
#  phone number = 01 257 8466  --  average call duration in mins : 16.22
#  phone number = 01 258 0694  --  average call duration in mins : 13.30
#  phone number = 01 258 4533  --  average call duration in mins : 15.00
#  phone number = 01 258 8772  --  average call duration in mins : 15.01
#  phone number = 01 259 1137  --  average call duration in mins : 15.79
#  phone number = 01 259 8086  --  average call duration in mins : 12.86
#  phone number = 01 259 8095  --  average call duration in mins : 13.87
#  phone number = 01 259 9107  --  average call duration in mins : 23.91
#  phone number = 01 260 0073  --  average call duration in mins : 14.18
#  phone number = 01 260 1450  --  average call duration in mins : 13.76
#  phone number = 01 260 4797  --  average call duration in mins : 17.21
#  phone number = 01 262 0194  --  average call duration in mins : 14.95
#  phone number = 01 262 2672  --  average call duration in mins : 17.06
#  phone number = 01 263 9539  --  average call duration in mins : 19.78
#  phone number = 01 264 0352  --  average call duration in mins : 15.89
#  phone number = 01 264 0835  --  average call duration in mins : 17.07
#  phone number = 01 264 6566  --  average call duration in mins : 19.70
#  phone number = 01 265 3934  --  average call duration in mins : 14.36
#  phone number = 01 266 2396  --  average call duration in mins : 19.21
#  phone number = 01 266 4464  --  average call duration in mins : 17.40
#  phone number = 01 266 4579  --  average call duration in mins : 14.74
#  phone number = 01 267 1304  --  average call duration in mins : 26.23
#  phone number = 01 267 3722  --  average call duration in mins : 15.85
#  phone number = 01 267 4419  --  average call duration in mins : 16.32
#  phone number = 01 268 7140  --  average call duration in mins : 20.12
#  phone number = 01 269 4612  --  average call duration in mins : 17.20
#  phone number = 01 271 8206  --  average call duration in mins : 16.92
#  phone number = 01 272 2488  --  average call duration in mins : 13.36
#  phone number = 01 272 5419  --  average call duration in mins : 14.35
#  phone number = 01 273 0693  --  average call duration in mins : 11.26
#  phone number = 01 274 2699  --  average call duration in mins : 12.75
#  phone number = 01 274 3705  --  average call duration in mins : 17.33
#  phone number = 01 274 6134  --  average call duration in mins : 13.86
# ...
#  phone number = 095 708 1099  --  average call duration in mins : 15.80
#  phone number = 095 737 1152  --  average call duration in mins : 15.33
#  phone number = 095 770 1007  --  average call duration in mins : 13.69
#  phone number = 095 773 9254  --  average call duration in mins : 13.26
#  phone number = 095 778 5357  --  average call duration in mins : 14.43
#  phone number = 095 785 7003  --  average call duration in mins : 9.76
#  phone number = 095 809 4048  --  average call duration in mins : 13.30
#  phone number = 095 860 7556  --  average call duration in mins : 15.65
#  phone number = 095 868 8733  --  average call duration in mins : 15.49
#  phone number = 095 873 9443  --  average call duration in mins : 16.47
#  phone number = 095 893 5103  --  average call duration in mins : 16.75
#  phone number = 095 910 5244  --  average call duration in mins : 13.61
#  phone number = 095 911 0660  --  average call duration in mins : 10.90
#  phone number = 095 930 6123  --  average call duration in mins : 8.47
#  phone number = 095 937 2294  --  average call duration in mins : 11.49
#  phone number = 095 943 2513  --  average call duration in mins : 17.66
#  phone number = 095 974 1555  --  average call duration in mins : 17.32
#  phone number = 095 988 3431  --  average call duration in mins : 13.72
#  phone number = 096 031 2027  --  average call duration in mins : 8.84
#  phone number = 096 049 6722  --  average call duration in mins : 17.05
#  phone number = 096 059 7711  --  average call duration in mins : 15.94
#  phone number = 096 163 8616  --  average call duration in mins : 10.71
#  phone number = 096 166 1215  --  average call duration in mins : 17.71
#  phone number = 096 171 7739  --  average call duration in mins : 21.20
#  phone number = 096 178 1757  --  average call duration in mins : 11.34
#  phone number = 096 186 4517  --  average call duration in mins : 14.17
#  phone number = 096 216 7538  --  average call duration in mins : 11.01
#  phone number = 096 217 0066  --  average call duration in mins : 38.69
#  phone number = 096 235 9352  --  average call duration in mins : 16.50
#  phone number = 096 240 7557  --  average call duration in mins : 15.09
#  phone number = 096 241 5530  --  average call duration in mins : 16.12
#  phone number = 096 245 2124  --  average call duration in mins : 10.91
#  phone number = 096 274 9944  --  average call duration in mins : 10.57
#  phone number = 096 303 9307  --  average call duration in mins : 14.19
#  phone number = 096 324 9242  --  average call duration in mins : 16.46
#  phone number = 096 356 6517  --  average call duration in mins : 13.79
#  phone number = 096 411 5000  --  average call duration in mins : 17.56
#  phone number = 096 425 4011  --  average call duration in mins : 19.45
#  phone number = 096 451 4366  --  average call duration in mins : 14.76
#  phone number = 096 481 4167  --  average call duration in mins : 13.60
#  phone number = 096 491 3734  --  average call duration in mins : 13.82
#  phone number = 096 553 0228  --  average call duration in mins : 13.55
#  phone number = 096 575 9818  --  average call duration in mins : 14.19
#  phone number = 096 583 0838  --  average call duration in mins : 13.26
#  phone number = 096 596 8412  --  average call duration in mins : 14.87
#  phone number = 096 624 6086  --  average call duration in mins : 15.10
#  phone number = 096 625 8463  --  average call duration in mins : 16.94
#  phone number = 096 628 0190  --  average call duration in mins : 12.62
#  phone number = 096 660 8648  --  average call duration in mins : 15.53
#  phone number = 096 675 2696  --  average call duration in mins : 11.17
#  phone number = 096 721 2926  --  average call duration in mins : 14.71
#  phone number = 096 724 1328  --  average call duration in mins : 16.90
#  phone number = 096 760 4136  --  average call duration in mins : 16.31
#  phone number = 096 762 4518  --  average call duration in mins : 15.57
#  phone number = 096 762 5554  --  average call duration in mins : 15.10
#  phone number = 096 776 3415  --  average call duration in mins : 15.95
#  phone number = 096 778 6309  --  average call duration in mins : 17.24
#  phone number = 096 843 3437  --  average call duration in mins : 16.46
#  phone number = 096 856 8319  --  average call duration in mins : 9.23
#  phone number = 096 875 0322  --  average call duration in mins : 13.34
#  phone number = 096 894 9646  --  average call duration in mins : 13.57
#  phone number = 096 911 2396  --  average call duration in mins : 10.02
#  phone number = 096 917 0305  --  average call duration in mins : 14.99
#  phone number = 096 942 1313  --  average call duration in mins : 15.21
#  phone number = 096 954 7374  --  average call duration in mins : 14.78
#  phone number = 096 963 9439  --  average call duration in mins : 12.00
#  phone number = 096 965 5787  --  average call duration in mins : 16.26
#  phone number = 096 984 5416  --  average call duration in mins : 15.51
#  phone number = 097 049 1224  --  average call duration in mins : 16.76
#  phone number = 097 068 0123  --  average call duration in mins : 12.30
#  phone number = 097 128 0556  --  average call duration in mins : 13.84
#  phone number = 097 156 3860  --  average call duration in mins : 11.43
#  phone number = 097 159 3589  --  average call duration in mins : 14.18
#  phone number = 097 168 9493  --  average call duration in mins : 12.04
#  phone number = 097 211 1630  --  average call duration in mins : 17.27
#  phone number = 097 241 8396  --  average call duration in mins : 13.87
#  phone number = 097 244 2994  --  average call duration in mins : 13.18
#  phone number = 097 276 0543  --  average call duration in mins : 12.70
#  phone number = 097 286 3014  --  average call duration in mins : 17.81
#  phone number = 097 309 1688  --  average call duration in mins : 14.99
#  phone number = 097 337 9385  --  average call duration in mins : 12.34
#  phone number = 097 343 4457  --  average call duration in mins : 12.73
#  phone number = 097 355 2360  --  average call duration in mins : 13.35
#  phone number = 097 380 6492  --  average call duration in mins : 15.88
#  phone number = 097 383 9791  --  average call duration in mins : 12.84
#  phone number = 097 418 2240  --  average call duration in mins : 4.95
#  phone number = 097 421 3048  --  average call duration in mins : 21.19
#  phone number = 097 458 2208  --  average call duration in mins : 7.94
#  phone number = 097 470 1830  --  average call duration in mins : 13.77
#  phone number = 097 480 6837  --  average call duration in mins : 11.63
#  phone number = 097 492 8940  --  average call duration in mins : 18.36
#  phone number = 097 518 8668  --  average call duration in mins : 15.44
#  phone number = 097 539 0904  --  average call duration in mins : 17.99
#  phone number = 097 546 3920  --  average call duration in mins : 13.03
#  phone number = 097 566 2311  --  average call duration in mins : 14.35
#  phone number = 097 584 7397  --  average call duration in mins : 15.18
#  phone number = 097 601 5401  --  average call duration in mins : 14.57
#  phone number = 097 603 9467  --  average call duration in mins : 16.20
#  phone number = 097 632 0123  --  average call duration in mins : 20.36
#  phone number = 097 660 7672  --  average call duration in mins : 12.74
#  phone number = 097 669 5398  --  average call duration in mins : 13.30
#  phone number = 097 670 6904  --  average call duration in mins : 16.09
#  phone number = 097 677 9605  --  average call duration in mins : 15.03
#  phone number = 097 705 0231  --  average call duration in mins : 15.86
#  phone number = 097 738 2344  --  average call duration in mins : 15.21
#  phone number = 097 739 7332  --  average call duration in mins : 15.42
#  phone number = 097 742 5312  --  average call duration in mins : 14.98
#  phone number = 097 749 5893  --  average call duration in mins : 18.22
#  phone number = 097 781 5993  --  average call duration in mins : 18.77
#  phone number = 097 782 9315  --  average call duration in mins : 14.98
#  phone number = 097 800 1897  --  average call duration in mins : 14.35
#  phone number = 097 821 7601  --  average call duration in mins : 11.38
#  phone number = 097 825 7348  --  average call duration in mins : 17.58
#  phone number = 097 830 7504  --  average call duration in mins : 11.81
#  phone number = 097 835 8282  --  average call duration in mins : 13.74
#  phone number = 097 853 6536  --  average call duration in mins : 16.06
#  phone number = 097 857 3575  --  average call duration in mins : 15.93
#  phone number = 097 860 7752  --  average call duration in mins : 13.14
#  phone number = 097 886 8635  --  average call duration in mins : 22.89
#  phone number = 097 918 8834  --  average call duration in mins : 14.83
#  phone number = 097 922 5004  --  average call duration in mins : 18.58
#  phone number = 097 970 8184  --  average call duration in mins : 16.75
#  phone number = 097 974 5548  --  average call duration in mins : 11.91
#  phone number = 097 978 6830  --  average call duration in mins : 13.83
#  phone number = 097 984 1283  --  average call duration in mins : 10.74
#  phone number = 098 023 1709  --  average call duration in mins : 14.69
#  phone number = 098 024 6082  --  average call duration in mins : 11.30
#  phone number = 098 033 2530  --  average call duration in mins : 14.24
#  phone number = 098 058 2030  --  average call duration in mins : 15.01
#  phone number = 098 064 9518  --  average call duration in mins : 10.13
#  phone number = 098 067 7222  --  average call duration in mins : 13.56
#  phone number = 098 148 2924  --  average call duration in mins : 17.05
#  phone number = 098 175 2992  --  average call duration in mins : 9.84
#  phone number = 098 203 9497  --  average call duration in mins : 20.21
#  phone number = 098 223 3747  --  average call duration in mins : 15.42
#  phone number = 098 270 2822  --  average call duration in mins : 14.47
#  phone number = 098 302 3134  --  average call duration in mins : 14.58
#  phone number = 098 317 0154  --  average call duration in mins : 10.54
#  phone number = 098 325 9421  --  average call duration in mins : 13.52
#  phone number = 098 395 7912  --  average call duration in mins : 14.67
#  phone number = 098 436 3682  --  average call duration in mins : 14.42
#  phone number = 098 436 8234  --  average call duration in mins : 34.13
#  phone number = 098 456 6760  --  average call duration in mins : 16.42
#  phone number = 098 471 2379  --  average call duration in mins : 15.70
#  phone number = 098 471 5749  --  average call duration in mins : 15.09
#  phone number = 098 479 8154  --  average call duration in mins : 14.16
#  phone number = 098 506 4624  --  average call duration in mins : 19.56
#  phone number = 098 507 3591  --  average call duration in mins : 14.94
#  phone number = 098 532 2951  --  average call duration in mins : 17.32
#  phone number = 098 568 8430  --  average call duration in mins : 17.85
#  phone number = 098 645 4041  --  average call duration in mins : 12.54
#  phone number = 098 662 8068  --  average call duration in mins : 14.04
#  phone number = 098 703 0848  --  average call duration in mins : 14.27
#  phone number = 098 733 2818  --  average call duration in mins : 15.48
#  phone number = 098 742 7462  --  average call duration in mins : 16.93
#  phone number = 098 745 4469  --  average call duration in mins : 15.13
#  phone number = 098 746 1914  --  average call duration in mins : 15.97
#  phone number = 098 761 8559  --  average call duration in mins : 14.87
#  phone number = 098 787 5555  --  average call duration in mins : 18.43
#  phone number = 098 792 0545  --  average call duration in mins : 17.56
#  phone number = 098 793 5932  --  average call duration in mins : 17.10
#  phone number = 098 802 1130  --  average call duration in mins : 17.63
#  phone number = 098 804 6637  --  average call duration in mins : 14.19
#  phone number = 098 830 0863  --  average call duration in mins : 19.44
#  phone number = 098 861 2349  --  average call duration in mins : 14.60
#  phone number = 098 873 2168  --  average call duration in mins : 5.13
#  phone number = 098 876 1159  --  average call duration in mins : 12.18
#  phone number = 098 976 3902  --  average call duration in mins : 19.32
#  phone number = 098 984 0097  --  average call duration in mins : 15.04
#  phone number = 098 986 3148  --  average call duration in mins : 16.30
#  phone number = 098 991 7385  --  average call duration in mins : 14.73
#  phone number = 099 007 2663  --  average call duration in mins : 16.50
#  phone number = 099 074 8265  --  average call duration in mins : 15.10
#  phone number = 099 082 9689  --  average call duration in mins : 9.49
#  phone number = 099 118 3706  --  average call duration in mins : 14.10
#  phone number = 099 123 4828  --  average call duration in mins : 10.96
#  phone number = 099 129 9014  --  average call duration in mins : 8.10
#  phone number = 099 131 8627  --  average call duration in mins : 16.22
#  phone number = 099 155 4735  --  average call duration in mins : 14.42
#  phone number = 099 182 3641  --  average call duration in mins : 15.12
#  phone number = 099 183 1097  --  average call duration in mins : 14.81
#  phone number = 099 201 0842  --  average call duration in mins : 14.17
#  phone number = 099 205 6701  --  average call duration in mins : 11.86
#  phone number = 099 236 8205  --  average call duration in mins : 15.11
#  phone number = 099 254 0042  --  average call duration in mins : 14.80
#  phone number = 099 264 7569  --  average call duration in mins : 15.89
#  phone number = 099 302 4237  --  average call duration in mins : 15.48
#  phone number = 099 329 2806  --  average call duration in mins : 12.26
#  phone number = 099 385 3375  --  average call duration in mins : 15.34
#  phone number = 099 392 3191  --  average call duration in mins : 15.04
#  phone number = 099 403 7775  --  average call duration in mins : 15.90
#  phone number = 099 421 7006  --  average call duration in mins : 14.07
#  phone number = 099 421 7773  --  average call duration in mins : 24.15
#  phone number = 099 422 7581  --  average call duration in mins : 23.40
#  phone number = 099 459 2667  --  average call duration in mins : 15.24
#  phone number = 099 467 0203  --  average call duration in mins : 15.12
#  phone number = 099 468 7790  --  average call duration in mins : 14.93
#  phone number = 099 496 5160  --  average call duration in mins : 12.59
#  phone number = 099 534 3954  --  average call duration in mins : 14.02
#  phone number = 099 567 1853  --  average call duration in mins : 16.87
#  phone number = 099 573 8495  --  average call duration in mins : 14.56
#  phone number = 099 648 3187  --  average call duration in mins : 9.39
#  phone number = 099 649 5307  --  average call duration in mins : 16.13
#  phone number = 099 653 9766  --  average call duration in mins : 14.38
#  phone number = 099 665 4287  --  average call duration in mins : 13.94
#  phone number = 099 687 9704  --  average call duration in mins : 11.41
#  phone number = 099 760 8745  --  average call duration in mins : 14.32
#  phone number = 099 768 5189  --  average call duration in mins : 16.05
#  phone number = 099 776 2074  --  average call duration in mins : 14.54
#  phone number = 099 786 5545  --  average call duration in mins : 12.92
#  phone number = 099 804 3736  --  average call duration in mins : 18.02
#  phone number = 099 818 3679  --  average call duration in mins : 13.24
#  phone number = 099 827 2933  --  average call duration in mins : 10.11
#  phone number = 099 852 4932  --  average call duration in mins : 4.89
#  phone number = 099 863 6734  --  average call duration in mins : 16.97
#  phone number = 099 891 4468  --  average call duration in mins : 13.94
#  phone number = 099 932 6937  --  average call duration in mins : 14.98
#  phone number = 099 934 4854  --  average call duration in mins : 22.23
#  phone number = 099 950 5844  --  average call duration in mins : 11.95
#  phone number = 099 959 2978  --  average call duration in mins : 15.24
#  phone number = 099 965 9604  --  average call duration in mins : 17.78
#  phone number = 099 971 0686  --  average call duration in mins : 17.36

# %% [markdown]
# b) The number of calls made to customer support by phone number (2 marks)

# %%
conn.rollback()
result = conn.execute(text("SELECT calls.phonenumber, COUNT(*) as num_alls_made_to_cust_serv " 
                        "FROM calls "
                        "INNER JOIN customer_service "
                        "ON calls.connectionid = customer_service.connectionid "
                        "GROUP BY calls.phonenumber "
                        "ORDER BY calls.phonenumber;"
                        #")"
)
)

# get the value from the tuple result returned byt the sql query
num_calls_to_cs = result.fetchall()

# loop through the values, assigning a value to the first and second values in the tuple result
# this just allow us call them in print satement with mroe descriptive details
for row in num_calls_to_cs:
    phonenumber = row[0]
    num_calls_to_cust_services= row[1]
    print(f" phone number = {phonenumber}  --  number of calls to customer service : {num_calls_to_cust_services}")
# Out:
#  phone number = 01 000 9436  --  number of calls to customer service : 1
#  phone number = 01 001 6896  --  number of calls to customer service : 5
#  phone number = 01 001 9955  --  number of calls to customer service : 4
#  phone number = 01 002 1488  --  number of calls to customer service : 3
#  phone number = 01 002 3138  --  number of calls to customer service : 6
#  phone number = 01 002 7003  --  number of calls to customer service : 3
#  phone number = 01 003 5862  --  number of calls to customer service : 2
#  phone number = 01 004 1518  --  number of calls to customer service : 2
#  phone number = 01 004 3369  --  number of calls to customer service : 1
#  phone number = 01 004 6123  --  number of calls to customer service : 3
#  phone number = 01 005 3059  --  number of calls to customer service : 2
#  phone number = 01 005 7353  --  number of calls to customer service : 1
#  phone number = 01 005 8909  --  number of calls to customer service : 9
#  phone number = 01 005 9012  --  number of calls to customer service : 7
#  phone number = 01 006 5619  --  number of calls to customer service : 4
#  phone number = 01 006 8032  --  number of calls to customer service : 5
#  phone number = 01 007 0548  --  number of calls to customer service : 2
#  phone number = 01 007 3126  --  number of calls to customer service : 10
#  phone number = 01 008 0438  --  number of calls to customer service : 11
#  phone number = 01 008 1378  --  number of calls to customer service : 7
#  phone number = 01 008 2702  --  number of calls to customer service : 3
#  phone number = 01 008 5273  --  number of calls to customer service : 1
#  phone number = 01 009 8882  --  number of calls to customer service : 3
#  phone number = 01 010 3210  --  number of calls to customer service : 3
#  phone number = 01 010 4583  --  number of calls to customer service : 2
#  phone number = 01 010 9798  --  number of calls to customer service : 5
#  phone number = 01 011 1266  --  number of calls to customer service : 5
#  phone number = 01 011 1953  --  number of calls to customer service : 2
#  phone number = 01 011 8477  --  number of calls to customer service : 4
#  phone number = 01 012 7288  --  number of calls to customer service : 9
#  phone number = 01 013 7832  --  number of calls to customer service : 5
#  phone number = 01 014 0689  --  number of calls to customer service : 6
#  phone number = 01 014 1996  --  number of calls to customer service : 2
#  phone number = 01 016 0950  --  number of calls to customer service : 3
#  phone number = 01 018 5577  --  number of calls to customer service : 3
#  phone number = 01 019 5062  --  number of calls to customer service : 4
#  phone number = 01 020 0786  --  number of calls to customer service : 7
#  phone number = 01 020 1096  --  number of calls to customer service : 5
#  phone number = 01 020 6183  --  number of calls to customer service : 7
#  phone number = 01 020 7989  --  number of calls to customer service : 1
#  phone number = 01 020 9379  --  number of calls to customer service : 4
#  phone number = 01 021 2043  --  number of calls to customer service : 9
#  phone number = 01 021 4367  --  number of calls to customer service : 7
#  phone number = 01 021 5019  --  number of calls to customer service : 6
#  phone number = 01 021 5942  --  number of calls to customer service : 1
#  phone number = 01 022 1093  --  number of calls to customer service : 5
#  phone number = 01 022 2769  --  number of calls to customer service : 4
#  phone number = 01 023 1536  --  number of calls to customer service : 1
#  phone number = 01 023 6034  --  number of calls to customer service : 6
#  phone number = 01 023 8054  --  number of calls to customer service : 2
#  phone number = 01 025 5897  --  number of calls to customer service : 4
#  phone number = 01 025 6508  --  number of calls to customer service : 2
#  phone number = 01 025 6891  --  number of calls to customer service : 1
#  phone number = 01 026 1446  --  number of calls to customer service : 4
#  phone number = 01 026 5303  --  number of calls to customer service : 3
#  phone number = 01 026 8589  --  number of calls to customer service : 4
#  phone number = 01 027 3127  --  number of calls to customer service : 10
#  phone number = 01 027 6544  --  number of calls to customer service : 2
#  phone number = 01 027 7838  --  number of calls to customer service : 2
#  phone number = 01 028 5379  --  number of calls to customer service : 10
#  phone number = 01 028 7785  --  number of calls to customer service : 2
#  phone number = 01 029 6454  --  number of calls to customer service : 8
#  phone number = 01 030 0622  --  number of calls to customer service : 7
#  phone number = 01 031 1696  --  number of calls to customer service : 4
#  phone number = 01 031 7619  --  number of calls to customer service : 1
#  phone number = 01 031 8008  --  number of calls to customer service : 1
#  phone number = 01 034 3280  --  number of calls to customer service : 10
#  phone number = 01 036 2386  --  number of calls to customer service : 3
#  phone number = 01 036 2438  --  number of calls to customer service : 1
#  phone number = 01 036 5399  --  number of calls to customer service : 3
#  phone number = 01 038 1351  --  number of calls to customer service : 7
#  phone number = 01 038 5176  --  number of calls to customer service : 2
#  phone number = 01 039 0574  --  number of calls to customer service : 5
#  phone number = 01 040 2094  --  number of calls to customer service : 3
#  phone number = 01 040 5603  --  number of calls to customer service : 3
#  phone number = 01 040 6754  --  number of calls to customer service : 1
#  phone number = 01 040 7065  --  number of calls to customer service : 4
#  phone number = 01 040 8055  --  number of calls to customer service : 1
#  phone number = 01 041 0679  --  number of calls to customer service : 7
#  phone number = 01 042 1549  --  number of calls to customer service : 4
#  phone number = 01 042 4350  --  number of calls to customer service : 1
#  phone number = 01 042 5622  --  number of calls to customer service : 4
#  phone number = 01 042 9157  --  number of calls to customer service : 4
#  phone number = 01 043 6513  --  number of calls to customer service : 1
#  phone number = 01 044 2909  --  number of calls to customer service : 6
#  phone number = 01 045 3778  --  number of calls to customer service : 4
#  phone number = 01 045 9305  --  number of calls to customer service : 4
#  phone number = 01 046 1809  --  number of calls to customer service : 1
#  phone number = 01 046 2525  --  number of calls to customer service : 1
#  phone number = 01 046 7656  --  number of calls to customer service : 8
#  phone number = 01 047 1637  --  number of calls to customer service : 11
#  phone number = 01 047 6919  --  number of calls to customer service : 3
#  phone number = 01 048 3321  --  number of calls to customer service : 2
#  phone number = 01 049 3297  --  number of calls to customer service : 4
#  phone number = 01 049 6783  --  number of calls to customer service : 1
#  phone number = 01 049 9980  --  number of calls to customer service : 10
#  phone number = 01 050 9912  --  number of calls to customer service : 2
#  phone number = 01 051 5064  --  number of calls to customer service : 2
#  phone number = 01 051 6305  --  number of calls to customer service : 6
#  phone number = 01 051 7089  --  number of calls to customer service : 3
#  phone number = 01 053 1264  --  number of calls to customer service : 4
#  phone number = 01 054 1555  --  number of calls to customer service : 4
#  phone number = 01 054 1611  --  number of calls to customer service : 2
#  phone number = 01 055 4064  --  number of calls to customer service : 3
#  phone number = 01 056 8501  --  number of calls to customer service : 2
#  phone number = 01 057 1498  --  number of calls to customer service : 3
#  phone number = 01 058 1435  --  number of calls to customer service : 1
#  phone number = 01 058 6889  --  number of calls to customer service : 6
#  phone number = 01 059 1117  --  number of calls to customer service : 5
#  phone number = 01 059 3596  --  number of calls to customer service : 4
#  phone number = 01 060 5603  --  number of calls to customer service : 5
#  phone number = 01 060 7849  --  number of calls to customer service : 4
#  phone number = 01 061 1272  --  number of calls to customer service : 1
#  phone number = 01 061 2698  --  number of calls to customer service : 1
#  phone number = 01 061 7312  --  number of calls to customer service : 5
#  phone number = 01 062 1387  --  number of calls to customer service : 3
#  phone number = 01 062 4505  --  number of calls to customer service : 10
#  phone number = 01 062 6478  --  number of calls to customer service : 2
#  phone number = 01 062 6717  --  number of calls to customer service : 4
#  phone number = 01 062 7978  --  number of calls to customer service : 8
#  phone number = 01 063 9249  --  number of calls to customer service : 1
#  phone number = 01 064 9939  --  number of calls to customer service : 5
#  phone number = 01 065 9063  --  number of calls to customer service : 4
#  phone number = 01 066 4390  --  number of calls to customer service : 3
#  phone number = 01 067 7684  --  number of calls to customer service : 3
#  phone number = 01 067 9625  --  number of calls to customer service : 6
#  phone number = 01 068 3946  --  number of calls to customer service : 3
#  phone number = 01 068 6894  --  number of calls to customer service : 6
#  phone number = 01 071 7402  --  number of calls to customer service : 2
#  phone number = 01 072 3292  --  number of calls to customer service : 2
#  phone number = 01 072 5523  --  number of calls to customer service : 1
#  phone number = 01 073 3754  --  number of calls to customer service : 7
#  phone number = 01 073 6007  --  number of calls to customer service : 10
#  phone number = 01 074 4230  --  number of calls to customer service : 1
#  phone number = 01 074 4857  --  number of calls to customer service : 1
#  phone number = 01 075 2041  --  number of calls to customer service : 5
#  phone number = 01 076 8087  --  number of calls to customer service : 3
#  phone number = 01 077 5662  --  number of calls to customer service : 4
#  phone number = 01 077 9376  --  number of calls to customer service : 4
#  phone number = 01 078 3073  --  number of calls to customer service : 3
#  phone number = 01 078 5248  --  number of calls to customer service : 4
#  phone number = 01 078 7201  --  number of calls to customer service : 2
#  phone number = 01 078 9022  --  number of calls to customer service : 1
#  phone number = 01 079 9635  --  number of calls to customer service : 4
#  phone number = 01 080 0105  --  number of calls to customer service : 2
#  phone number = 01 080 1220  --  number of calls to customer service : 4
#  phone number = 01 080 3589  --  number of calls to customer service : 3
#  phone number = 01 080 4058  --  number of calls to customer service : 8
#  phone number = 01 080 5748  --  number of calls to customer service : 1
#  phone number = 01 080 6020  --  number of calls to customer service : 4
#  phone number = 01 080 8799  --  number of calls to customer service : 3
#  phone number = 01 080 9502  --  number of calls to customer service : 2
#  phone number = 01 080 9716  --  number of calls to customer service : 2
#  phone number = 01 081 4561  --  number of calls to customer service : 1
#  phone number = 01 081 4566  --  number of calls to customer service : 2
#  phone number = 01 081 8458  --  number of calls to customer service : 3
#  phone number = 01 081 9637  --  number of calls to customer service : 1
#  phone number = 01 082 4718  --  number of calls to customer service : 2
#  phone number = 01 085 0209  --  number of calls to customer service : 2
#  phone number = 01 085 4787  --  number of calls to customer service : 4
#  phone number = 01 085 9247  --  number of calls to customer service : 4
#  phone number = 01 086 0400  --  number of calls to customer service : 1
#  phone number = 01 086 7028  --  number of calls to customer service : 3
#  phone number = 01 086 7661  --  number of calls to customer service : 6
#  phone number = 01 087 6846  --  number of calls to customer service : 2
#  phone number = 01 087 7025  --  number of calls to customer service : 1
#  phone number = 01 088 6093  --  number of calls to customer service : 2
#  phone number = 01 089 0549  --  number of calls to customer service : 3
#  phone number = 01 089 6127  --  number of calls to customer service : 6
#  phone number = 01 090 2350  --  number of calls to customer service : 7
#  phone number = 01 090 3690  --  number of calls to customer service : 1
#  phone number = 01 091 3191  --  number of calls to customer service : 3
#  phone number = 01 091 4461  --  number of calls to customer service : 1
#  phone number = 01 091 5387  --  number of calls to customer service : 10
#  phone number = 01 091 9901  --  number of calls to customer service : 6
#  phone number = 01 093 0318  --  number of calls to customer service : 9
#  phone number = 01 093 3563  --  number of calls to customer service : 1
#  phone number = 01 093 5026  --  number of calls to customer service : 1
#  phone number = 01 094 2631  --  number of calls to customer service : 8
#  phone number = 01 094 7572  --  number of calls to customer service : 6
#  phone number = 01 095 5179  --  number of calls to customer service : 3
#  phone number = 01 095 6183  --  number of calls to customer service : 7
#  phone number = 01 095 7173  --  number of calls to customer service : 4
#  phone number = 01 096 1539  --  number of calls to customer service : 4
#  phone number = 01 097 9221  --  number of calls to customer service : 5
#  phone number = 01 098 8776  --  number of calls to customer service : 1
#  phone number = 01 099 0689  --  number of calls to customer service : 7
#  phone number = 01 099 1853  --  number of calls to customer service : 1
#  phone number = 01 099 5443  --  number of calls to customer service : 2
#  phone number = 01 099 6113  --  number of calls to customer service : 5
#  phone number = 01 100 3828  --  number of calls to customer service : 4
#  phone number = 01 100 4959  --  number of calls to customer service : 5
#  phone number = 01 100 5312  --  number of calls to customer service : 2
#  phone number = 01 100 6767  --  number of calls to customer service : 2
#  phone number = 01 101 5451  --  number of calls to customer service : 2
#  phone number = 01 102 3250  --  number of calls to customer service : 6
#  phone number = 01 102 5743  --  number of calls to customer service : 5
#  phone number = 01 103 8315  --  number of calls to customer service : 4
#  phone number = 01 104 0513  --  number of calls to customer service : 5
#  phone number = 01 104 0620  --  number of calls to customer service : 3
#  phone number = 01 104 2635  --  number of calls to customer service : 14
#  phone number = 01 104 4540  --  number of calls to customer service : 3
#  phone number = 01 104 7507  --  number of calls to customer service : 9
#  phone number = 01 104 8816  --  number of calls to customer service : 1
#  phone number = 01 105 1378  --  number of calls to customer service : 8
#  phone number = 01 105 2419  --  number of calls to customer service : 5
#  phone number = 01 106 0144  --  number of calls to customer service : 2
#  phone number = 01 106 0847  --  number of calls to customer service : 4
#  phone number = 01 106 2284  --  number of calls to customer service : 4
#  phone number = 01 106 9634  --  number of calls to customer service : 2
#  phone number = 01 107 0324  --  number of calls to customer service : 7
#  phone number = 01 108 0021  --  number of calls to customer service : 7
#  phone number = 01 108 0816  --  number of calls to customer service : 7
#  phone number = 01 108 2515  --  number of calls to customer service : 1
#  phone number = 01 109 2515  --  number of calls to customer service : 3
#  phone number = 01 109 6735  --  number of calls to customer service : 3
#  phone number = 01 109 6982  --  number of calls to customer service : 1
#  phone number = 01 109 8748  --  number of calls to customer service : 5
#  phone number = 01 110 0724  --  number of calls to customer service : 2
#  phone number = 01 110 4632  --  number of calls to customer service : 4
#  phone number = 01 110 8839  --  number of calls to customer service : 4
#  phone number = 01 110 9700  --  number of calls to customer service : 1
#  phone number = 01 111 0448  --  number of calls to customer service : 1
#  phone number = 01 112 1838  --  number of calls to customer service : 6
#  phone number = 01 112 6336  --  number of calls to customer service : 4
#  phone number = 01 113 3918  --  number of calls to customer service : 2
#  phone number = 01 113 4041  --  number of calls to customer service : 2
#  phone number = 01 113 9048  --  number of calls to customer service : 3
#  phone number = 01 114 2425  --  number of calls to customer service : 7
#  phone number = 01 114 8854  --  number of calls to customer service : 7
#  phone number = 01 115 0744  --  number of calls to customer service : 3
#  phone number = 01 115 5361  --  number of calls to customer service : 7
#  phone number = 01 115 6043  --  number of calls to customer service : 1
#  phone number = 01 116 2405  --  number of calls to customer service : 2
#  phone number = 01 116 2490  --  number of calls to customer service : 2
#  phone number = 01 116 7820  --  number of calls to customer service : 2
#  phone number = 01 116 7986  --  number of calls to customer service : 6
#  phone number = 01 117 4702  --  number of calls to customer service : 5
#  phone number = 01 117 5538  --  number of calls to customer service : 4
#  phone number = 01 117 6176  --  number of calls to customer service : 11
#  phone number = 01 117 7199  --  number of calls to customer service : 3
#  phone number = 01 118 3666  --  number of calls to customer service : 3
#  phone number = 01 118 4164  --  number of calls to customer service : 9
#  phone number = 01 118 7246  --  number of calls to customer service : 3
#  phone number = 01 118 9489  --  number of calls to customer service : 8
#  phone number = 01 118 9715  --  number of calls to customer service : 2
#  phone number = 01 119 5352  --  number of calls to customer service : 5
#  phone number = 01 119 9126  --  number of calls to customer service : 2
#  phone number = 01 120 0757  --  number of calls to customer service : 5
#  phone number = 01 120 0772  --  number of calls to customer service : 1
#  phone number = 01 120 7794  --  number of calls to customer service : 3
#  phone number = 01 120 9576  --  number of calls to customer service : 2
#  phone number = 01 121 3013  --  number of calls to customer service : 2
#  phone number = 01 121 4075  --  number of calls to customer service : 9
#  phone number = 01 121 8920  --  number of calls to customer service : 1
#  phone number = 01 121 9246  --  number of calls to customer service : 2
#  phone number = 01 122 5643  --  number of calls to customer service : 5
#  phone number = 01 122 8155  --  number of calls to customer service : 3
#  phone number = 01 122 8982  --  number of calls to customer service : 6
#  phone number = 01 123 3207  --  number of calls to customer service : 2
#  phone number = 01 123 4401  --  number of calls to customer service : 4
#  phone number = 01 123 6751  --  number of calls to customer service : 7
#  phone number = 01 123 9294  --  number of calls to customer service : 8
#  phone number = 01 124 1137  --  number of calls to customer service : 1
#  phone number = 01 125 4223  --  number of calls to customer service : 4
#  phone number = 01 125 6352  --  number of calls to customer service : 1
#  phone number = 01 125 7323  --  number of calls to customer service : 4
#  phone number = 01 126 5554  --  number of calls to customer service : 2
#  phone number = 01 127 6482  --  number of calls to customer service : 1
#  phone number = 01 127 9548  --  number of calls to customer service : 4
#  phone number = 01 129 5428  --  number of calls to customer service : 5
#  phone number = 01 129 5848  --  number of calls to customer service : 2
#  phone number = 01 129 7514  --  number of calls to customer service : 2
#  phone number = 01 130 6190  --  number of calls to customer service : 4
#  phone number = 01 130 6495  --  number of calls to customer service : 6
#  phone number = 01 131 1010  --  number of calls to customer service : 1
#  phone number = 01 131 2670  --  number of calls to customer service : 6
#  phone number = 01 131 3929  --  number of calls to customer service : 4
#  phone number = 01 131 7338  --  number of calls to customer service : 1
#  phone number = 01 132 1436  --  number of calls to customer service : 5
#  phone number = 01 132 5695  --  number of calls to customer service : 3
#  phone number = 01 132 8893  --  number of calls to customer service : 1
#  phone number = 01 133 1507  --  number of calls to customer service : 6
#  phone number = 01 134 7272  --  number of calls to customer service : 2
#  phone number = 01 135 1366  --  number of calls to customer service : 6
#  phone number = 01 135 1423  --  number of calls to customer service : 3
#  phone number = 01 136 7321  --  number of calls to customer service : 2
#  phone number = 01 137 1576  --  number of calls to customer service : 1
#  phone number = 01 137 5885  --  number of calls to customer service : 3
#  phone number = 01 137 7256  --  number of calls to customer service : 3
#  phone number = 01 139 2949  --  number of calls to customer service : 4
#  phone number = 01 140 5404  --  number of calls to customer service : 4
#  phone number = 01 140 8199  --  number of calls to customer service : 3
#  phone number = 01 141 0504  --  number of calls to customer service : 5
#  phone number = 01 142 3394  --  number of calls to customer service : 3
#  phone number = 01 142 3409  --  number of calls to customer service : 4
#  phone number = 01 143 1824  --  number of calls to customer service : 4
#  phone number = 01 143 6965  --  number of calls to customer service : 2
#  phone number = 01 143 8073  --  number of calls to customer service : 3
#  phone number = 01 144 3410  --  number of calls to customer service : 11
#  phone number = 01 146 4477  --  number of calls to customer service : 2
#  phone number = 01 147 1997  --  number of calls to customer service : 5
#  phone number = 01 147 4551  --  number of calls to customer service : 1
#  phone number = 01 147 9607  --  number of calls to customer service : 14
#  phone number = 01 148 3325  --  number of calls to customer service : 6
#  phone number = 01 148 3612  --  number of calls to customer service : 2
#  phone number = 01 148 5574  --  number of calls to customer service : 1
#  phone number = 01 148 6430  --  number of calls to customer service : 3
#  phone number = 01 149 9236  --  number of calls to customer service : 4
#  phone number = 01 149 9413  --  number of calls to customer service : 3
#  phone number = 01 150 1632  --  number of calls to customer service : 1
#  phone number = 01 150 3230  --  number of calls to customer service : 2
#  phone number = 01 150 5142  --  number of calls to customer service : 6
#  phone number = 01 151 0818  --  number of calls to customer service : 1
#  phone number = 01 151 0845  --  number of calls to customer service : 9
#  phone number = 01 151 2521  --  number of calls to customer service : 5
#  phone number = 01 151 2782  --  number of calls to customer service : 3
#  phone number = 01 151 6551  --  number of calls to customer service : 5
#  phone number = 01 151 6643  --  number of calls to customer service : 8
#  phone number = 01 152 3397  --  number of calls to customer service : 7
#  phone number = 01 153 7935  --  number of calls to customer service : 3
#  phone number = 01 153 8674  --  number of calls to customer service : 2
#  phone number = 01 154 7337  --  number of calls to customer service : 3
#  phone number = 01 156 5486  --  number of calls to customer service : 4
#  phone number = 01 156 7305  --  number of calls to customer service : 7
#  phone number = 01 156 8421  --  number of calls to customer service : 10
#  phone number = 01 156 9548  --  number of calls to customer service : 1
#  phone number = 01 157 0608  --  number of calls to customer service : 4
#  phone number = 01 157 9991  --  number of calls to customer service : 4
#  phone number = 01 158 6402  --  number of calls to customer service : 1
#  phone number = 01 158 7062  --  number of calls to customer service : 2
#  phone number = 01 158 7833  --  number of calls to customer service : 2
#  phone number = 01 158 8895  --  number of calls to customer service : 1
#  phone number = 01 158 9429  --  number of calls to customer service : 5
#  phone number = 01 159 0347  --  number of calls to customer service : 3
#  phone number = 01 159 0855  --  number of calls to customer service : 6
#  phone number = 01 159 8591  --  number of calls to customer service : 1
#  phone number = 01 160 4028  --  number of calls to customer service : 9
#  phone number = 01 160 8117  --  number of calls to customer service : 1
#  phone number = 01 161 8741  --  number of calls to customer service : 4
#  phone number = 01 162 0261  --  number of calls to customer service : 10
#  phone number = 01 162 5934  --  number of calls to customer service : 2
#  phone number = 01 165 0885  --  number of calls to customer service : 3
#  phone number = 01 166 0928  --  number of calls to customer service : 1
#  phone number = 01 166 6119  --  number of calls to customer service : 4
#  phone number = 01 166 6140  --  number of calls to customer service : 1
#  phone number = 01 167 1683  --  number of calls to customer service : 4
#  phone number = 01 167 7379  --  number of calls to customer service : 10
#  phone number = 01 168 3717  --  number of calls to customer service : 6
#  phone number = 01 168 9604  --  number of calls to customer service : 9
#  phone number = 01 169 2437  --  number of calls to customer service : 3
#  phone number = 01 170 1428  --  number of calls to customer service : 4
#  phone number = 01 171 0815  --  number of calls to customer service : 2
#  phone number = 01 171 1252  --  number of calls to customer service : 3
#  phone number = 01 172 0308  --  number of calls to customer service : 4
#  phone number = 01 172 5769  --  number of calls to customer service : 2
#  phone number = 01 172 7725  --  number of calls to customer service : 7
#  phone number = 01 173 0215  --  number of calls to customer service : 3
#  phone number = 01 173 1780  --  number of calls to customer service : 8
#  phone number = 01 173 2196  --  number of calls to customer service : 5
#  phone number = 01 173 3215  --  number of calls to customer service : 5
#  phone number = 01 173 5928  --  number of calls to customer service : 6
#  phone number = 01 173 7904  --  number of calls to customer service : 8
#  phone number = 01 174 2362  --  number of calls to customer service : 2
#  phone number = 01 174 6137  --  number of calls to customer service : 2
#  phone number = 01 175 2891  --  number of calls to customer service : 3
#  phone number = 01 175 5988  --  number of calls to customer service : 2
#  phone number = 01 175 6813  --  number of calls to customer service : 8
#  phone number = 01 175 7126  --  number of calls to customer service : 2
#  phone number = 01 177 0952  --  number of calls to customer service : 1
#  phone number = 01 177 4863  --  number of calls to customer service : 2
#  phone number = 01 180 3115  --  number of calls to customer service : 2
#  phone number = 01 180 4661  --  number of calls to customer service : 1
#  phone number = 01 180 9556  --  number of calls to customer service : 3
#  phone number = 01 181 1680  --  number of calls to customer service : 1
#  phone number = 01 181 6124  --  number of calls to customer service : 7
#  phone number = 01 182 3297  --  number of calls to customer service : 4
#  phone number = 01 182 4112  --  number of calls to customer service : 7
#  phone number = 01 183 2755  --  number of calls to customer service : 3
#  phone number = 01 183 3850  --  number of calls to customer service : 7
#  phone number = 01 185 2943  --  number of calls to customer service : 5
#  phone number = 01 185 4094  --  number of calls to customer service : 4
#  phone number = 01 185 8476  --  number of calls to customer service : 1
#  phone number = 01 186 4068  --  number of calls to customer service : 8
#  phone number = 01 187 1140  --  number of calls to customer service : 5
#  phone number = 01 187 3845  --  number of calls to customer service : 7
#  phone number = 01 187 4164  --  number of calls to customer service : 4
#  phone number = 01 187 7119  --  number of calls to customer service : 1
#  phone number = 01 188 8208  --  number of calls to customer service : 1
#  phone number = 01 189 8206  --  number of calls to customer service : 3
#  phone number = 01 190 8424  --  number of calls to customer service : 2
#  phone number = 01 190 9802  --  number of calls to customer service : 4
#  phone number = 01 191 2566  --  number of calls to customer service : 6
#  phone number = 01 191 4804  --  number of calls to customer service : 2
#  phone number = 01 191 9303  --  number of calls to customer service : 4
#  phone number = 01 192 3852  --  number of calls to customer service : 6
#  phone number = 01 192 6771  --  number of calls to customer service : 3
#  phone number = 01 192 7529  --  number of calls to customer service : 5
#  phone number = 01 194 5162  --  number of calls to customer service : 1
#  phone number = 01 194 5183  --  number of calls to customer service : 6
#  phone number = 01 194 6183  --  number of calls to customer service : 1
#  phone number = 01 194 8039  --  number of calls to customer service : 1
#  phone number = 01 195 0468  --  number of calls to customer service : 2
#  phone number = 01 195 4785  --  number of calls to customer service : 8
#  phone number = 01 195 5842  --  number of calls to customer service : 6
#  phone number = 01 195 7265  --  number of calls to customer service : 1
#  phone number = 01 196 7964  --  number of calls to customer service : 1
#  phone number = 01 197 1057  --  number of calls to customer service : 1
#  phone number = 01 197 7672  --  number of calls to customer service : 1
#  phone number = 01 197 8891  --  number of calls to customer service : 1
#  phone number = 01 198 0288  --  number of calls to customer service : 7
#  phone number = 01 198 0950  --  number of calls to customer service : 6
#  phone number = 01 198 5897  --  number of calls to customer service : 1
#  phone number = 01 199 1016  --  number of calls to customer service : 8
#  phone number = 01 199 6268  --  number of calls to customer service : 1
#  phone number = 01 200 1319  --  number of calls to customer service : 2
#  phone number = 01 201 2567  --  number of calls to customer service : 4
#  phone number = 01 201 2682  --  number of calls to customer service : 6
#  phone number = 01 201 5556  --  number of calls to customer service : 3
#  phone number = 01 201 6093  --  number of calls to customer service : 7
#  phone number = 01 202 0384  --  number of calls to customer service : 3
#  phone number = 01 202 2201  --  number of calls to customer service : 1
#  phone number = 01 203 2213  --  number of calls to customer service : 4
#  phone number = 01 203 4015  --  number of calls to customer service : 2
#  phone number = 01 203 9468  --  number of calls to customer service : 4
#  phone number = 01 204 5594  --  number of calls to customer service : 4
#  phone number = 01 205 2242  --  number of calls to customer service : 3
#  phone number = 01 205 7529  --  number of calls to customer service : 2
#  phone number = 01 205 8305  --  number of calls to customer service : 5
#  phone number = 01 205 9705  --  number of calls to customer service : 1
#  phone number = 01 206 4995  --  number of calls to customer service : 8
#  phone number = 01 206 7443  --  number of calls to customer service : 6
#  phone number = 01 207 7024  --  number of calls to customer service : 7
#  phone number = 01 208 1902  --  number of calls to customer service : 2
#  phone number = 01 208 4478  --  number of calls to customer service : 4
#  phone number = 01 208 6879  --  number of calls to customer service : 2
#  phone number = 01 209 0819  --  number of calls to customer service : 7
#  phone number = 01 209 1612  --  number of calls to customer service : 4
#  phone number = 01 209 5912  --  number of calls to customer service : 1
#  phone number = 01 211 3425  --  number of calls to customer service : 14
#  phone number = 01 211 5140  --  number of calls to customer service : 5
#  phone number = 01 211 6541  --  number of calls to customer service : 6
#  phone number = 01 211 7104  --  number of calls to customer service : 2
#  phone number = 01 212 0290  --  number of calls to customer service : 1
#  phone number = 01 212 4291  --  number of calls to customer service : 10
#  phone number = 01 212 9923  --  number of calls to customer service : 7
#  phone number = 01 213 2476  --  number of calls to customer service : 1
#  phone number = 01 213 3660  --  number of calls to customer service : 3
#  phone number = 01 213 8819  --  number of calls to customer service : 8
#  phone number = 01 214 0664  --  number of calls to customer service : 4
#  phone number = 01 214 1610  --  number of calls to customer service : 12
#  phone number = 01 214 8720  --  number of calls to customer service : 5
#  phone number = 01 215 4902  --  number of calls to customer service : 6
#  phone number = 01 215 5448  --  number of calls to customer service : 15
#  phone number = 01 216 0513  --  number of calls to customer service : 6
#  phone number = 01 216 6453  --  number of calls to customer service : 4
#  phone number = 01 217 5335  --  number of calls to customer service : 6
#  phone number = 01 217 7550  --  number of calls to customer service : 7
#  phone number = 01 217 8310  --  number of calls to customer service : 5
#  phone number = 01 218 0890  --  number of calls to customer service : 3
#  phone number = 01 219 0775  --  number of calls to customer service : 1
#  phone number = 01 219 5055  --  number of calls to customer service : 1
#  phone number = 01 219 6067  --  number of calls to customer service : 5
#  phone number = 01 219 6215  --  number of calls to customer service : 2
#  phone number = 01 220 2580  --  number of calls to customer service : 7
#  phone number = 01 220 2663  --  number of calls to customer service : 8
#  phone number = 01 220 9415  --  number of calls to customer service : 4
#  phone number = 01 221 5212  --  number of calls to customer service : 1
#  phone number = 01 221 5448  --  number of calls to customer service : 1
#  phone number = 01 221 8813  --  number of calls to customer service : 2
#  phone number = 01 222 3669  --  number of calls to customer service : 1
#  phone number = 01 222 6311  --  number of calls to customer service : 4
#  phone number = 01 222 7701  --  number of calls to customer service : 2
#  phone number = 01 223 0244  --  number of calls to customer service : 5
#  phone number = 01 224 0455  --  number of calls to customer service : 3
#  phone number = 01 225 6098  --  number of calls to customer service : 8
#  phone number = 01 225 8073  --  number of calls to customer service : 2
#  phone number = 01 226 2628  --  number of calls to customer service : 3
#  phone number = 01 227 5263  --  number of calls to customer service : 6
#  phone number = 01 227 9959  --  number of calls to customer service : 9
#  phone number = 01 228 4949  --  number of calls to customer service : 1
#  phone number = 01 228 9332  --  number of calls to customer service : 6
#  phone number = 01 229 0394  --  number of calls to customer service : 6
#  phone number = 01 229 1458  --  number of calls to customer service : 4
#  phone number = 01 229 4703  --  number of calls to customer service : 4
#  phone number = 01 229 8743  --  number of calls to customer service : 1
#  phone number = 01 230 2501  --  number of calls to customer service : 6
#  phone number = 01 230 6971  --  number of calls to customer service : 9
#  phone number = 01 230 9103  --  number of calls to customer service : 3
#  phone number = 01 233 3287  --  number of calls to customer service : 2
#  phone number = 01 233 8555  --  number of calls to customer service : 7
#  phone number = 01 234 3803  --  number of calls to customer service : 10
#  phone number = 01 234 4184  --  number of calls to customer service : 10
#  phone number = 01 234 6120  --  number of calls to customer service : 4
#  phone number = 01 235 0067  --  number of calls to customer service : 6
#  phone number = 01 235 1869  --  number of calls to customer service : 1
#  phone number = 01 235 3224  --  number of calls to customer service : 2
#  phone number = 01 235 4880  --  number of calls to customer service : 2
#  phone number = 01 236 6210  --  number of calls to customer service : 3
#  phone number = 01 237 9710  --  number of calls to customer service : 7
#  phone number = 01 238 4133  --  number of calls to customer service : 3
#  phone number = 01 238 8586  --  number of calls to customer service : 4
#  phone number = 01 240 4133  --  number of calls to customer service : 9
#  phone number = 01 240 5578  --  number of calls to customer service : 2
#  phone number = 01 241 0489  --  number of calls to customer service : 10
#  phone number = 01 241 9382  --  number of calls to customer service : 3
#  phone number = 01 243 4778  --  number of calls to customer service : 7
#  phone number = 01 243 5948  --  number of calls to customer service : 5
#  phone number = 01 243 6450  --  number of calls to customer service : 1
#  phone number = 01 244 2454  --  number of calls to customer service : 11
#  phone number = 01 244 2646  --  number of calls to customer service : 1
#  phone number = 01 244 2658  --  number of calls to customer service : 4
#  phone number = 01 244 7361  --  number of calls to customer service : 2
#  phone number = 01 244 8806  --  number of calls to customer service : 5
#  phone number = 01 245 5697  --  number of calls to customer service : 3
#  phone number = 01 245 9534  --  number of calls to customer service : 3
#  phone number = 01 246 5159  --  number of calls to customer service : 2
#  phone number = 01 247 6613  --  number of calls to customer service : 5
#  phone number = 01 247 8370  --  number of calls to customer service : 6
#  phone number = 01 249 1448  --  number of calls to customer service : 1
#  phone number = 01 249 7746  --  number of calls to customer service : 2
#  phone number = 01 250 7386  --  number of calls to customer service : 1
#  phone number = 01 250 9855  --  number of calls to customer service : 3
#  phone number = 01 251 6227  --  number of calls to customer service : 8
#  phone number = 01 251 9007  --  number of calls to customer service : 2
#  phone number = 01 252 2830  --  number of calls to customer service : 1
#  phone number = 01 252 3527  --  number of calls to customer service : 2
#  phone number = 01 253 6046  --  number of calls to customer service : 2
#  phone number = 01 253 6161  --  number of calls to customer service : 2
#  phone number = 01 253 7761  --  number of calls to customer service : 1
#  phone number = 01 254 8971  --  number of calls to customer service : 6
#  phone number = 01 255 0256  --  number of calls to customer service : 1
#  phone number = 01 255 8668  --  number of calls to customer service : 1
#  phone number = 01 256 4296  --  number of calls to customer service : 8
#  phone number = 01 256 4498  --  number of calls to customer service : 3
#  phone number = 01 257 2235  --  number of calls to customer service : 6
#  phone number = 01 257 8466  --  number of calls to customer service : 1
#  phone number = 01 258 0694  --  number of calls to customer service : 8
#  phone number = 01 258 4533  --  number of calls to customer service : 2
#  phone number = 01 258 8772  --  number of calls to customer service : 5
#  phone number = 01 259 1137  --  number of calls to customer service : 6
#  phone number = 01 259 8086  --  number of calls to customer service : 4
#  phone number = 01 259 8095  --  number of calls to customer service : 1
#  phone number = 01 259 9107  --  number of calls to customer service : 1
#  phone number = 01 260 0073  --  number of calls to customer service : 8
#  phone number = 01 260 1450  --  number of calls to customer service : 4
#  phone number = 01 260 4797  --  number of calls to customer service : 1
#  phone number = 01 262 0194  --  number of calls to customer service : 4
#  phone number = 01 262 2672  --  number of calls to customer service : 6
#  phone number = 01 263 9539  --  number of calls to customer service : 5
#  phone number = 01 264 0352  --  number of calls to customer service : 1
#  phone number = 01 264 0835  --  number of calls to customer service : 4
#  phone number = 01 264 6566  --  number of calls to customer service : 4
#  phone number = 01 265 3934  --  number of calls to customer service : 6
#  phone number = 01 266 2396  --  number of calls to customer service : 3
#  phone number = 01 266 4579  --  number of calls to customer service : 4
#  phone number = 01 267 1304  --  number of calls to customer service : 1
#  phone number = 01 267 3722  --  number of calls to customer service : 1
#  phone number = 01 267 4419  --  number of calls to customer service : 2
#  phone number = 01 268 7140  --  number of calls to customer service : 4
#  phone number = 01 271 8206  --  number of calls to customer service : 5
#  phone number = 01 272 2488  --  number of calls to customer service : 4
#  phone number = 01 272 5419  --  number of calls to customer service : 6
#  phone number = 01 274 2699  --  number of calls to customer service : 5
#  phone number = 01 274 3705  --  number of calls to customer service : 4
#  phone number = 01 274 6134  --  number of calls to customer service : 2
#  phone number = 01 275 3512  --  number of calls to customer service : 5
#  phone number = 01 276 4663  --  number of calls to customer service : 7
#  phone number = 01 276 6266  --  number of calls to customer service : 2
#  phone number = 01 277 0570  --  number of calls to customer service : 3
#  phone number = 01 277 1936  --  number of calls to customer service : 8
#  phone number = 01 277 2115  --  number of calls to customer service : 4
#  phone number = 01 277 4169  --  number of calls to customer service : 1
#  phone number = 01 277 7885  --  number of calls to customer service : 1
#  phone number = 01 278 2534  --  number of calls to customer service : 6
#  phone number = 01 278 3857  --  number of calls to customer service : 1
#  phone number = 01 278 3982  --  number of calls to customer service : 4
#  phone number = 01 280 2299  --  number of calls to customer service : 4
#  phone number = 01 281 2777  --  number of calls to customer service : 6
#  phone number = 01 281 6998  --  number of calls to customer service : 7
#  phone number = 01 283 0288  --  number of calls to customer service : 6
#  phone number = 01 283 0942  --  number of calls to customer service : 1
#  phone number = 01 283 2624  --  number of calls to customer service : 7
#  phone number = 01 283 4158  --  number of calls to customer service : 10
#  phone number = 01 284 7237  --  number of calls to customer service : 5
#  phone number = 01 285 2072  --  number of calls to customer service : 5
#  phone number = 01 286 0082  --  number of calls to customer service : 3
#  phone number = 01 287 2765  --  number of calls to customer service : 9
#  phone number = 01 287 4571  --  number of calls to customer service : 6
#  phone number = 01 287 5228  --  number of calls to customer service : 1
#  phone number = 01 287 9205  --  number of calls to customer service : 1
#  phone number = 01 288 1641  --  number of calls to customer service : 1
#  phone number = 01 288 6732  --  number of calls to customer service : 2
#  phone number = 01 288 8606  --  number of calls to customer service : 1
#  phone number = 01 288 9973  --  number of calls to customer service : 2
#  phone number = 01 289 3470  --  number of calls to customer service : 2
#  phone number = 01 289 3801  --  number of calls to customer service : 2
#  phone number = 01 289 4619  --  number of calls to customer service : 8
#  phone number = 01 289 6490  --  number of calls to customer service : 2
#  phone number = 01 289 6679  --  number of calls to customer service : 4
#  phone number = 01 291 6924  --  number of calls to customer service : 2
#  phone number = 01 293 3849  --  number of calls to customer service : 3
#  phone number = 01 293 5985  --  number of calls to customer service : 4
#  phone number = 01 293 8480  --  number of calls to customer service : 2
#  phone number = 01 295 1672  --  number of calls to customer service : 1
#  phone number = 01 296 1866  --  number of calls to customer service : 3
#  phone number = 01 296 4602  --  number of calls to customer service : 2
#  phone number = 01 297 2895  --  number of calls to customer service : 3
#  phone number = 01 297 5159  --  number of calls to customer service : 2
#  phone number = 01 298 4326  --  number of calls to customer service : 1
#  phone number = 01 298 7495  --  number of calls to customer service : 2
#  phone number = 01 298 8674  --  number of calls to customer service : 3
#  phone number = 01 299 1968  --  number of calls to customer service : 5
#  phone number = 01 299 6910  --  number of calls to customer service : 6
#  phone number = 01 300 0457  --  number of calls to customer service : 3
#  phone number = 01 300 3300  --  number of calls to customer service : 3
#  phone number = 01 300 4808  --  number of calls to customer service : 3
#  phone number = 01 301 5814  --  number of calls to customer service : 2
#  phone number = 01 301 8491  --  number of calls to customer service : 5
#  phone number = 01 302 5938  --  number of calls to customer service : 3
#  phone number = 01 303 2429  --  number of calls to customer service : 3
#  phone number = 01 303 6077  --  number of calls to customer service : 3
#  phone number = 01 303 6152  --  number of calls to customer service : 1
#  phone number = 01 304 0309  --  number of calls to customer service : 9
#  phone number = 01 304 0401  --  number of calls to customer service : 2
#  phone number = 01 304 1114  --  number of calls to customer service : 3
#  phone number = 01 305 0448  --  number of calls to customer service : 3
#  phone number = 01 305 1589  --  number of calls to customer service : 6
#  phone number = 01 305 9725  --  number of calls to customer service : 3
#  phone number = 01 306 4064  --  number of calls to customer service : 4
#  phone number = 01 306 9805  --  number of calls to customer service : 1
#  phone number = 01 307 2572  --  number of calls to customer service : 6
#  phone number = 01 308 6438  --  number of calls to customer service : 2
#  phone number = 01 308 8054  --  number of calls to customer service : 4
#  phone number = 01 308 8092  --  number of calls to customer service : 8
#  phone number = 01 309 6489  --  number of calls to customer service : 1
#  phone number = 01 309 8936  --  number of calls to customer service : 3
#  phone number = 01 310 7654  --  number of calls to customer service : 6
#  phone number = 01 310 9309  --  number of calls to customer service : 1
#  phone number = 01 311 2568  --  number of calls to customer service : 1
#  phone number = 01 311 3058  --  number of calls to customer service : 1
#  phone number = 01 311 4869  --  number of calls to customer service : 2
#  phone number = 01 312 2399  --  number of calls to customer service : 7
#  phone number = 01 314 4643  --  number of calls to customer service : 2
#  phone number = 01 314 6617  --  number of calls to customer service : 2
#  phone number = 01 315 3292  --  number of calls to customer service : 3
#  phone number = 01 315 7585  --  number of calls to customer service : 2
#  phone number = 01 317 8196  --  number of calls to customer service : 2
#  phone number = 01 318 7069  --  number of calls to customer service : 5
#  phone number = 01 319 0829  --  number of calls to customer service : 5
#  phone number = 01 319 6933  --  number of calls to customer service : 4
#  phone number = 01 320 1786  --  number of calls to customer service : 7
#  phone number = 01 321 3899  --  number of calls to customer service : 4
#  phone number = 01 321 6436  --  number of calls to customer service : 4
#  phone number = 01 321 7383  --  number of calls to customer service : 6
#  phone number = 01 323 8791  --  number of calls to customer service : 2
#  phone number = 01 324 0817  --  number of calls to customer service : 5
# ...
#  phone number = 095 089 6861  --  number of calls to customer service : 4
#  phone number = 095 093 6529  --  number of calls to customer service : 1
#  phone number = 095 104 4167  --  number of calls to customer service : 12
#  phone number = 095 119 3949  --  number of calls to customer service : 2
#  phone number = 095 125 1767  --  number of calls to customer service : 7
#  phone number = 095 137 6784  --  number of calls to customer service : 11
#  phone number = 095 189 9559  --  number of calls to customer service : 2
#  phone number = 095 233 6225  --  number of calls to customer service : 1
#  phone number = 095 237 0920  --  number of calls to customer service : 8
#  phone number = 095 265 2444  --  number of calls to customer service : 13
#  phone number = 095 276 1170  --  number of calls to customer service : 1
#  phone number = 095 281 1792  --  number of calls to customer service : 2
#  phone number = 095 319 7775  --  number of calls to customer service : 1
#  phone number = 095 369 0498  --  number of calls to customer service : 5
#  phone number = 095 386 3222  --  number of calls to customer service : 1
#  phone number = 095 398 6440  --  number of calls to customer service : 4
#  phone number = 095 414 6769  --  number of calls to customer service : 4
#  phone number = 095 427 3639  --  number of calls to customer service : 2
#  phone number = 095 432 0525  --  number of calls to customer service : 5
#  phone number = 095 483 6391  --  number of calls to customer service : 6
#  phone number = 095 503 6129  --  number of calls to customer service : 2
#  phone number = 095 553 1980  --  number of calls to customer service : 2
#  phone number = 095 562 2752  --  number of calls to customer service : 6
#  phone number = 095 590 6556  --  number of calls to customer service : 7
#  phone number = 095 592 9168  --  number of calls to customer service : 3
#  phone number = 095 592 9413  --  number of calls to customer service : 5
#  phone number = 095 595 1684  --  number of calls to customer service : 1
#  phone number = 095 639 0996  --  number of calls to customer service : 1
#  phone number = 095 696 3668  --  number of calls to customer service : 4
#  phone number = 095 708 1099  --  number of calls to customer service : 7
#  phone number = 095 737 1152  --  number of calls to customer service : 2
#  phone number = 095 770 1007  --  number of calls to customer service : 9
#  phone number = 095 773 9254  --  number of calls to customer service : 3
#  phone number = 095 778 5357  --  number of calls to customer service : 2
#  phone number = 095 785 7003  --  number of calls to customer service : 1
#  phone number = 095 809 4048  --  number of calls to customer service : 3
#  phone number = 095 860 7556  --  number of calls to customer service : 4
#  phone number = 095 873 9443  --  number of calls to customer service : 7
#  phone number = 095 893 5103  --  number of calls to customer service : 2
#  phone number = 095 910 5244  --  number of calls to customer service : 1
#  phone number = 095 911 0660  --  number of calls to customer service : 1
#  phone number = 095 930 6123  --  number of calls to customer service : 3
#  phone number = 095 937 2294  --  number of calls to customer service : 1
#  phone number = 095 943 2513  --  number of calls to customer service : 4
#  phone number = 095 974 1555  --  number of calls to customer service : 3
#  phone number = 096 031 2027  --  number of calls to customer service : 1
#  phone number = 096 049 6722  --  number of calls to customer service : 1
#  phone number = 096 163 8616  --  number of calls to customer service : 2
#  phone number = 096 166 1215  --  number of calls to customer service : 2
#  phone number = 096 178 1757  --  number of calls to customer service : 4
#  phone number = 096 186 4517  --  number of calls to customer service : 5
#  phone number = 096 216 7538  --  number of calls to customer service : 1
#  phone number = 096 240 7557  --  number of calls to customer service : 2
#  phone number = 096 241 5530  --  number of calls to customer service : 5
#  phone number = 096 245 2124  --  number of calls to customer service : 3
#  phone number = 096 274 9944  --  number of calls to customer service : 2
#  phone number = 096 303 9307  --  number of calls to customer service : 3
#  phone number = 096 324 9242  --  number of calls to customer service : 4
#  phone number = 096 411 5000  --  number of calls to customer service : 2
#  phone number = 096 425 4011  --  number of calls to customer service : 2
#  phone number = 096 451 4366  --  number of calls to customer service : 9
#  phone number = 096 481 4167  --  number of calls to customer service : 5
#  phone number = 096 491 3734  --  number of calls to customer service : 4
#  phone number = 096 583 0838  --  number of calls to customer service : 1
#  phone number = 096 596 8412  --  number of calls to customer service : 6
#  phone number = 096 624 6086  --  number of calls to customer service : 2
#  phone number = 096 628 0190  --  number of calls to customer service : 7
#  phone number = 096 660 8648  --  number of calls to customer service : 1
#  phone number = 096 675 2696  --  number of calls to customer service : 3
#  phone number = 096 721 2926  --  number of calls to customer service : 4
#  phone number = 096 724 1328  --  number of calls to customer service : 5
#  phone number = 096 760 4136  --  number of calls to customer service : 4
#  phone number = 096 762 4518  --  number of calls to customer service : 4
#  phone number = 096 762 5554  --  number of calls to customer service : 3
#  phone number = 096 776 3415  --  number of calls to customer service : 1
#  phone number = 096 778 6309  --  number of calls to customer service : 2
#  phone number = 096 824 3556  --  number of calls to customer service : 1
#  phone number = 096 843 3437  --  number of calls to customer service : 7
#  phone number = 096 856 8319  --  number of calls to customer service : 3
#  phone number = 096 894 9646  --  number of calls to customer service : 1
#  phone number = 096 911 2396  --  number of calls to customer service : 1
#  phone number = 096 917 0305  --  number of calls to customer service : 4
#  phone number = 096 942 1313  --  number of calls to customer service : 1
#  phone number = 096 954 7374  --  number of calls to customer service : 3
#  phone number = 096 963 9439  --  number of calls to customer service : 10
#  phone number = 096 984 5416  --  number of calls to customer service : 2
#  phone number = 097 049 1224  --  number of calls to customer service : 1
#  phone number = 097 128 0556  --  number of calls to customer service : 1
#  phone number = 097 156 3860  --  number of calls to customer service : 1
#  phone number = 097 159 3589  --  number of calls to customer service : 2
#  phone number = 097 168 9493  --  number of calls to customer service : 2
#  phone number = 097 211 1630  --  number of calls to customer service : 5
#  phone number = 097 241 8396  --  number of calls to customer service : 3
#  phone number = 097 276 0543  --  number of calls to customer service : 5
#  phone number = 097 286 3014  --  number of calls to customer service : 5
#  phone number = 097 309 1688  --  number of calls to customer service : 4
#  phone number = 097 337 9385  --  number of calls to customer service : 5
#  phone number = 097 343 4457  --  number of calls to customer service : 7
#  phone number = 097 355 2360  --  number of calls to customer service : 4
#  phone number = 097 383 9791  --  number of calls to customer service : 3
#  phone number = 097 458 2208  --  number of calls to customer service : 1
#  phone number = 097 470 1830  --  number of calls to customer service : 3
#  phone number = 097 480 6837  --  number of calls to customer service : 1
#  phone number = 097 492 8940  --  number of calls to customer service : 1
#  phone number = 097 518 8668  --  number of calls to customer service : 1
#  phone number = 097 539 0904  --  number of calls to customer service : 5
#  phone number = 097 546 3920  --  number of calls to customer service : 2
#  phone number = 097 566 2311  --  number of calls to customer service : 2
#  phone number = 097 584 7397  --  number of calls to customer service : 7
#  phone number = 097 601 5401  --  number of calls to customer service : 3
#  phone number = 097 603 9467  --  number of calls to customer service : 5
#  phone number = 097 632 0123  --  number of calls to customer service : 2
#  phone number = 097 660 7672  --  number of calls to customer service : 2
#  phone number = 097 669 5398  --  number of calls to customer service : 1
#  phone number = 097 670 6904  --  number of calls to customer service : 5
#  phone number = 097 677 9605  --  number of calls to customer service : 7
#  phone number = 097 705 0231  --  number of calls to customer service : 4
#  phone number = 097 739 7332  --  number of calls to customer service : 1
#  phone number = 097 742 5312  --  number of calls to customer service : 1
#  phone number = 097 749 5893  --  number of calls to customer service : 1
#  phone number = 097 781 5993  --  number of calls to customer service : 1
#  phone number = 097 782 9315  --  number of calls to customer service : 4
#  phone number = 097 800 1897  --  number of calls to customer service : 2
#  phone number = 097 821 7601  --  number of calls to customer service : 1
#  phone number = 097 825 7348  --  number of calls to customer service : 4
#  phone number = 097 830 7504  --  number of calls to customer service : 1
#  phone number = 097 835 8282  --  number of calls to customer service : 8
#  phone number = 097 853 6536  --  number of calls to customer service : 6
#  phone number = 097 857 3575  --  number of calls to customer service : 5
#  phone number = 097 860 7752  --  number of calls to customer service : 7
#  phone number = 097 886 8635  --  number of calls to customer service : 2
#  phone number = 097 918 8834  --  number of calls to customer service : 4
#  phone number = 097 922 5004  --  number of calls to customer service : 1
#  phone number = 097 970 8184  --  number of calls to customer service : 7
#  phone number = 097 978 6830  --  number of calls to customer service : 7
#  phone number = 097 984 1283  --  number of calls to customer service : 5
#  phone number = 098 023 1709  --  number of calls to customer service : 1
#  phone number = 098 024 6082  --  number of calls to customer service : 1
#  phone number = 098 033 2530  --  number of calls to customer service : 8
#  phone number = 098 058 2030  --  number of calls to customer service : 6
#  phone number = 098 067 7222  --  number of calls to customer service : 6
#  phone number = 098 148 2924  --  number of calls to customer service : 2
#  phone number = 098 175 2992  --  number of calls to customer service : 2
#  phone number = 098 203 9497  --  number of calls to customer service : 2
#  phone number = 098 223 3747  --  number of calls to customer service : 7
#  phone number = 098 270 2822  --  number of calls to customer service : 1
#  phone number = 098 302 3134  --  number of calls to customer service : 5
#  phone number = 098 325 9421  --  number of calls to customer service : 7
#  phone number = 098 395 7912  --  number of calls to customer service : 2
#  phone number = 098 436 3682  --  number of calls to customer service : 4
#  phone number = 098 456 6760  --  number of calls to customer service : 4
#  phone number = 098 471 2379  --  number of calls to customer service : 3
#  phone number = 098 471 5749  --  number of calls to customer service : 6
#  phone number = 098 479 8154  --  number of calls to customer service : 3
#  phone number = 098 506 4624  --  number of calls to customer service : 1
#  phone number = 098 507 3591  --  number of calls to customer service : 1
#  phone number = 098 532 2951  --  number of calls to customer service : 4
#  phone number = 098 568 8430  --  number of calls to customer service : 4
#  phone number = 098 645 4041  --  number of calls to customer service : 1
#  phone number = 098 662 8068  --  number of calls to customer service : 5
#  phone number = 098 733 2818  --  number of calls to customer service : 5
#  phone number = 098 742 7462  --  number of calls to customer service : 8
#  phone number = 098 745 4469  --  number of calls to customer service : 2
#  phone number = 098 746 1914  --  number of calls to customer service : 5
#  phone number = 098 787 5555  --  number of calls to customer service : 1
#  phone number = 098 792 0545  --  number of calls to customer service : 1
#  phone number = 098 793 5932  --  number of calls to customer service : 2
#  phone number = 098 802 1130  --  number of calls to customer service : 2
#  phone number = 098 804 6637  --  number of calls to customer service : 3
#  phone number = 098 861 2349  --  number of calls to customer service : 7
#  phone number = 098 876 1159  --  number of calls to customer service : 6
#  phone number = 098 976 3902  --  number of calls to customer service : 3
#  phone number = 098 984 0097  --  number of calls to customer service : 11
#  phone number = 098 986 3148  --  number of calls to customer service : 2
#  phone number = 099 007 2663  --  number of calls to customer service : 6
#  phone number = 099 074 8265  --  number of calls to customer service : 3
#  phone number = 099 118 3706  --  number of calls to customer service : 4
#  phone number = 099 123 4828  --  number of calls to customer service : 3
#  phone number = 099 131 8627  --  number of calls to customer service : 5
#  phone number = 099 155 4735  --  number of calls to customer service : 4
#  phone number = 099 182 3641  --  number of calls to customer service : 2
#  phone number = 099 183 1097  --  number of calls to customer service : 6
#  phone number = 099 201 0842  --  number of calls to customer service : 7
#  phone number = 099 205 6701  --  number of calls to customer service : 1
#  phone number = 099 236 8205  --  number of calls to customer service : 1
#  phone number = 099 254 0042  --  number of calls to customer service : 1
#  phone number = 099 264 7569  --  number of calls to customer service : 7
#  phone number = 099 302 4237  --  number of calls to customer service : 5
#  phone number = 099 329 2806  --  number of calls to customer service : 4
#  phone number = 099 385 3375  --  number of calls to customer service : 4
#  phone number = 099 392 3191  --  number of calls to customer service : 3
#  phone number = 099 403 7775  --  number of calls to customer service : 3
#  phone number = 099 421 7006  --  number of calls to customer service : 7
#  phone number = 099 422 7581  --  number of calls to customer service : 1
#  phone number = 099 459 2667  --  number of calls to customer service : 9
#  phone number = 099 467 0203  --  number of calls to customer service : 3
#  phone number = 099 496 5160  --  number of calls to customer service : 5
#  phone number = 099 534 3954  --  number of calls to customer service : 6
#  phone number = 099 567 1853  --  number of calls to customer service : 2
#  phone number = 099 573 8495  --  number of calls to customer service : 6
#  phone number = 099 649 5307  --  number of calls to customer service : 8
#  phone number = 099 653 9766  --  number of calls to customer service : 5
#  phone number = 099 665 4287  --  number of calls to customer service : 5
#  phone number = 099 687 9704  --  number of calls to customer service : 1
#  phone number = 099 760 8745  --  number of calls to customer service : 7
#  phone number = 099 768 5189  --  number of calls to customer service : 1
#  phone number = 099 776 2074  --  number of calls to customer service : 5
#  phone number = 099 786 5545  --  number of calls to customer service : 1
#  phone number = 099 804 3736  --  number of calls to customer service : 1
#  phone number = 099 818 3679  --  number of calls to customer service : 3
#  phone number = 099 863 6734  --  number of calls to customer service : 1
#  phone number = 099 891 4468  --  number of calls to customer service : 6
#  phone number = 099 932 6937  --  number of calls to customer service : 5
#  phone number = 099 959 2978  --  number of calls to customer service : 3
#  phone number = 099 965 9604  --  number of calls to customer service : 3
#  phone number = 099 971 0686  --  number of calls to customer service : 1

# %% [markdown]
# c) The number of calls made by call rate (2 marks)

# %%
conn.rollback()
result = conn.execute(text("SELECT calls.callrate, COUNT(*) as num_calls_per_rate " 
                        "FROM calls "
                        "GROUP BY calls.callrate "
                        "ORDER BY calls.callrate;"
                        #")"
)
)

# get the value from the tuple result returned byt the sql query
num_calls_per_callrate = result.fetchall()

# we have 4 rates in our output data i a list of tuples
# given its 4 rates we'll put it into a data fram instead of looping through the list and pritning to mak it a bit easier to read

# we'lla ssign the tuple object to a pandas df and specify the coumn names, then pritn it out to view it
num_call_per_rate_df = pd.DataFrame(num_calls_per_callrate, columns=['callrate', 'num_of_calls'] )
print(num_call_per_rate_df)
# Out:
#    callrate  num_of_calls
# 0         1         40467
# 1         2         40326
# 2         3         40632
# 3         4         40159

# %% [markdown]
# # Report

# %% [markdown]
# Describe your findings in a short report, summarizing the information you have collected from previous questions and giving some interpretation of results. You might for example generate a table with results, and give some interpretation in a few sentences. You can also imagine you are an analyst interested in reading this report and collecting the most important information extracted from the data. (5 marks)

# %%
# Calculate total revenue per call rate - to see which are most profitable
# we multiple cost per min by call duration converted to mins and SUm that for each rate
# exclude customer servcie calls as w did earlier
conn.rollback()
result = conn.execute(text("SELECT call_rates.callrate, SUM(calls.duration/60 * call_rates.costperminute) AS total_revenue "
                           "FROM calls "
                           "JOIN call_rates "
                           "ON calls.callrate = call_rates.callrate "
                           "WHERE calls.connectionid NOT IN (SELECT connectionid FROM customer_service) "
                           "GROUP BY call_rates.callrate "
                           "ORDER BY total_revenue DESC "
                        #")"
)
)

rev_per_cr = result.fetchall()


rev_per_cr_df = pd.DataFrame(rev_per_cr, columns=['callrate', 'total revenue euro'] )
# reveue is a string object - need to convert to numeric and also round to 2 decomal places
rev_per_cr_df['total revenue euro'] = pd.to_numeric(rev_per_cr_df['total revenue euro'])
rev_per_cr_df['total revenue euro'] = rev_per_cr_df['total revenue euro'].round(2)

# display table for total revenue per call rate
print(rev_per_cr_df)
# Out:
#    callrate  total revenue euro
# 0         1           312593.02
# 1         2           143787.12
# 2         3           143047.63
# 3         4            16238.57

# %%
# alculate how many calls are international , romaing and not internation
conn.rollback()
result = conn.execute(text("SELECT "
                           "SUM(CASE WHEN cr.isinternational = 'TRUE' THEN 1 ELSE 0 END) AS international_calls, "
                           "SUM(CASE WHEN cr.isroaming = 'TRUE' THEN 1 ELSE 0 END) AS roaming_calls, "
                           "SUM(CASE WHEN cr.isinternational != 'TRUE' AND cr.isroaming != 'TRUE' THEN 1 ELSE 0 END) AS domestic_calls "
                           "FROM calls c "
                           "JOIN call_rates cr ON c.callrate = cr.callrate; "
                           # ")"
)
)


international, roaming, domestic = result.fetchone()
total_num_calls = (international+roaming+domestic)

print(f"International calls: {international}")
print(f"Roaming calls: {roaming}")
print(f"Domestic calls: {domestic}")
print(f" total number of calls = {total_num_calls}")
# Out:
# International calls: 80793
# Roaming calls: 81099
# Domestic calls: 40159
#  total number of calls = 202051

# %%
call_rates_df = tbls_dict['call_rates']
print(call_rates_df)
print(num_call_per_rate_df)
print(rev_per_cr_df)

# merge num calls df with total revenue df
num_calls_rev_rate_df = pd.merge(num_call_per_rate_df, rev_per_cr_df, on='callrate')
# merge with call rates tables
full_rates_df = pd.merge(num_calls_rev_rate_df, call_rates_df, on='callrate')
full_rates_df['costperminute'] = pd.to_numeric(full_rates_df['costperminute'])
print(full_rates_df)
print(full_rates_df.columns)
print(full_rates_df.dtypes)
# Out:
#    callrate isinternational isroaming costperminute
# 0         1            TRUE      TRUE          0.57
# 1         2            TRUE     FALSE          0.26
# 2         3           FALSE      TRUE          0.26
# 3         4           FALSE     FALSE          0.03
#    callrate  num_of_calls
# 0         1         40467
# 1         2         40326
# 2         3         40632
# 3         4         40159
#    callrate  total revenue euro
# 0         1           312593.02
# 1         2           143787.12
# 2         3           143047.63
# 3         4            16238.57
#    callrate  num_of_calls  total revenue euro isinternational isroaming  \
# 0         1         40467           312593.02            TRUE      TRUE
# 1         2         40326           143787.12            TRUE     FALSE
# 2         3         40632           143047.63           FALSE      TRUE
# 3         4         40159            16238.57           FALSE     FALSE
#
#    costperminute
# 0           0.57
# 1           0.26
# 2           0.26
# 3           0.03
# Index(['callrate', 'num_of_calls', 'total revenue euro', 'isinternational',
#        'isroaming', 'costperminute'],
#       dtype='object')
# callrate                int64
# num_of_calls            int64
# total revenue euro    float64
# isinternational        object
# isroaming              object
# costperminute         float64
# dtype: object

# %%
#summary_stats = full_rates_df[['num_of_calls', 'total revenue euro', 'costperminute']].describe()
summary_stats = full_rates_df.describe()
print(summary_stats)
# Out:
#        callrate  num_of_calls  total revenue euro  costperminute
# count  4.000000       4.00000            4.000000        4.00000
# mean   2.500000   40396.00000       153916.585000        0.28000
# std    1.290994     201.49938       121592.471097        0.22166
# min    1.000000   40159.00000        16238.570000        0.03000
# 25%    1.750000   40284.25000       111345.365000        0.20250
# 50%    2.500000   40396.50000       143417.375000        0.26000
# 75%    3.250000   40508.25000       185988.595000        0.33750
# max    4.000000   40632.00000       312593.020000        0.57000

# %%
# import matplotlib.pyplot as plt
# import numpy as np


# define the three sets pf data we'll use,  we will use - revenue / call rate / number of calls
labels = full_rates_df['callrate'].astype(str)
num_calls = full_rates_df['num_of_calls']
revenue = full_rates_df['total revenue euro']

# define the bin width and label locations
x = np.arange(len(labels))
width = 0.35  

fig, ax1 = plt.subplots(figsize=(10,6))

# plot the data with labels
ax1.bar(x - width/2, num_calls, width, label='Number of Calls', color='skyblue')
ax1.set_xlabel('Call Rate')
ax1.set_ylabel('Number of Calls', color='skyblue')
ax1.tick_params(axis='y', labelcolor='skyblue')
ax1.set_xticks(x)
ax1.set_xticklabels(labels)

# Create a twin axis for revenue
ax2 = ax1.twinx()
ax2.bar(x + width/2, revenue, width, label='Total Revenue', color='orange')
ax2.set_ylabel('Total Revenue (€)', color='orange')
ax2.tick_params(axis='y', labelcolor='orange')

# define the title and la legend
plt.title('Number of Calls vs Total Revenue per Call Rate')
fig.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming your merged DataFrame is named full_rates_df
plt.figure(figsize=(8,6))
plt.bar(full_rates_df['callrate'].astype(str), full_rates_df['total revenue euro'], color='orange')
plt.xlabel('Call Rate')
plt.ylabel('Total Revenue (€)')
plt.title('Total Revenue per Call Rate')
plt.xticks(rotation=0)
plt.show()

# %%
import matplotlib.pyplot as plt

# Pie chart for percentage contribution to total revenue by call rate
plt.figure(figsize=(6, 6))
plt.pie(
    full_rates_df['total revenue euro'], 
    labels=full_rates_df['callrate'], 
    autopct='%1.1f%%', 
    startangle=90, 
    wedgeprops={'edgecolor': 'white'}
)

plt.title('Percentage Contribution to Total Revenue by Call Rate', fontsize=12)
plt.show()

# %%
import matplotlib.pyplot as plt

# relationship between cost per minute and total revenue is there a correlati between the two
# yes the higher the rate the hugher the revenue
plt.scatter(full_rates_df['costperminute'], full_rates_df['total revenue euro'])
plt.xlabel('Cost per minute (€)')
plt.ylabel('Total revenue (€)')
plt.title('Cost per minute vs Total Revenue')
plt.show()

# %%
# relationship between number of calls and total revenue is there a correlati between the two
# yes the higher the rate the hugher the revenue
plt.scatter(full_rates_df['num_of_calls'], full_rates_df['total revenue euro'])
plt.xlabel('Cost per minute (€)')
plt.ylabel('Total revenue (€)')
plt.title('Cost per minute vs Total Revenue')
plt.show()

# %% [markdown]
# Add any text here

# %% [markdown]
# we dont' have a customer ID number! only way to know how many individual customers there are is by dob
# how many dob are tjhe sidentical?
#
# how many customers have more than one phone?
#
# the most profitable rates
# the most used rates
#
# international calls
#
# % roaming percentage of calls overall that are internation - canwe  determine profits off them?
#
# age profile of users?
#
# typical contract start date - can we crete alerts before contract expires to contact customers and try get themto rne before expiry
# to keep their numbers they need to renww before expiry otherwise we issue them wirha  new numbers (etoprtion)
