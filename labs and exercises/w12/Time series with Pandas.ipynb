# %% [markdown]
# # Loading and Analysing Time Series Data with *Pandas*
#
# Use this notebook to work along with the examples in the lecture notes

# %% [markdown]
# ### Task 1

# %% [markdown]
# Check the documentation for the strftime and strptime method [here](https://docs.python.org/3/library/datetime.html#strftime-and-strptime-format-codes).
# Given the following time string '2023-10-26 14:45:00' create a datetime object with `strptime`.
# Use the datetime object and create two strings with `strftime`. The strings should have the following format:
#
# <code>Month DD, YYYY - HH:MM AM/PM
# HH:MM AM/PM</code>

# %% [markdown]
# ### Task 2

# %% [markdown]
# Download the `dow_jones_index.csv` file [here](https://drive.google.com/file/d/1hNhWE8lWABOjviK8KSZ8btwPm-lM2hFK/view?usp=sharing) and load it using `read_csv` from Pandas. Create a copy of the dataframe containing only IBM stock information.
#
# Use [pd.to_datetime](https://pandas.pydata.org/docs/reference/api/pandas.to_datetime.html) to convert the date column to the correct type.
# Set the date column as the index using  [set_index](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.set_index.html#pandas.DataFrame.set_index)
#
# Get the first and last date in the series

# %% [markdown]
# ### Task 3

# %% [markdown]
# Change the `open` column to `float`. Hint: you will need to format it to remove the `$`
# Using the [plot](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.html#pandas.DataFrame.plot) function plot the open price for IBM stocks from January 2011 till February 2011. Hint: you can use slice to get a subset of the dataframe.

# %% [markdown]
# ### Task 4

# %% [markdown]
# Still using the IBM stock values, resample the `high` feature to monthly intervals, keeping the maximum value of each month.
# Resample the monthly values to quarterly, keeping the `mean` of each month.
#
# Hint: check the possible aggregation functions for resample [here](https://pandas.pydata.org/docs/reference/resampling.html#computations-descriptive-stats)

# %% [markdown]
# ### Task 5

# %% [markdown]
# Get the stock prices for GE, IBM, and MSFT.  Calculate the 4-week rolling mean of their open stock prices.
# Plot all three rolling mean in a single graph.
#
# Hint: Try to create a loop that will iterate over the different companies.

# %% [markdown]
# ### Task 6

# %% [markdown]
# Let’s fill missing values with a moving average window.
# Use the data below as a simple example:

# %%
data = {
    'Date': pd.date_range(start='2023-11-02', periods=10, freq='D'),
    'Value': [1.1, 2.2, np.nan, 4.4, 5.5, np.nan, np.nan, 8.8, 9.9, 10.0]
}

data = pd.DataFrame(data)

# %% [markdown]
# Create a rolling window of size 3 and calculate the moving average. Using the fillna method, pass the previous result ro replace NAs
#
# Hint: You will need to use the min_periods parameter of the [rolling](https://pandas.pydata.org/docs/reference/api/pandas.core.groupby.DataFrameGroupBy.rolling.html) method.

# %% [markdown]
# ### Task 7
#
# Using the values and moving averages calculated on Task 6 plot a line graph Showing both columns over time.
#
#
# Highlight the value value points in which *value - moving_average > 1*.
